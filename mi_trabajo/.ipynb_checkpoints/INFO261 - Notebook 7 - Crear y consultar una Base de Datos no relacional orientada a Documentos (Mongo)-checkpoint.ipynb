# %% [markdown]
# # Notebook 7 - Crear y consultar una Base de Datos no relacional orientada a Documentos (Mongo)

# %% [markdown]
# ## Ejercicio 1: Primeros pasos desde Mongo CLI

# %% [markdown]
# En un terminal, verificar si el SGBD Mongo ya está iniciado:
#
# <code>ps -aux | grep mongod</code>
#
# Si no está iniciado, iniciarlo con el comando: <code>mongod</code>
#
# Luego, abrir otra pestaña de terminal (CTRL + Shift + T) e iniciar el cliente CLI de mongo: <code>mongo</code>.

# %% [markdown]
# 1) Creamos una nueva base de datos llamado <b>nb7-peliculas</b>
#
# <code>use nb7-peliculas</code>
#
# Deberian ver como respuesta del sistema la respuesta: "switched to db nb7-peliculas"

# %% [markdown]
# Mongo CLI no utiliza SQL para realizar operaciones CRUD (Create/Read/Update/Delete), utiliza su propia API parecida al lenguaje Javascript.
#
# La variable <code>db</code> representa siempre la base de datos que estamos utilizando (en este caso "nb7-peliculas").
#
# 2) Creamos una colección <b>actors</b>
#
# <code>db.actors.insert({firstname:"Will", lastname:"Smith"})</code>
#
# Como pueden verlo, para crear la colección no tuvimos que definir la estructura de la colección, simplemente hemos insertado un documento.
#
# Verificamos que hemos realmente creado la coleccion con:
#
# <code>db.actors.find()</code>
#
# 3) Insertamos varios documentos en la colección en un solo comando:
#
# <code>db.actors.insertMany([{firstname:"Scarlett", lastname:"Johanson"},{firstname:"Matt", lastname:"Damon"},{firstname:"Nathan", lastname:"Smith"}])</code>
#
# 4) Contamos cuántos documentos tenemos en la colección:
#
# <code>db.actors.count()</code>
#
# Como en SQL, la API de Mongo permite construir consultas para filtrar, ordenar o agrupar datos. Sin embargo, la síntaxis es distinta (y amenudo menos simple e intuitiva que SQL).
#
# 5) Filtramos los actores que se llaman 'Smith'
#
# <code>db.actors.find({lastname:"Smith"})</code>
#
# Mongo tambien permite modificar los datos (ojo: Mongo no tiene mecanismo interno para asegurar la coherencia de los datos, es la responsabilidad del programador de la aplicación).
#
# 6) Actualizamos un documento. Por ejemplo, "Nathan Smith" se llama ahora "Nathan Lane"
#
# <code>db.actors.update({firstname:"Nathan", lastname:"Smith"},{$set : {lastname:"Lane"}})</code>
#
# Este último comando va a actualizar el primer documento encontrado que corresponde al filtro definido.
#
# 7) Supongamos ahora que queremos agregar un campo "gender" en todos los documentos:
#
# ¿Qué hace el comando siguiente? ¿Cuál es el limite?
#
# <code>db.actors.update({},{$set : {gender:"M"}})</code>
#
# Para actualizar todos los documentos, y no simplemente el primero, podemos utilizar el comando:
#
# <code>db.actors.update({},{$set : {gender:"M"}},{multi:true})</code>
#
# 8) Actualizar el documento "Scarlett Johanson", para indicar que es una mujer (gender:"F").
#
# 9) Para suprimir un atributo, podemos utilizar el operador $unset. Por ejemplo:
#
# <code>db.actors.update({},{$unset : {gender:1}},{multi:true})</code>
#
# 10) Para suprimir un documento completo, podemos utilizar el comando:
#
# <code>db.actors.remove({lastname:"Smith"})</code>
#
# 11) Agregamos un atributo de tipo arreglo en un documento
#
# <code>db.actors.update({firstname:"Matt"},{$set : {tab:[1,"a"]}})</code>
#
# 12) Añadimos un valor en el arreglo con el operator $push
#
# <code>db.actors.update({firstname:"Matt"},{$push : {tab:["new_value"]}})</code>
#
# ¿Cuál es el problema con el último comando? ¿Cuál es la diferencia con el comando siguiente?
#
# <code>db.actors.update({firstname:"Matt"},{$push : {tab:"new_value"}})</code>
#
# Cómo pueden verlo el SGBD no relacional Mongo es mucho más flexible que MySQL, pero deja mucho más posibilidad de equivocarse.
#
#
# No duden en consultar la documentación de Mongo para probar otros comandos CRUD: https://docs.mongodb.com/manual/crud/

# %% [markdown]
# ## Ejercicio 2: Primeras consultas avanzadas con una colección de peliculas
#
# En este segundo ejercicio, trabajaremos con una base de datos existente llamada "movie details", la cual tiene 2295 documentos JSON resumiendo información sobre peliculas.
#
# - Descargar el dataset https://raw.githubusercontent.com/steveren/docs-assets/charts-tutorial/movieDetails.json. ¿Qué contiene este archivo? Un documento JSON? Un arreglo de documentos JSON? Una lista de documentos JSON?
#
# - Importamos los datos en Mongo con el comando siguiente:
#
# <code>mongoimport --db nb7-peliculas --collection movieDetails --drop --file <path/to/movieDetails.json></code>
#
# A continuación, queremos realizar algunas consultas típicas para observar la diferencia entre el lenguaje de consulta SQL y el lenguaje de Mongo.
#
# <b>Nota bena</b>: ¿Qué pasa si agregan la función <code>.pretty()</code> al final de un comando? Por ejemplo: <code>db.actors.find().pretty()</code>
#
# 1) Utilizar un comando Mongo para contar cuántos documentos hay en la colección 'movieDetails'. ¿Cuál sería el equivalente en SQL?
#
# <code>select count(*) from movieDetails</code>/<code>db.movieDetails.count()</code>
#
# 2) Mostrar los títulos (title) y años de producción (year) de todas las peliculas de la colección. ¿A qué clausula SQL correspondría?
#
# <code>select title, year from movieDetails</code>/<code>db.movieDetails.find({},{title:1,year:1})</code>
#
# 3) Contar las peliculas realizadas entre 1990 y 2000
#
# <code>db.movieDetails.count({$and:[{year:{$gte:1990}},{year:{$lte:2000}}]})</code>
#
# 4) ¿Cuáles son los titulos de peliculas que ganaron más de 5 awards?
#
# <code>db.movieDetails.find({"awards.wins":{$gt:5}},{title:1,"awards.wins":1,_id:0})</code>
#
# 5) ¿Cuál es el rating promedio en el sitio imdb para todas las peliculas?
#
# <code>db.movieDetails.aggregate([{$group:{_id:null,average:{$avg:"$imdb.rating"}}}])</code>
#
# 6) ¿Cuáles son las peliculas en las cuales participó el actor Nicolas Cage?
#
# <code>db.movieDetails.find({actors:"Nicolas Cage"},{_id:0,title:1})</code>
#
# 7) ¿Cuál es el número de pelicula por año?
#
# <code>db.movieDetails.aggregate([{$group:{_id:"$year",numeropeliculas:{$sum:1}}}])</code>
#
# 8) ¿Cuál es la pelicula con el mejor rating?
#
# <code>db.movieDetails.find({},{title:1,"imdb.rating":1,_id:0}).sort({"imdb.rating":-1}).limit(1)</code>
#
# 9) ¿Cuáles son los thrillers con un rating de al menos 6?
#
# <code>db.movieDetails.find({$and:[{"imdb.rating":{$gte:6}},{genres:"Thriller"}]},{_id:0,title:1,"imdb.rating":1})</code>
#
# 10) ¿Cuáles son todos los valores de generos posibles?
#
# <code>db.movieDetails.distinct("genres")</code>
#
# 11) ¿Cuáles son las peliculas que contienen la palabra 'Star'?
#
# <code>db.movieDetails.find({title: {$regex:".*star", $options:"i"}},{_id:0,title:1})</code>
#
# 12) ¿Cuáles son los títulos que empiezan con la letra 'T'?
#
# <code>db.movieDetails.find({title:{$regex:/^T/}},{title:1})</code>
#
# 13) ¿Cuáles son las peliculas que no son de tipo Drama o Thriller?
#
# <code>db.movieDetails.find({$and:[{genres:{$ne:"Thriller"}},{genres:{$ne:"Drama"}}]})</code>

# %% [markdown]
# ## Ejercicio 3: Integrar Mongo con Python
#
# Desde un entorno Python, conectarse a su base de datos movieDetails y realizar consultas similares al ejercicio 2.

# %%
import json
import pymongo
from pymongo import MongoClient
from pprint import pprint

client = MongoClient('localhost', 27017)
db = client['nb7_peliculas']
collection = db['movieDetails']

# %%
#1) Utilizar un comando Mongo para contar cuántos documentos hay en la colección 'movieDetails'

count = db.movieDetails.estimated_document_count()
print(count)
# Out:
# 2295

# %%
#2) Mostrar los títulos (title) y años de producción (year) de todas las peliculas de la colección

for i in db.movieDetails.find({},{'title':1,'year':1,'_id':0}):
    print(i)
# Out:
# {'title': 'West Side Story', 'year': 1961.0}
# {'title': 'Wild Wild West', 'year': 1999.0}
# {'title': 'Once Upon a Time in the West', 'year': 1968.0}
# {'title': 'An American Tail: Fievel Goes West', 'year': 1991.0}
# {'title': 'Red Rock West', 'year': 1993.0}
# {'title': 'How the West Was Won', 'year': 1962.0}
# {'title': 'Slow West', 'year': 2015.0}
# {'title': 'A Million Ways to Die in the West', 'year': 2014.0}
# {'title': 'Journey to the West', 'year': 2013.0}
# {'title': 'Star Wars: Episode V - The Empire Strikes Back', 'year': 1980.0}
# {'title': 'West of Memphis', 'year': 2012.0}
# {'title': 'Star Wars: Episode IV - A New Hope', 'year': 1977.0}
# {'title': 'Star Wars: Episode I - The Phantom Menace', 'year': 1999.0}
# {'title': 'Star Wars: Episode VI - Return of the Jedi', 'year': 1983.0}
# {'title': 'Star Wars: Episode III - Revenge of the Sith', 'year': 2005.0}
# {'title': 'Star Wars: Episode II - Attack of the Clones', 'year': 2002.0}
# {'title': 'Star Trek Into Darkness', 'year': 2013.0}
# {'title': 'Star Trek', 'year': 2009.0}
# {'title': 'Star Trek: First Contact', 'year': 1996.0}
# {'title': 'Star Trek II: The Wrath of Khan', 'year': 1982.0}
# {'title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'year': 1964.0}
# {'title': 'Love Actually', 'year': 2003.0}
# {'title': 'Shakespeare in Love', 'year': 1998.0}
# {'title': 'P.S. I Love You', 'year': 2007.0}
# {'title': 'I Love You, Man', 'year': 2009.0}
# {'title': 'From Russia with Love', 'year': 1963.0}
# {'title': 'From Paris with Love', 'year': 2010.0}
# {'title': 'Punch-Drunk Love', 'year': 2002.0}
# {'title': 'I Love You Phillip Morris', 'year': 2009.0}
# {'title': '2001: A Space Odyssey', 'year': 1968.0}
# {'title': 'Office Space', 'year': 1999.0}
# {'title': 'Space Cowboys', 'year': 2000.0}
# {'title': 'Zathura: A Space Adventure', 'year': 2005.0}
# {'title': 'Love & Other Drugs', 'year': 2010.0}
# {'title': 'Plan 9 from Outer Space', 'year': 1959.0}
# {'title': 'Muppets from Space', 'year': 1999.0}
# {'title': '2001: A Space Travesty', 'year': 2000.0}
# {'title': 'Space Chimps', 'year': 2008.0}
# {'title': 'Turks in Space', 'year': 2006.0}
# {'title': 'The Adventures of Tintin', 'year': 2011.0}
# {'title': 'The Adventures of Priscilla, Queen of the Desert', 'year': 1994.0}
# {'title': 'The Adventures of Robin Hood', 'year': 1938.0}
# {'title': 'Adventures in Babysitting', 'year': 1987.0}
# {'title': 'Lost in Space', 'year': 1998.0}
# {'title': 'The Many Adventures of Winnie the Pooh', 'year': 1977.0}
# {'title': 'The Adventures of Sharkboy and Lavagirl 3-D', 'year': 2005.0}
# {'title': 'The Adventures of Buckaroo Banzai Across the 8th Dimension', 'year': 1984.0}
# {'title': 'The Extraordinary Adventures of Adèle Blanc-Sec', 'year': 2010.0}
# {'title': 'The Adventures of Rocky & Bullwinkle', 'year': 2000.0}
# {'title': 'The Truman Show', 'year': 1998.0}
# {'title': 'The Rocky Horror Picture Show', 'year': 1975.0}
# {'title': 'Quiz Show', 'year': 1994.0}
# {'title': 'Best in Show', 'year': 2000.0}
# {'title': 'The Last Picture Show', 'year': 1971.0}
# {'title': 'Show Me Love', 'year': 1998.0}
# {'title': 'The Greatest Show on Earth', 'year': 1952.0}
# {'title': "There's No Business Like Show Business", 'year': 1954.0}
# {'title': 'Show Boat', 'year': 1951.0}
# {'title': 'Show People', 'year': 1928.0}
# {'title': "Pirates of the Caribbean: Dead Man's Chest", 'year': 2006.0}
# {'title': 'Shaun of the Dead', 'year': 2004.0}
# {'title': 'Dead Poets Society', 'year': 1989.0}
# {'title': 'The Evil Dead', 'year': 1981.0}
# {'title': 'Dawn of the Dead', 'year': 2004.0}
# {'title': 'Evil Dead', 'year': 2013.0}
# {'title': 'Evil Dead II', 'year': 1987.0}
# {'title': 'Dawn of the Dead', 'year': 1978.0}
# {'title': 'Night of the Living Dead', 'year': 1968.0}
# {'title': "Before the Devil Knows You're Dead", 'year': 2007.0}
# {'title': 'Rise of the Planet of the Apes', 'year': 2011.0}
# {'title': 'Planet Terror', 'year': 2007.0}
# {'title': 'Planet of the Apes', 'year': 2001.0}
# {'title': 'Planet of the Apes', 'year': 1968.0}
# {'title': 'Treasure Planet', 'year': 2002.0}
# {'title': 'Dawn of the Planet of the Apes', 'year': 2014.0}
# {'title': 'Red Planet', 'year': 2000.0}
# {'title': 'Planet 51', 'year': 2009.0}
# {'title': 'Beneath the Planet of the Apes', 'year': 1970.0}
# {'title': 'Alien', 'year': 1979.0}
# {'title': 'Alien³', 'year': 1992.0}
# {'title': 'Forbidden Planet', 'year': 1956.0}
# {'title': 'Alien: Resurrection', 'year': 1997.0}
# {'title': 'AVP: Alien vs. Predator', 'year': 2004.0}
# {'title': 'My Stepmother Is an Alien', 'year': 1988.0}
# {'title': 'Alien Nation', 'year': 1988.0}
# {'title': 'Alien Raiders', 'year': 2008.0}
# {'title': 'Alien Autopsy', 'year': 2006.0}
# {'title': 'Alien Outpost', 'year': 2014.0}
# {'title': 'Butch Cassidy and the Sundance Kid', 'year': 1969.0}
# {'title': 'The Karate Kid', 'year': 1984.0}
# {'title': 'The Karate Kid', 'year': 2010.0}
# {'title': 'The Heartbreak Kid', 'year': 2007.0}
# {'title': 'The Kid', 'year': 1921.0}
# {'title': 'Alien Abduction', 'year': 2014.0}
# {'title': 'Honey I Blew Up the Kid', 'year': 1992.0}
# {'title': 'Diary of a Wimpy Kid', 'year': 2010.0}
# {'title': 'The Kid', 'year': 2000.0}
# {'title': 'Trail of the Pink Panther', 'year': 1982.0}
# {'title': 'The Kid with a Bike', 'year': 2011.0}
# {'title': 'The Karate Kid, Part II', 'year': 1986.0}
# {'title': 'False Trail', 'year': 2011.0}
# {'title': 'The Hallelujah Trail', 'year': 1965.0}
# {'title': 'Anacondas: Trail of Blood', 'year': 2009.0}
# {'title': 'HOUBA! On the Trail of the Marsupilami', 'year': 2012.0}
# {'title': 'The Big Trail', 'year': 1930.0}
# {'title': 'Crossfire Trail', 'year': 2001.0}
# {'title': 'MacGyver: Trail to Doomsday', 'year': 1994.0}
# {'title': 'Santa Fe Trail', 'year': 1940.0}
# {'title': 'Where the Trail Ends', 'year': 2012.0}
# {'title': 'All Quiet on the Western Front', 'year': 1930.0}
# {'title': 'All Quiet on the Western Front', 'year': 1979.0}
# {'title': 'Sukiyaki Western Django', 'year': 2007.0}
# {'title': 'The Decline of Western Civilization Part II: The Metal Years', 'year': 1988.0}
# {'title': 'Western Union', 'year': 1941.0}
# {'title': 'The Decline of Western Civilization', 'year': 1981.0}
# {'title': 'Brazilian Western', 'year': 2013.0}
# {'title': 'Total western', 'year': 2000.0}
# {'title': 'Western Spaghetti', 'year': 2008.0}
# {'title': 'Midnight Cowboy', 'year': 1969.0}
# {'title': 'Cowboy Bebop: The Movie', 'year': 2001.0}
# {'title': 'The Adventures of Baron Munchausen', 'year': 1988.0}
# {'title': 'Urban Cowboy', 'year': 1980.0}
# {'title': 'Drugstore Cowboy', 'year': 1989.0}
# {'title': 'The Cowboy Way', 'year': 1994.0}
# {'title': 'Cowboy', 'year': 1958.0}
# {'title': "Ride 'Em Cowboy", 'year': 1942.0}
# {'title': 'Carry on Cowboy', 'year': 1965.0}
# {'title': 'Quick Gun Murugun: Misadventures of an Indian Cowboy', 'year': 2009.0}
# {'title': 'The Cowboy and the Lady', 'year': 1938.0}
# {'title': 'The Naked Gun: From the Files of Police Squad!', 'year': 1988.0}
# {'title': 'Naked Gun 33 1/3: The Final Insult', 'year': 1994.0}
# {'title': 'The Naked Gun 2½: The Smell of Fear', 'year': 1991.0}
# {'title': 'The Man with the Golden Gun', 'year': 1974.0}
# {'title': 'Western', 'year': 1997.0}
# {'title': 'Machine Gun Preacher', 'year': 2011.0}
# {'title': 'Top Gun', 'year': 1986.0}
# {'title': 'The Way of the Gun', 'year': 2000.0}
# {'title': 'Johnny Got His Gun', 'year': 1971.0}
# {'title': 'Son of a Gun', 'year': 2014.0}
# {'title': 'Gun Crazy', 'year': 1950.0}
# {'title': 'Paris, Texas', 'year': 1984.0}
# {'title': 'The Texas Chainsaw Massacre', 'year': 2003.0}
# {'title': 'Texas Chainsaw 3D', 'year': 2013.0}
# {'title': 'The Texas Chainsaw Massacre 2', 'year': 1986.0}
# {'title': 'The Texas Chainsaw Massacre: The Beginning', 'year': 2006.0}
# {'title': 'The Texas Chain Saw Massacre', 'year': 1974.0}
# {'title': 'Texas Chainsaw Massacre: The Next Generation', 'year': 1994.0}
# {'title': 'From Dusk Till Dawn 2: Texas Blood Money', 'year': 1999.0}
# {'title': 'Leatherface: Texas Chainsaw Massacre III', 'year': 1990.0}
# {'title': "Bill & Ted's Excellent Adventure", 'year': 1989.0}
# {'title': 'Happy, Texas', 'year': 1999.0}
# {'title': 'The Poseidon Adventure', 'year': 1972.0}
# {'title': "Pee-wee's Big Adventure", 'year': 1985.0}
# {'title': 'My Awkward Sexual Adventure', 'year': 2012.0}
# {'title': 'The Oogieloves in the Big Balloon Adventure', 'year': 2012.0}
# {'title': 'Caravan of Courage: An Ewok Adventure', 'year': 1984.0}
# {'title': 'Remo Williams: The Adventure Begins', 'year': 1985.0}
# {'title': 'Free Willy 2: The Adventure Home', 'year': 1995.0}
# {'title': 'Into the Wild', 'year': 2007.0}
# {'title': 'Arthur and the Great Adventure', 'year': 2009.0}
# {'title': 'Wild Hogs', 'year': 2007.0}
# {'title': 'Where the Wild Things Are', 'year': 2009.0}
# {'title': 'Wild', 'year': 2014.0}
# {'title': 'Wild Tales', 'year': 2014.0}
# {'title': 'The Wild Bunch', 'year': 1969.0}
# {'title': 'Beasts of the Southern Wild', 'year': 2012.0}
# {'title': 'Wild Things', 'year': 1998.0}
# {'title': 'Wild Strawberries', 'year': 1957.0}
# {'title': 'Above the Law', 'year': 1988.0}
# {'title': 'Down by Law', 'year': 1986.0}
# {'title': 'Son in Law', 'year': 1993.0}
# {'title': 'Law Abiding Citizen', 'year': 2009.0}
# {'title': 'Law of Desire', 'year': 1987.0}
# {'title': 'Beyond the Law', 'year': 1993.0}
# {'title': "Murphy's Law", 'year': 1986.0}
# {'title': "Herod's Law", 'year': 1999.0}
# {'title': 'Monster-in-Law', 'year': 2005.0}
# {'title': 'Homeward Bound: The Incredible Journey', 'year': 1993.0}
# {'title': 'Bound for Glory', 'year': 1976.0}
# {'title': 'Bound to Vengeance', 'year': 2015.0}
# {'title': 'Bound', 'year': 1996.0}
# {'title': 'Bound', 'year': 2015.0}
# {'title': "Logan's War: Bound by Honor", 'year': 1998.0}
# {'title': 'Bollywood Bound', 'year': 2003.0}
# {'title': 'A Ship Bound for India', 'year': 1947.0}
# {'title': 'Trouble Bound', 'year': 1993.0}
# {'title': 'Outside the Law', 'year': 2010.0}
# {'title': 'Storm Bound', 'year': 2007.0}
# {'title': 'Shutter Island', 'year': 2010.0}
# {'title': 'The Island', 'year': 2005.0}
# {'title': 'Journey 2: The Mysterious Island', 'year': 2012.0}
# {'title': "Nim's Island", 'year': 2008.0}
# {'title': 'Spy Kids 2: Island of Lost Dreams', 'year': 2002.0}
# {'title': 'The Island of Dr. Moreau', 'year': 1996.0}
# {'title': 'Cutthroat Island', 'year': 1995.0}
# {'title': 'City Island', 'year': 2009.0}
# {'title': 'Muppet Treasure Island', 'year': 1996.0}
# {'title': "King of Devil's Island", 'year': 2010.0}
# {'title': 'After Earth', 'year': 2013.0}
# {'title': 'The Day the Earth Stood Still', 'year': 2008.0}
# {'title': 'Like Stars on Earth', 'year': 2007.0}
# {'title': 'Journey to the Center of the Earth', 'year': 2008.0}
# {'title': 'Another Earth', 'year': 2011.0}
# {'title': 'Battlefield Earth', 'year': 2000.0}
# {'title': 'The Day the Earth Stood Still', 'year': 1951.0}
# {'title': 'The Man from Earth', 'year': 2007.0}
# {'title': 'Night on Earth', 'year': 1991.0}
# {'title': 'Escape from Planet Earth', 'year': 2013.0}
# {'title': 'Pretty Woman', 'year': 1990.0}
# {'title': 'Scent of a Woman', 'year': 1992.0}
# {'title': 'The Other Woman', 'year': 2014.0}
# {'title': 'Woman in Gold', 'year': 2015.0}
# {'title': 'The Woman in Black', 'year': 2012.0}
# {'title': 'When a Man Loves a Woman', 'year': 1994.0}
# {'title': 'The Woman in Black 2: Angel of Death', 'year': 2014.0}
# {'title': 'The Other Woman', 'year': 2009.0}
# {'title': 'The Woman', 'year': 2011.0}
# {'title': 'I Could Never Be Your Woman', 'year': 2007.0}
# {'title': 'Lost in Translation', 'year': 2003.0}
# {'title': 'Raiders of the Lost Ark', 'year': 1981.0}
# {'title': 'Home Alone 2: Lost in New York', 'year': 1992.0}
# {'title': 'Lost Highway', 'year': 1997.0}
# {'title': 'The Lost Boys', 'year': 1987.0}
# {'title': 'Atlantis: The Lost Empire', 'year': 2001.0}
# {'title': 'All Is Lost', 'year': 2013.0}
# {'title': 'The Lost World: Jurassic Park', 'year': 1997.0}
# {'title': 'The City of Lost Children', 'year': 1995.0}
# {'title': 'True Romance', 'year': 1993.0}
# {'title': 'Romance & Cigarettes', 'year': 2005.0}
# {'title': 'Romance', 'year': 1999.0}
# {'title': 'Office Romance', 'year': 1977.0}
# {'title': "Murphy's Romance", 'year': 1985.0}
# {'title': "Tillie's Punctured Romance", 'year': 1914.0}
# {'title': 'A Cruel Romance', 'year': 1984.0}
# {'title': 'Modern Romance', 'year': 1981.0}
# {'title': 'Guilty of Romance', 'year': 2011.0}
# {'title': 'The Little Mermaid', 'year': 1989.0}
# {'title': 'Little Miss Sunshine', 'year': 2006.0}
# {'title': 'Stuart Little', 'year': 1999.0}
# {'title': 'A Little Romance', 'year': 1979.0}
# {'title': 'Big Trouble in Little China', 'year': 1986.0}
# {'title': 'Little Fockers', 'year': 2010.0}
# {'title': 'Little Nicky', 'year': 2000.0}
# {'title': 'Little Women', 'year': 1994.0}
# {'title': 'Chicken Little', 'year': 2005.0}
# {'title': 'Stuart Little 2', 'year': 2002.0}
# {'title': 'Crazy Heart', 'year': 2009.0}
# {'title': 'Angel Heart', 'year': 1987.0}
# {'title': 'Little Shop of Horrors', 'year': 1986.0}
# {'title': 'Wild at Heart', 'year': 1990.0}
# {'title': 'Whisper of the Heart', 'year': 1995.0}
# {'title': 'I Heart Huckabees', 'year': 2004.0}
# {'title': 'A Mighty Heart', 'year': 2007.0}
# {'title': 'Where the Heart Is', 'year': 2000.0}
# {'title': 'The Normal Heart', 'year': 2014.0}
# {'title': 'Playing by Heart', 'year': 1998.0}
# {'title': 'The Beat That My Heart Skipped', 'year': 2005.0}
# {'title': 'The Big Lebowski', 'year': 1998.0}
# {'title': 'Big Fish', 'year': 2003.0}
# {'title': 'Big Hero 6', 'year': 2014.0}
# {'title': 'Big Daddy', 'year': 1999.0}
# {'title': 'My Big Fat Greek Wedding', 'year': 2002.0}
# {'title': "Big Momma's House", 'year': 2000.0}
# {'title': 'Big', 'year': 1988.0}
# {'title': 'The Big Sleep', 'year': 1946.0}
# {'title': 'In Time', 'year': 2011.0}
# {'title': 'Big Eyes', 'year': 2014.0}
# {'title': 'Prince of Persia: The Sands of Time', 'year': 2010.0}
# {'title': 'Once Upon a Time in America', 'year': 1984.0}
# {'title': 'Once Upon a Time in Mexico', 'year': 2003.0}
# {'title': 'Hot Tub Time Machine', 'year': 2010.0}
# {'title': 'A Time to Kill', 'year': 1996.0}
# {'title': "The Time Traveler's Wife", 'year': 2009.0}
# {'title': 'Lagaan: Once Upon a Time in India', 'year': 2001.0}
# {'title': 'Gone Girl', 'year': 2014.0}
# {'title': 'The Time Machine', 'year': 2002.0}
# {'title': 'The Girl with the Dragon Tattoo', 'year': 2011.0}
# {'title': 'The Girl with the Dragon Tattoo', 'year': 2009.0}
# {'title': 'The Girl Next Door', 'year': 2004.0}
# {'title': 'Girl, Interrupted', 'year': 1999.0}
# {'title': 'Lars and the Real Girl', 'year': 2007.0}
# {'title': 'The Other Boleyn Girl', 'year': 2008.0}
# {'title': 'The Girl Who Played with Fire', 'year': 2009.0}
# {'title': 'Terminator 2: Judgment Day', 'year': 1991.0}
# {'title': 'Girl with a Pearl Earring', 'year': 2003.0}
# {'title': 'My Girl', 'year': 1991.0}
# {'title': 'Groundhog Day', 'year': 1993.0}
# {'title': 'Independence Day', 'year': 1996.0}
# {'title': 'The Day After Tomorrow', 'year': 2004.0}
# {'title': 'Training Day', 'year': 2001.0}
# {'title': "Ferris Bueller's Day Off", 'year': 1986.0}
# {'title': 'Dog Day Afternoon', 'year': 1975.0}
# {'title': 'Die Another Day', 'year': 2002.0}
# {'title': 'World War Z', 'year': 2013.0}
# {'title': 'Knight and Day', 'year': 2010.0}
# {'title': 'Thor: The Dark World', 'year': 2013.0}
# {'title': 'Jurassic World', 'year': 2015.0}
# {'title': 'Scott Pilgrim vs. the World', 'year': 2010.0}
# {'title': 'Master and Commander: The Far Side of the World', 'year': 2003.0}
# {'title': 'The World Is Not Enough', 'year': 1999.0}
# {'title': "Wayne's World", 'year': 1992.0}
# {'title': 'A Good Day to Die Hard', 'year': 2013.0}
# {'title': 'Team America: World Police', 'year': 2004.0}
# {'title': '30 Days of Night', 'year': 2007.0}
# {'title': 'Date Night', 'year': 2010.0}
# {'title': 'Night at the Museum', 'year': 2006.0}
# {'title': 'Good Night, and Good Luck.', 'year': 2005.0}
# {'title': 'Ghost World', 'year': 2001.0}
# {'title': 'The Night of the Hunter', 'year': 1955.0}
# {'title': 'Fright Night', 'year': 2011.0}
# {'title': 'We Own the Night', 'year': 2007.0}
# {'title': 'Run All Night', 'year': 2015.0}
# {'title': 'Night at the Museum: Secret of the Tomb', 'year': 2014.0}
# {'title': 'Man of Steel', 'year': 2013.0}
# {'title': 'Iron Man', 'year': 2008.0}
# {'title': 'Iron Man 2', 'year': 2010.0}
# {'title': 'The Amazing Spider-Man', 'year': 2012.0}
# {'title': 'Spider-Man', 'year': 2002.0}
# {'title': 'Spider-Man 2', 'year': 2004.0}
# {'title': 'Rain Man', 'year': 1988.0}
# {'title': 'Spider-Man 3', 'year': 2007.0}
# {'title': 'Toy Story', 'year': 1995.0}
# {'title': 'Toy Story 3', 'year': 2010.0}
# {'title': 'The Amazing Spider-Man 2', 'year': 2014.0}
# {'title': 'Toy Story 2', 'year': 1999.0}
# {'title': 'Dodgeball: A True Underdog Story', 'year': 2004.0}
# {'title': 'A Christmas Story', 'year': 1983.0}
# {'title': "It's Kind of a Funny Story", 'year': 2010.0}
# {'title': 'Iron Man 3', 'year': 2013.0}
# {'title': 'Perfume: The Story of a Murderer', 'year': 2006.0}
# {'title': 'The NeverEnding Story', 'year': 1984.0}
# {'title': "It's a Wonderful Life", 'year': 1946.0}
# {'title': 'Life Is Beautiful', 'year': 1997.0}
# {'title': 'Life of Pi', 'year': 2012.0}
# {'title': 'Life of Brian', 'year': 1979.0}
# {'title': 'The Secret Life of Walter Mitty', 'year': 2013.0}
# {'title': "A Bug's Life", 'year': 1998.0}
# {'title': 'The Life Aquatic with Steve Zissou', 'year': 2004.0}
# {'title': 'The Straight Story', 'year': 1999.0}
# {'title': "A Bug's Life", 'year': 1998.0}
# {'title': "Mia Italida ap' tin Kypseli", 'year': 1968.0}
# {'title': 'The Tree of Life', 'year': 2011.0}
# {'title': "Gabros ap' to Londino", 'year': 1967.0}
# {'title': "Ap' ta kokala vgalmena", 'year': 2011.0}
# {'title': "Hooligans - Kato ta heria ap' ta niata!", 'year': 1983.0}
# {'title': 'Being AP', 'year': 2015.0}
# {'title': "Tora pou fevgo ap' ti zoi", 'year': 1966.0}
# {'title': "I gynaikara ap' to Kilkis", 'year': 1985.0}
# {'title': "To gelio vgike ap' ton Paradeiso", 'year': 1963.0}
# {'title': 'Lara Croft Tomb Raider: The Cradle of Life', 'year': 2003.0}
# {'title': "Pio thermi kai ap' ton ilio", 'year': 1972.0}
# {'title': 'AC/DC: Let There Be Rock', 'year': 1980.0}
# {'title': 'AC/DC: Family Jewels', 'year': 2005.0}
# {'title': 'AC/DC: No Bull', 'year': 1996.0}
# {'title': 'AC/DC: Live at Donington', 'year': 1992.0}
# {'title': 'AC/DC: Live at River Plate', 'year': 2011.0}
# {'title': 'AC/DC: Stiff Upper Lip Live', 'year': 2001.0}
# {'title': 'One Million AC/DC', 'year': 1969.0}
# {'title': 'Ap 2000', 'year': 2002.0}
# {'title': 'BG - Neveroyatni razkazi za edin savremenen bulgarin', 'year': 1996.0}
# {'title': 'AC/DC: Plug Me In', 'year': 2007.0}
# {'title': 'B.G. aru 19 sai no nikki agete yokkata', 'year': 1968.0}
# {'title': 'AC/DC: Highway to Hell - Classic Album Under Review', 'year': 2008.0}
# {'title': 'B.G. monogatari: nijusai no nikki', 'year': 1961.0}
# {'title': 'B.G. Roper Presents...', 'year': 1995.0}
# {'title': 'Incredible Blinking Machines Presents BG/B', 'year': 2008.0}
# {'title': 'AC/DC: Fly on the Wall', 'year': 1985.0}
# {'title': 'Blur: Rated BG', 'year': 2013.0}
# {'title': 'The Notorious B.G.: A Forum with Bill Gates', 'year': 2005.0}
# {'title': 'B.D. in the mountains and on the seaside', 'year': 1971.0}
# {'title': 'B.D. in alert', 'year': 1971.0}
# {'title': 'B.D. în alerta - Vaduve cu termen redus', 'year': 1971.0}
# {'title': 'B.D. în alerta - Profesorul de mimica', 'year': 1970.0}
# {'title': 'B.D. Women', 'year': 1994.0}
# {'title': "BG's Dirty 30: Cruise to Ensenada", 'year': 2015.0}
# {'title': 'The Unknown Celebrities: B.D. Benedikt', 'year': 2001.0}
# {'title': 'B.D.', 'year': 2004.0}
# {'title': 'bd: Snowboad Rulerz', 'year': 2006.0}
# {'title': 'Bi pooli', 'year': 2009.0}
# {'title': 'Bikhod & Bi Jahat', 'year': 2012.0}
# {'title': 'Xiao Bi de gu shi', 'year': 1983.0}
# {'title': 'Fu gui bi ren', 'year': 1987.0}
# {'title': "Bi, Don't Be Afraid", 'year': 2010.0}
# {'title': 'O-Bi, O-Ba - The End of Civilization', 'year': 1985.0}
# {'title': 'Bi the Way', 'year': 2008.0}
# {'title': 'Il Bi e il Ba', 'year': 1986.0}
# {'title': 'Ci chu yu bi chu', 'year': 2012.0}
# {'title': 'La bi xiao xiao sheng', 'year': 1995.0}
# {'title': 'Ab Tak Chhappan', 'year': 2004.0}
# {'title': 'Ab-normal Beauty', 'year': 2004.0}
# {'title': 'Aa Ab Laut Chalen', 'year': 1999.0}
# {'title': 'Ab Ke Baras', 'year': 2002.0}
# {'title': 'Ab Tumhare Hawale Watan Saathiyo', 'year': 2004.0}
# {'title': 'Ab Tak Chhappan 2', 'year': 2015.0}
# {'title': 'Faryad-e zir-e ab', 'year': 1977.0}
# {'title': 'Fink fährt ab', 'year': 1999.0}
# {'title': 'Peter schießt den Vogel ab', 'year': 1959.0}
# {'title': 'Hotter Than July Bk', 'year': 2008.0}
# {'title': 'Die Post geht ab', 'year': 1962.0}
# {'title': 'BK 2 LA', 'year': 2015.0}
# {'title': 'Ao: The Last Hunter', 'year': 2010.0}
# {'title': 'S.O.S.: Mulheres ao Mar', 'year': 2014.0}
# {'title': 'Assalto ao Santa Maria', 'year': 2010.0}
# {'title': 'S.O.S.: Mulheres ao Mar 2', 'year': 2015.0}
# {'title': 'Ao oni', 'year': 2014.0}
# {'title': 'O Convite ao Prazer', 'year': 1980.0}
# {'title': 'Ao qi xiong ying', 'year': 1989.0}
# {'title': 'Shou zhi ao chu', 'year': 1981.0}
# {'title': 'Fei hu xiong xin 2 zhi ao qi bi tian gao', 'year': 1996.0}
# {'title': 'Adeus Até ao Meu Regresso: Soldados do Império', 'year': 2007.0}
# {'title': 'Dv', 'year': 2013.0}
# {'title': 'Broken: How to Make DV Look Like Film', 'year': 2005.0}
# {'title': 'DV Guide', 'year': 2012.0}
# {'title': 'Dv-Campitelli', 'year': 2002.0}
# {'title': 'D.V.', 'year': 2004.0}
# {'title': 'Heft in BH', 'year': 2001.0}
# {'title': 'Gahee & B.H.', 'year': 2006.0}
# {'title': 'BH eurosong', 'year': 2005.0}
# {'title': 'DV: Domestic Violence', 'year': 2005.0}
# {'title': 'SX80 bh', 'year': 2006.0}
# {'title': 'BL.A.CK', 'year': 2011.0}
# {'title': 'BM.F', 'year': 2015.0}
# {'title': 'Ef', 'year': 2014.0}
# {'title': 'Killa-EF', 'year': 2010.0}
# {'title': 'Ulf & EF', 'year': 1993.0}
# {'title': 'Sånt är livet', 'year': 1996.0}
# {'title': 'Pettson & Findus - Katten och gubbens år', 'year': 1999.0}
# {'title': 'Jag är med barn', 'year': 1979.0}
# {'title': 'Ranjana Ami Ar Ashbona', 'year': 2011.0}
# {'title': 'Själen är större än världen', 'year': 1985.0}
# {'title': 'Nu är pappa trött igen!', 'year': 1996.0}
# {'title': 'Vem är du?', 'year': 2005.0}
# {'title': 'Jag är inte beredd att dö än', 'year': 2014.0}
# {'title': 'Mitt hem är Copacabana', 'year': 1965.0}
# {'title': 'D.W. Griffith and Lillian Gish', 'year': 2001.0}
# {'title': 'Maria Wern: Först när givaren är död', 'year': 2013.0}
# {'title': 'D.W. Griffith et le loup', 'year': 2011.0}
# {'title': 'D.W. Griffith', 'year': 1975.0}
# {'title': 'The 1986 Annual D.W. Griffith Awards', 'year': 1986.0}
# {'title': 'The Return of E.C. Gonatas', 'year': 2012.0}
# {'title': 'Reverse Plantation, an E.C. Skit', 'year': 2015.0}
# {'title': 'E.A. 2', 'year': 2002.0}
# {'title': 'Hoe zotter hoe liever, het succes van de Vlaamse volksfilms van Edith Kiel e.a. van 1930-1960', 'year': 2004.0}
# {'title': "Naked Love: Ea's Garden", 'year': 2012.0}
# {'title': 'Dupa ea', 'year': 2007.0}
# {'title': 'Megafactories: EA Sports', 'year': 2011.0}
# {'title': 'EA in Silicon Valley', 'year': 2015.0}
# {'title': 'Ea la mio neña, ea', 'year': 2013.0}
# {'title': 'Ea Sola - Sécheresse et pluie', 'year': 1999.0}
# {'title': "E.A. Poe's Berenice", 'year': 2012.0}
# {'title': '2005 EA Sports NFL Quarterback Challenge', 'year': 2005.0}
# {'title': 'Sigur Rós: Ég anda', 'year': 2012.0}
# {'title': 'Ég elska þig', 'year': 2009.0}
# {'title': 'Ég mundi segja hó', 'year': 1982.0}
# {'title': 'Ég er ekki nógu gott landslag', 'year': 2011.0}
# {'title': 'Det er eg!', 'year': 2005.0}
# {'title': 'Az ég kék éve', 'year': 1988.0}
# {'title': 'Ég Anda', 'year': 2012.0}
# {'title': 'Ég Man Þig', 'year': 2016.0}
# {'title': 'Ahol az ég is meghajlik...', 'year': 1994.0}
# {'title': 'Ég és föld között', 'year': 1961.0}
# {'title': 'Eb & Flo', 'year': 1998.0}
# {'title': 'The Buffalo Chips: Gimme an Eb Minor', 'year': 2011.0}
# {'title': 'The Land of Eb', 'year': 2012.0}
# {'title': 'Eb & Flo', 'year': 1994.0}
# {'title': 'Eb', 'year': 2009.0}
# {'title': "B.F.'s Daughter", 'year': 1948.0}
# {'title': 'Mr. B.F. Keith', 'year': 1898.0}
# {'title': "B.F. Keith's New Million Dollar Theatre", 'year': 1902.0}
# {'title': 'Road EB 01', 'year': 2013.0}
# {'title': "BF's Forever", 'year': 2014.0}
# {'title': 'BF Nowhere', 'year': 2013.0}
# {'title': 'EP-X-503', 'year': 1962.0}
# {'title': 'The Committee Ep 1: Bad Dog', 'year': 2010.0}
# {'title': 'Gamechangers Ep. 3: A Legend in the Booth', 'year': 2010.0}
# {'title': 'Gamechangers Ep. 1: The Rant Writer', 'year': 2010.0}
# {'title': 'Cleve Dixon Ep 2: The Downtown Breakdown', 'year': 2012.0}
# {'title': 'Asian Conan Ep. 1', 'year': 2010.0}
# {'title': 'My Best Friend Bigfoot Ep.1 & 2.', 'year': 2010.0}
# {'title': 'Gamechangers Ep. 2: Fear the NFL Draft', 'year': 2010.0}
# {'title': 'Nathan Grant: Ghost Detective Ep. 7', 'year': 2010.0}
# {'title': 'EP: Side 2', 'year': 2006.0}
# {'title': 'Captain EO', 'year': 1986.0}
# {'title': 'Captain Eo Grand Opening', 'year': 1986.0}
# {'title': 'Captain EO Promo & Pre-show', 'year': 1986.0}
# {'title': 'Hi-eo-ro', 'year': 2010.0}
# {'title': 'Enchantress Eo-eul', 'year': 1987.0}
# {'title': 'Mul eo on doh', 'year': 2011.0}
# {'title': 'Eo', 'year': 2013.0}
# {'title': 'EO Bubble Buddy', 'year': 2013.0}
# {'title': 'Lost Flower Eo Woo-dong', 'year': 2015.0}
# {'title': "The Making of 'Captain Eo'", 'year': 1986.0}
# {'title': 'Immortal (Ad Vitam)', 'year': 2004.0}
# {'title': 'Dracula A.D. 1972', 'year': 1972.0}
# {'title': "Daleks' Invasion Earth 2150 A.D.", 'year': 1966.0}
# {'title': 'Babylon A.D.', 'year': 2008.0}
# {'title': 'Ad Fundum', 'year': 1993.0}
# {'title': "L'assassino è costretto ad uccidere ancora", 'year': 1975.0}
# {'title': '2000 AD', 'year': 2000.0}
# {'title': 'AD/BC: A Rock Opera', 'year': 2004.0}
# {'title': '681 AD: The Glory of Khan', 'year': 1981.0}
# {'title': 'WWE: The New & Improved DX', 'year': 2007.0}
# {'title': 'WWE: DX: One Last Stand', 'year': 2011.0}
# {'title': 'Eiga Purikyua ôru sutâzu DX 2: Kibou no hikari Reinbô jueru o mamore!', 'year': 2010.0}
# {'title': 'Precure Allstars DX', 'year': 2009.0}
# {'title': 'A.D. Police Files', 'year': 1990.0}
# {'title': 'Eiga Purikyua ôru sutâzu DX 3: Mirai ni todoke! Sekai o tsunagu nijiiro no hana', 'year': 2011.0}
# {'title': 'Swallowed Land DX', 'year': 2006.0}
# {'title': 'Jitsuroku! Real kyoufu DX', 'year': 2009.0}
# {'title': 'Dorîmu ûman x zâmen suiken DX 5', 'year': 2004.0}
# {'title': 'df/dx', 'year': 2007.0}
# {'title': 'The Best of BJ Thomas Live', 'year': 2005.0}
# {'title': 'UFC 107: BJ Penn vs. Diego Sanchez', 'year': 2009.0}
# {'title': 'Pia Carrot e Yokoso! 2 DX', 'year': 1999.0}
# {'title': 'Yokohama BJ Blues', 'year': 1981.0}
# {'title': 'B.J.: Black Jocks', 'year': 2000.0}
# {'title': 'BJ Babes', 'year': 2006.0}
# {'title': 'BJ Babes 2', 'year': 2008.0}
# {'title': 'BJ', 'year': 2012.0}
# {'title': 'BJ Thomas: That Christmas Feeling', 'year': 2005.0}
# {'title': 'BJ Becky', 'year': 1998.0}
# {'title': 'The Ran(dy)som for Eva', 'year': 1985.0}
# {'title': 'Dy herë mat', 'year': 1986.0}
# {'title': 'L.A.dy Dior', 'year': 2011.0}
# {'title': 'Dy gosti', 'year': 1982.0}
# {'title': 'Bj', 'year': 2013.0}
# {'title': 'Ar-khi-me-dy!', 'year': 1975.0}
# {'title': 'Dhimbje midis dy brigjeve', 'year': 1980.0}
# {'title': 'Dy endjet', 'year': 1973.0}
# {'title': 'Pranvera dy hapa pranë', 'year': 1984.0}
# {'title': 'Ne kufi te dy legjendave', 'year': 1982.0}
# {'title': 'Dy-nasty', 'year': 1988.0}
# {'title': 'Rang De Basanti', 'year': 2006.0}
# {'title': 'Casa de mi Padre', 'year': 2012.0}
# {'title': 'Cyrano de Bergerac', 'year': 1990.0}
# {'title': 'Belle de Jour', 'year': 1967.0}
# {'title': 'Jean de Florette', 'year': 1986.0}
# {'title': 'Café de Flore', 'year': 2011.0}
# {'title': 'Torrente, el brazo tonto de la ley', 'year': 1998.0}
# {'title': 'De-Lovely', 'year': 2004.0}
# {'title': 'The Earrings of Madame de...', 'year': 1953.0}
# {'title': 'Cul-De-Sac', 'year': 1966.0}
# {'title': 'Ek Tha Tiger', 'year': 2012.0}
# {'title': 'Ek Villain', 'year': 2014.0}
# {'title': 'Ek Hasina Thi', 'year': 2004.0}
# {'title': 'Ek Thi Daayan', 'year': 2013.0}
# {'title': 'Gadar: Ek Prem Katha', 'year': 2001.0}
# {'title': 'Ek Main Aur Ekk Tu', 'year': 2012.0}
# {'title': 'Ek Chalis Ki Last Local', 'year': 2007.0}
# {'title': 'Jaani Dushman: Ek Anokhi Kahani', 'year': 2002.0}
# {'title': 'Ek Ajnabee', 'year': 2005.0}
# {'title': 'Ek Aur Ek Gyarah: By Hook or by Crook', 'year': 2003.0}
# {'title': 'Gay Purr-ee', 'year': 1962.0}
# {'title': 'Ee Parakkum Thalika', 'year': 2001.0}
# {'title': 'Ee Adutha Kaalath', 'year': 2012.0}
# {'title': 'Ee Pattanathil Bhootham', 'year': 2009.0}
# {'title': 'Ee Thanutha Veluppan Kalathu', 'year': 1990.0}
# {'title': 'Ee Rojullo', 'year': 2012.0}
# {'title': 'Ormayundo Ee Mukham', 'year': 2014.0}
# {'title': 'Ee Puzhayum Kadannu', 'year': 1996.0}
# {'title': 'The EE British Academy Film Awards', 'year': 2015.0}
# {'title': 'Yemaindi Ee Vela', 'year': 2010.0}
# {'title': 'B.B. and the Cormorant', 'year': 2003.0}
# {'title': 'B.B. King: The Life of Riley', 'year': 2012.0}
# {'title': 'Live by Request: BB King', 'year': 2003.0}
# {'title': 'B.B. King: Into the Night', 'year': 1985.0}
# {'title': 'The Jazz Channel Presents B.B. King', 'year': 2000.0}
# {'title': 'B.B. King: The Life of Riley', 'year': 2012.0}
# {'title': 'Mardi Gras.BB: A Silent Rockumentary', 'year': 2012.0}
# {'title': 'B.B. King: The Blues Summit', 'year': 1995.0}
# {'title': 'B.B. King: Live', 'year': 2011.0}
# {'title': 'Ed', 'year': 1996.0}
# {'title': 'Evil Ed', 'year': 1995.0}
# {'title': 'Ed Wood', 'year': 1994.0}
# {'title': 'Ed Gein: The Butcher of Plainfield', 'year': 2007.0}
# {'title': 'Totally F***ed Up', 'year': 1993.0}
# {'title': 'Ed Gein', 'year': 2000.0}
# {'title': 'BB Gun', 'year': 2001.0}
# {'title': 'Ed and His Dead Mother', 'year': 1993.0}
# {'title': 'Sex Ed', 'year': 2014.0}
# {'title': "Ed, Edd n Eddy's Big Picture Show", 'year': 2009.0}
# {'title': 'Rubin and Ed', 'year': 1991.0}
# {'title': 'As Good as It Gets', 'year': 1997.0}
# {'title': 'Life as a House', 'year': 2001.0}
# {'title': 'Life as We Know It', 'year': 2010.0}
# {'title': 'Thick as Thieves', 'year': 2009.0}
# {'title': 'As Above, So Below', 'year': 2014.0}
# {'title': 'My Life as a Dog', 'year': 1985.0}
# {'title': 'As It Is in Heaven', 'year': 2004.0}
# {'title': 'Cool as Ice', 'year': 1991.0}
# {'title': 'As Tears Go By', 'year': 1988.0}
# {'title': 'Come as You Are', 'year': 2011.0}
# {'title': 'Ev', 'year': 2010.0}
# {'title': 'Az 1812-es év', 'year': 1973.0}
# {'title': 'Kiralik ev', 'year': 1986.0}
# {'title': 'No EV Trouble in Little China', 'year': 2011.0}
# {'title': 'Küçük ev', 'year': 1977.0}
# {'title': 'Expediente EV-0043', 'year': 2009.0}
# {'title': 'Talada ev', 'year': 1986.0}
# {'title': 'Basketball Wives: Temper Tantrums w/ Ev', 'year': 2012.0}
# {'title': 'Egy éj Velencében', 'year': 1934.0}
# {'title': 'Csendes éj', 'year': 2006.0}
# {'title': 'The Story of Father Ev', 'year': 2012.0}
# {'title': 'Ev hali', 'year': 2002.0}
# {'title': "EJ's Awesome Recovery", 'year': 2011.0}
# {'title': 'Captain E.J. Smith, R.N.R. Commander of the Ill Fated S.S. Titanic: A Final Inspection of His Vessel Ten Minutes Before Sailing Time', 'year': 1912.0}
# {'title': 'Ej blot til lyst', 'year': 2006.0}
# {'title': 'Egy éj at Arany Bogárban', 'year': 1992.0}
# {'title': 'Strawberry Schmilsson Forever - A Videopainting by E.J. Gold', 'year': 1994.0}
# {'title': 'Behöriga äga ej tillträde', 'year': 1988.0}
# {'title': 'Lek ej med kärleken', 'year': 1961.0}
# {'title': 'The Hi-Lo Country', 'year': 1998.0}
# {'title': 'O Dia D E.J. Carvalho', 'year': 2012.0}
# {'title': 'Lo', 'year': 2009.0}
# {'title': 'Rok Sako To Rok Lo', 'year': 2004.0}
# {'title': 'Isi/Disi - Amor a lo bestia', 'year': 2004.0}
# {'title': 'Il commissario Lo Gatto', 'year': 1986.0}
# {'title': 'Manny & Lo', 'year': 1996.0}
# {'title': 'Lo contrario al amor', 'year': 2011.0}
# {'title': 'Il trucido e lo sbirro', 'year': 1976.0}
# {'title': 'Todo lo que tú quieras', 'year': 2010.0}
# {'title': 'No lo llames amor... llámalo X', 'year': 2011.0}
# {'title': 'Eu Te Amo', 'year': 1981.0}
# {'title': 'Os Homens São de Marte... E é pra Lá que Eu Vou!', 'year': 2014.0}
# {'title': 'Eu', 'year': 1987.0}
# {'title': "Tout le monde n'a pas eu la chance d'avoir des parents communistes", 'year': 1993.0}
# {'title': 'Les demoiselles ont eu 25 ans', 'year': 1993.0}
# {'title': 'Eu sunt Adam!', 'year': 1996.0}
# {'title': 'Com Licença, Eu Vou à Luta', 'year': 1986.0}
# {'title': 'Que Farei eu com Esta Espada?', 'year': 1975.0}
# {'title': 'Eu Matei Lúcio Flávio', 'year': 1979.0}
# {'title': 'Hut Nr. E.W. 2106 V', 'year': 1915.0}
# {'title': "The Artist's Studio: E.W. NAY", 'year': 2012.0}
# {'title': 'In Search of Myster Ey', 'year': 2008.0}
# {'title': 'Eu Não Faço a Menor Ideia do Que Eu Tô Fazendo Com a Minha Vida', 'year': 2012.0}
# {'title': 'Ey Pari Kojai', 'year': 2011.0}
# {'title': 'Ey, na linkore!', 'year': 1985.0}
# {'title': 'Ey!', 'year': 1981.0}
# {'title': 'Journ(ey)ées aux pays des percussions', 'year': 2000.0}
# {'title': 'Ya ey nravlyus', 'year': 1985.0}
# {'title': 'Pra/ey: A Vampire Film Short by Lia Scott Price', 'year': 2012.0}
# {'title': 'Ey, kto nibud!', 'year': 1963.0}
# {'title': 'El/Ey', 'year': 2014.0}
# {'title': 'Pig-Hoo-o-o-o-ey', 'year': 1954.0}
# {'title': "JB Smoove: That's How I Dooz It", 'year': 2012.0}
# {'title': '1940: A Reminiscence by J.B. Priestly', 'year': 1965.0}
# {'title': 'Pour J.B.', 'year': 2001.0}
# {'title': 'J.C. Chávez', 'year': 2007.0}
# {'title': 'JB & the Mule', 'year': 2015.0}
# {'title': 'H20 Secrets: J.B. King', 'year': 2009.0}
# {'title': 'The Passing of J.B. Randall and Company', 'year': 1912.0}
# {'title': 'RTL voetbal: KNVB Beker finale Feyenoord - Roda JC', 'year': 2008.0}
# {'title': 'JC in tha Hood', 'year': 2008.0}
# {'title': 'J.C.', 'year': 1972.0}
# {'title': 'J.C. Leyendecker: The Great American Illustrator', 'year': 2000.0}
# {'title': 'J.C.', 'year': 2001.0}
# {'title': 'J.C.', 'year': 2010.0}
# {'title': 'Community Builder: The Life & Legacy of J.C. Nichols', 'year': 2006.0}
# {'title': 'J.F. Que?', 'year': 2004.0}
# {'title': "JF's Diary of a Mulatto Bride", 'year': 2012.0}
# {'title': 'J.C.', 'year': 2000.0}
# {'title': 'J.F. Willumsen', 'year': 1951.0}
# {'title': 'J.F. Willems', 'year': 1976.0}
# {'title': 'Rech JF: pour court-métrage rémunéré', 'year': 2009.0}
# {'title': 'Jo', 'year': 1971.0}
# {'title': 'Jo Jo Dancer, Your Life Is Calling', 'year': 1986.0}
# {'title': 'New Meet Me on South Street: The Story of JC Dobbs', 'year': 2011.0}
# {'title': 'Har Dil Jo Pyar Karega...', 'year': 2000.0}
# {'title': 'Jo Jeeta Wohi Sikandar', 'year': 1992.0}
# {'title': 'The Ballad of Little Jo', 'year': 1993.0}
# {'title': 'Jo Bole So Nihaal', 'year': 2005.0}
# {'title': 'Bobbie Jo and the Outlaw', 'year': 1976.0}
# {'title': 'Marie-Jo and Her 2 Lovers', 'year': 2002.0}
# {'title': 'Ashura-jô no hitomi', 'year': 2005.0}
# {'title': 'Dil Jo Bhi Kahey...', 'year': 2005.0}
# {'title': 'JP is My Friend', 'year': 2013.0}
# {'title': 'J.P. Hopfelt: My Kind of Free', 'year': 2014.0}
# {'title': 'Balázs (18) filmje - jp.co.de', 'year': 2012.0}
# {'title': 'JP Medical', 'year': 2011.0}
# {'title': 'J.P. Love in Berlin', 'year': 2007.0}
# {'title': 'JP Rawson', 'year': 2006.0}
# {'title': 'J.P.', 'year': 1988.0}
# {'title': 'The Death of J.P. Cuenca', 'year': 2015.0}
# {'title': "The Duke: Based on the Memoir 'I'm the Duke' by J.P. Duke", 'year': 2016.0}
# {'title': 'Varg Veum - I mørket er alle ulver grå', 'year': 2011.0}
# {'title': 'Hjelp, vi er i filmbransjen', 'year': 2011.0}
# {'title': 'Er kanns nicht lassen', 'year': 1962.0}
# {'title': 'ATM: Er Rak Error', 'year': 2012.0}
# {'title': 'Ma 6-T va crack-er', 'year': 1997.0}
# {'title': 'Baghdad ER', 'year': 2006.0}
# {'title': 'Salige er de som tørster', 'year': 1997.0}
# {'title': 'Skulle det dukke opp flere lik, er det bare å ringe...', 'year': 1970.0}
# {'title': 'Jin ping mei er ai de nu li', 'year': 2009.0}
# {'title': 'Hjelp, vi er russ', 'year': 2011.0}
# {'title': 'Full Circle: Malcolm Smith and J.N. Roberts - The Legend Lives On', 'year': 2007.0}
# {'title': 'KD Matheson Boundless Tribesman', 'year': 2009.0}
# {'title': 'KD No. 1', 'year': 1978.0}
# {'title': 'Live by Request: K.D. Lang', 'year': 2000.0}
# {'title': "K.D. Lang Talks with Percy Adlon About 'Percy Adlon's Salmonberries': 11 Years Later", 'year': 2001.0}
# {'title': 'K.D. Lang: Miss Chatelaine', 'year': 1992.0}
# {'title': 'Ju-on: The Grudge', 'year': 2002.0}
# {'title': 'Ju-On: The Grudge 2', 'year': 2003.0}
# {'title': 'Ju-on: The Curse 2', 'year': 2000.0}
# {'title': 'The Story of Qiu Ju', 'year': 1992.0}
# {'title': 'Ju Dou', 'year': 1990.0}
# {'title': 'Ju-on: The Curse', 'year': 2000.0}
# {'title': 'Ju-on: White Ghost', 'year': 2009.0}
# {'title': 'Han Gong-ju', 'year': 2013.0}
# {'title': "Shoot 'Em Up", 'year': 2007.0}
# {'title': "Ax 'Em", 'year': 1992.0}
# {'title': 'Ju-on: Black Ghost', 'year': 2009.0}
# {'title': "Give 'em Hell Malone", 'year': 2009.0}
# {'title': "Hang 'Em High", 'year': 1968.0}
# {'title': 'Ju-on: The Beginning of the End', 'year': 2014.0}
# {'title': "Class of Nuke 'Em High", 'year': 1986.0}
# {'title': "Class of Nuke 'Em High Part II: Subhumanoid Meltdown", 'year': 1991.0}
# {'title': "Keep 'Em Flying", 'year': 1941.0}
# {'title': "Kill 'em All", 'year': 2012.0}
# {'title': 'Jy is My Liefling', 'year': 1968.0}
# {'title': 'KJ: Music and Life', 'year': 2009.0}
# {'title': 'As Jy Sing', 'year': 2013.0}
# {'title': "Return to Nuke 'Em High Volume 1", 'year': 2013.0}
# {'title': 'Ngo ga yau yat chek hiu dung see', 'year': 2002.0}
# {'title': 'DJ KJ the First Hit', 'year': 2010.0}
# {'title': 'Gamma Labs Presents KJ Noons', 'year': 2013.0}
# {'title': "Jy's Lieflik Vanaand", 'year': 1962.0}
# {'title': '72 ga cho hak', 'year': 2010.0}
# {'title': 'Subete ga kurutteru', 'year': 1960.0}
# {'title': 'Ga, Ga - Chwala bohaterom', 'year': 1986.0}
# {'title': 'Jy is Myne', 'year': 2011.0}
# {'title': 'Daai foo ji ga', 'year': 1994.0}
# {'title': 'Amin Jensen - 150 kg over bæltestedet', 'year': 2003.0}
# {'title': 'Bong ga', 'year': 2007.0}
# {'title': 'A Portrait of Ga', 'year': 1952.0}
# {'title': 'Athens, Ga. - Inside/Out', 'year': 1987.0}
# {'title': 'Wat Jy Saai', 'year': 1979.0}
# {'title': 'The Hated K.P.', 'year': 1919.0}
# {'title': 'Yasha-ga-ike', 'year': 1979.0}
# {'title': '1.150 kg', 'year': 2003.0}
# {'title': 'Ørkenens sønner - Gå aldrig tilbage til en fuser!', 'year': 1997.0}
# {'title': 'Not Less Than 50 Kg', 'year': 2013.0}
# {'title': '18 kg', 'year': 2012.0}
# {'title': 'Josser, KC', 'year': 1929.0}
# {'title': 'Le disgrazie di un 100 Kg', 'year': 1911.0}
# {'title': '3 Kg', 'year': 2010.0}
# {'title': 'All About Me KG', 'year': 2014.0}
# {'title': 'Taste of KC Williams', 'year': 1992.0}
# {'title': 'NV in KC: A Story About Artists and Envy in Kansas City', 'year': 2013.0}
# {'title': 'Mrs. K.C. of England', 'year': 2000.0}
# {'title': 'The KC Challenge', 'year': 2012.0}
# {'title': 'Star Cuts 66: K.C. Valentine', 'year': 1987.0}
# {'title': 'K.C.', 'year': 2010.0}
# {'title': '2 Live Crew Feat. KC of KC & the Sunshine Band and Freak Nasty: 2 Live Party', 'year': 1998.0}
# {'title': 'Ko', 'year': 2011.0}
# {'title': 'Albert Pinto Ko Gussa Kyon Ata Hai', 'year': 1980.0}
# {'title': 'Private Times Video 485: Santa Fey & KC', 'year': 2004.0}
# {'title': 'Hachi-ko', 'year': 1987.0}
# {'title': "Ko-Ko's Earth Control", 'year': 1928.0}
# {'title': 'A Two Word Name with the Letters Kh and K', 'year': 2014.0}
# {'title': 'Bounce Ko Gals', 'year': 1997.0}
# {'title': 'Project A-Ko', 'year': 1986.0}
# {'title': 'Project A-Ko 2: Daitokuji zaibatsu no inbô', 'year': 1987.0}
# {'title': 'Project A-Ko Versus Battle 2: Blue Side', 'year': 1990.0}
# {'title': 'Project A-Ko 3: Cinderella Rhapsody', 'year': 1988.0}
# {'title': 'Sunlight Jr.', 'year': 2013.0}
# {'title': 'Dr. Josser, K.C.', 'year': 1931.0}
# {'title': 'Project A-Ko Versus Battle 1: Grey Side', 'year': 1990.0}
# {'title': 'Sherlock Jr.', 'year': 1924.0}
# {'title': 'Ace Ventura: Pet Detective Jr.', 'year': 2009.0}
# {'title': 'Santa, Jr.', 'year': 2002.0}
# {'title': 'Luxo Jr.', 'year': 1986.0}
# {'title': 'Mr. Death: The Rise and Fall of Fred A. Leuchter, Jr.', 'year': 1999.0}
# {'title': "Luxo Jr. in 'Surprise' and 'Light & Heavy'", 'year': 1991.0}
# {'title': 'Évocateur: The Morton Downey Jr. Movie', 'year': 2012.0}
# {'title': 'Treacle Jr.', 'year': 2010.0}
# {'title': 'Dallas: J.R. Returns', 'year': 1996.0}
# {'title': 'J.J. Biker', 'year': 2001.0}
# {'title': 'To Tulsa and Back: On Tour with J.J. Cale', 'year': 2005.0}
# {'title': 'Untitled Seth Ott/J.J. Project', 'year': 2015.0}
# {'title': 'A Tribute to J.J. Abrams', 'year': 2013.0}
# {'title': 'JJ Star... How Embarrassing', 'year': 2012.0}
# {'title': 'The JJ Project', 'year': 2015.0}
# {'title': 'Cowboys and Indians: The J.J. Harper Story', 'year': 2003.0}
# {'title': 'Untitled J.J. Abrams/Chris Alender Sci-Fi Project', 'year': 2016.0}
# {'title': "J.J. Redick's Guide to the Perfect March Madness Bracket", 'year': 2014.0}
# {'title': 'Eric Clapton & Friends: The Breeze - An Appreciation of JJ Cale', 'year': 2014.0}
# {'title': "L.L. M.M. le Tsar et la Tsarine entrant dans l'église de l'Assomption [Moscou]", 'year': 1896.0}
# {'title': 'Départ en gondole de LL. MM.', 'year': 1898.0}
# {'title': "LL Cool J's Mama Said Home Security Service", 'year': 2012.0}
# {'title': 'Hubert Selby Jr: It/ll Be Better Tomorrow', 'year': 2005.0}
# {'title': 'Cortège de gymnastique devant LL. MM.', 'year': 1899.0}
# {'title': "Monza, L.L. M.M. le Roi et la Reine d'Italie", 'year': 1896.0}
# {'title': "Incontro delle ll.mm. il re d'Italia e gli imperiali di Germania a Venezia splendida", 'year': 1908.0}
# {'title': 'L.M. Beat', 'year': 1969.0}
# {'title': "Nikki Rich & LL Cool J's Simone I Smith: Charitable Cancer Fundraiser", 'year': 2011.0}
# {'title': 'c o ll e g e t o w n', 'year': 2015.0}
# {'title': 'Elf ll', 'year': 2016.0}
# {'title': '100 Million BC', 'year': 2008.0}
# {'title': 'Josh Kirby... Time Warrior: Chapter 4, Eggs from 70 Million B.C.', 'year': 1995.0}
# {'title': 'One Million Years B.C.', 'year': 1966.0}
# {'title': 'One Million B.C.', 'year': 1940.0}
# {'title': '10,000 BC', 'year': 2008.0}
# {'title': 'LP Into the Wild Live at Eastwest Studios', 'year': 2012.0}
# {'title': 'Journey to 10,000 BC', 'year': 2008.0}
# {'title': 'R.F.D. 10,000 B.C.', 'year': 1916.0}
# {'title': 'Lp', 'year': 2015.0}
# {'title': 'Bimbos B.C.', 'year': 1990.0}
# {'title': 'B.C. Rock', 'year': 1980.0}
# {'title': 'Big Daddy Dad: Ride the Bus LP', 'year': 2015.0}
# {'title': 'Taboo: The Single and the LP', 'year': 1980.0}
# {'title': 'David LP: Rocky Balboa', 'year': 2013.0}
# {'title': 'La Casa: LP', 'year': 2014.0}
# {'title': 'Taboo: The Single and the LP', 'year': 1980.0}
# {'title': 'Catch LJ Live!', 'year': 2013.0}
# {'title': 'Lj - Ubiti', 'year': 1976.0}
# {'title': 'LJ BeachPad', 'year': 1996.0}
# {'title': 'L.J. Waters', 'year': 2007.0}
# {'title': 'My Way ... My Life Lp', 'year': 2015.0}
# {'title': 'Kenny Plays with LJ', 'year': 2013.0}
# {'title': 'Amanece, que no es poco', 'year': 1989.0}
# {'title': '9 és 1/2 randi', 'year': 2008.0}
# {'title': 'Es ist nicht leicht ein Gott zu sein', 'year': 1989.0}
# {'title': "Comme t'y es belle!", 'year': 2006.0}
# {'title': 'Pyaar Ka Punchnama', 'year': 2011.0}
# {'title': 'La ciudad no es para mí', 'year': 1966.0}
# {'title': 'Todo es mentira', 'year': 1994.0}
# {'title': 'Perder es cuestión de método', 'year': 2004.0}
# {'title': 'Malena es un nombre de tango', 'year': 1996.0}
# {'title': 'Tod den Hippies!! Es lebe der Punk!', 'year': 2015.0}
# {'title': 'Pyaar Ka Punchnama 2', 'year': 2015.0}
# {'title': 'El mundo es nuestro', 'year': 2012.0}
# {'title': 'Matru ki Bijlee ka Mandola', 'year': 2013.0}
# {'title': 'Muqaddar Ka Sikandar', 'year': 1978.0}
# {'title': 'One 2 Ka 4', 'year': 2001.0}
# {'title': 'Khiladiyon Ka Khiladi', 'year': 1996.0}
# {'title': 'Joru Ka Ghulam', 'year': 2000.0}
# {'title': 'MJ Dong', 'year': 2003.0}
# {'title': 'Luv Ka the End', 'year': 2011.0}
# {'title': 'The Secret Government: Origin, Identity and Purpose of the Real MJ-12', 'year': 1989.0}
# {'title': 'Remember the Time: An MJ Video Tribute', 'year': 2009.0}
# {'title': 'Roop Ki Rani Choron Ka Raja', 'year': 1993.0}
# {'title': 'Mj 12', 'year': 2015.0}
# {'title': 'L.S. Lowry', 'year': 1957.0}
# {'title': 'Sexy MF', 'year': 1992.0}
# {'title': 'Chalti Ka Naam Gaadi', 'year': 1958.0}
# {'title': 'Shun Li and the Poet', 'year': 2011.0}
# {'title': 'MF', 'year': 2016.0}
# {'title': 'Untitled MF 6: Bring the Rukus', 'year': 2011.0}
# {'title': '7 mf', 'year': 2012.0}
# {'title': 'Je li jasno prijatelju?', 'year': 2000.0}
# {'title': 'The LS SuperTards', 'year': 2015.0}
# {'title': 'Street Fighter: The Legend of Chun-Li', 'year': 2009.0}
# {'title': 'Tie jia wu di Ma Li Ya', 'year': 1988.0}
# {'title': 'Gorcilo - Jesi li to dosao da me vidis', 'year': 2015.0}
# {'title': "Jet Li Is 'The One'", 'year': 2002.0}
# {'title': 'Kormoranid ehk Nahkpükse ei pesta', 'year': 2011.0}
# {'title': 'Hei mao zhi ci sha Ye Li Qin', 'year': 1992.0}
# {'title': 'Zui hou sheng li', 'year': 1987.0}
# {'title': 'Mehed ei nuta', 'year': 1968.0}
# {'title': 'Bruce Li the Invincible Chinatown Connection', 'year': 1978.0}
# {'title': 'Ei ruumiita makuuhuoneeseen', 'year': 1959.0}
# {'title': 'Ei', 'year': 1988.0}
# {'title': 'Das Gelbe vom Ei', 'year': 1999.0}
# {'title': 'Heil Hitler und Alaaf! - Karneval in der NS-Zeit', 'year': 2008.0}
# {'title': 'Äiti ei enää keilaa', 'year': 2010.0}
# {'title': "'Ei se mitään!' sanoi Eemeli", 'year': 1962.0}
# {'title': 'Kuningas jolla ei ollut sydäntä', 'year': 1982.0}
# {'title': 'N.S. Khruschev v Amerike', 'year': 1959.0}
# {'title': 'Das Ei ist eine geschissene Gottesgabe', 'year': 1993.0}
# {'title': 'Das Ei', 'year': 1993.0}
# {'title': 'Passion et mort de N.S. Jésus-Christ', 'year': 1906.0}
# {'title': 'NS Roulette', 'year': 2012.0}
# {'title': "Hitlers Reiseagentur KdF - Die NS-Gemeinschaft 'Kraft durch Freude'", 'year': 2009.0}
# {'title': 'Frontabschnitt Hochschule - Universitäten in der NS-Zeit', 'year': 2006.0}
# {'title': 'MW', 'year': 2009.0}
# {'title': 'Once Upon a Nuclear Ship: Stories of the NS Savannah', 'year': 2012.0}
# {'title': 'Before Hollywood, There Was Fort Lee, N.J.', 'year': 1964.0}
# {'title': "Burning of the Standard Oil Co.'s Tanks, Bayonne, N.J.", 'year': 1900.0}
# {'title': 'MW: Dai 0 shô akuma no gêmu', 'year': 2009.0}
# {'title': 'Life Rescue Scene at Atlantic City, N.J.', 'year': 1902.0}
# {'title': 'Panorama of the Paterson (N.J.) Fire', 'year': 1902.0}
# {'title': 'Annual Baby Parade, 1904, Asbury Park, N.J.', 'year': 1904.0}
# {'title': 'Verdrängte Jahre - Die ÖBB auf Spurensuche in der NS-Zeit', 'year': 2012.0}
# {'title': 'Mx. Pink', 'year': 2015.0}
# {'title': 'Circular Panorama of Atlantic City, N.J.', 'year': 1901.0}
# {'title': 'Ruins of City Hall, Paterson (N.J.)', 'year': 1902.0}
# {'title': 'Advance Guard, Return of N.J. Troops', 'year': 1898.0}
# {'title': 'Shad Fishing at Gloucester, N.J.', 'year': 1901.0}
# {'title': 'Ice-Boat Racing at Redbank, N.J.', 'year': 1901.0}
# {'title': 'Agent Mx-z3Ro', 'year': 2011.0}
# {'title': 'Que Pena Tu Vida Mx', 'year': 2016.0}
# {'title': '97 goo waak jai: Jin mo bat sing', 'year': 1997.0}
# {'title': 'Gekijô ban Bleach: The DiamondDust Rebellion - Mô hitotsu no hyôrinmaru', 'year': 2007.0}
# {'title': 'Mo', 'year': 1983.0}
# {'title': 'Qu mo jing cha', 'year': 1990.0}
# {'title': 'Mo deng bao biao', 'year': 1981.0}
# {'title': "Mo' Better Blues", 'year': 1990.0}
# {'title': 'Mo', 'year': 2010.0}
# {'title': 'Zubekô banchô: zange no neuchi mo nai', 'year': 1971.0}
# {'title': 'Yuen chi mo hei', 'year': 1999.0}
# {'title': 'Mo hup leung juk', 'year': 2008.0}
# {'title': 'Les couloirs du temps: Les visiteurs II', 'year': 1998.0}
# {'title': 'Cirque du Soleil: Worlds Away', 'year': 2012.0}
# {'title': 'Les bronzés font du ski', 'year': 1979.0}
# {'title': 'Les couloirs du temps: Les visiteurs II', 'year': 1998.0}
# {'title': 'Les Visiteurs du Soir', 'year': 1942.0}
# {'title': "De l'autre côté du lit", 'year': 2008.0}
# {'title': 'Les dames du Bois de Boulogne', 'year': 1945.0}
# {'title': 'Speaking Object-ly', 'year': 1986.0}
# {'title': 'Tous les matins du monde', 'year': 1991.0}
# {'title': 'Hotel du Nord', 'year': 1938.0}
# {'title': 'Josef a Ly', 'year': 2004.0}
# {'title': "Cirque du Freak: The Vampire's Assistant", 'year': 2009.0}
# {'title': 'Ai xuoi van ly', 'year': 1996.0}
# {'title': 'Care Bears: Grizzle-ly Adventures', 'year': 2015.0}
# {'title': 'Anal-ly Yours', 'year': 2003.0}
# {'title': 'Sha(w)ly Not?', 'year': 1914.0}
# {'title': 'Hoa thiên lý', 'year': 1973.0}
# {'title': 'Lilith and Ly', 'year': 1919.0}
# {'title': 'EQ: A Film About Emotional Intelligence', 'year': 2015.0}
# {'title': 'Takot ako, eh!', 'year': 1987.0}
# {'title': 'Eh Janam Tumhare Lekhe', 'year': 2015.0}
# {'title': 'Here We Go Again, Eh Providence?', 'year': 1973.0}
# {'title': 'Here We Go Again, Eh Providence?', 'year': 1973.0}
# {'title': 'Life Is Tough, Eh Providence?', 'year': 1972.0}
# ...
# {'title': "CC Coletti's: Trouble with Me", 'year': 2010.0}
# {'title': 'CC 2010', 'year': 2009.0}
# {'title': 'C.C. gâruzu fâsuto ran: Kaze o dakishimete', 'year': 1992.0}
# {'title': 'The World Within: C.G. Jung in His Own Words', 'year': 1990.0}
# {'title': 'CC: Stand-Up - The Bonnaroo Experience', 'year': 2012.0}
# {'title': "CC Coletti's: Mercedes Benz", 'year': 2011.0}
# {'title': 'CC Variety TV', 'year': 2006.0}
# {'title': 'Bo', 'year': 2010.0}
# {'title': 'Bu Iste Bir Yalnizlik Var', 'year': 2013.0}
# {'title': 'Bo Burnham: Words, Words, Words', 'year': 2010.0}
# {'title': 'Bo ming chan dao duo ming qiang', 'year': 1979.0}
# {'title': 'Dan sun bo lok', 'year': 2007.0}
# {'title': 'Nereden çikti bu velet', 'year': 1975.0}
# {'title': "L'Empire Bo$$é", 'year': 2012.0}
# {'title': 'Tae-Bo Workout: Basic', 'year': 1999.0}
# {'title': 'Anata no naka de ikiru: CG seinen no kodoku to ai', 'year': 1995.0}
# {'title': 'Man bo nu lang', 'year': 1957.0}
# {'title': 'Inochi bô ni furô', 'year': 1971.0}
# {'title': 'Nereye bakiyor bu adamlar', 'year': 1976.0}
# {'title': 'A Ay', 'year': 1988.0}
# {'title': 'Fakat Müzeyyen Bu Derin Bir Tutku', 'year': 2014.0}
# {'title': 'Bu Son Olsun', 'year': 2012.0}
# {'title': 'Bu jian bu san', 'year': 1998.0}
# {'title': 'Shen bu you ji', 'year': 1980.0}
# {'title': '¡Ay amor... cómo me has puesto!', 'year': 1951.0}
# {'title': 'Xin tian long ba bu zhi tian shan tong lao', 'year': 1994.0}
# {'title': 'Xiaohai bu ben 2', 'year': 2006.0}
# {'title': 'Ay Lav Yu', 'year': 2010.0}
# {'title': 'Batsin bu dünya', 'year': 1975.0}
# {'title': 'Modern Greeks: C.P. Cavafy', 'year': 2007.0}
# {'title': 'GameCenter CX: The Movie - 1986 Mighty Bomb Jack', 'year': 2014.0}
# {'title': '¡Ay, Carmela!', 'year': 1990.0}
# {'title': 'Mr London: CP 2013', 'year': 2012.0}
# {'title': 'Sule, Ay Need You', 'year': 2012.0}
# {'title': '¡Ay, qué tiempos señor don Simón!', 'year': 1941.0}
# {'title': 'Ay Juancito', 'year': 2004.0}
# {'title': 'Ay büyürken uyuyamam', 'year': 2011.0}
# {'title': 'Cl/h', 'year': 1997.0}
# {'title': 'Kung ikaw ay isang panaginip', 'year': 2002.0}
# {'title': 'Sayonara CP', 'year': 1972.0}
# {'title': 'CP Castings', 'year': 1989.0}
# {'title': 'Ay! Ay! Ramon', 'year': 2015.0}
# {'title': 'Yrrol - En kolossalt genomtänkt film', 'year': 1994.0}
# {'title': 'Romance @ C.P. Coaching', 'year': 2012.0}
# {'title': 'CP Trainer', 'year': 2007.0}
# {'title': 'CP Time', 'year': 2010.0}
# {'title': 'C.P. Research Institute', 'year': 1998.0}
# {'title': 'CP Family Reunion', 'year': 2013.0}
# {'title': "Ma vie en l'air", 'year': 2005.0}
# {'title': '75 cl', 'year': 2012.0}
# {'title': 'Cl.One', 'year': 2005.0}
# {'title': 'Indieboyz Cl!maxed', 'year': 2010.0}
# {'title': 'Ez firiyam tu ma li cih', 'year': 2012.0}
# {'title': 'En la cama', 'year': 2005.0}
# {'title': 'Un Coeur en Hiver', 'year': 1992.0}
# {'title': '10 Ez Steps for Mortician Success', 'year': 2010.0}
# {'title': 'En gång i Phuket', 'year': 2011.0}
# {'title': 'Ma Vie en Rose', 'year': 1997.0}
# {'title': 'Hälsoresan - En smal film av stor vikt', 'year': 1999.0}
# {'title': 'Search for a CW Star', 'year': 2010.0}
# {'title': 'En la ciudad sin límites', 'year': 2002.0}
# {'title': 'Arc-en-CL', 'year': 2000.0}
# {'title': 'EZ Money', 'year': 2005.0}
# {'title': 'Ez történt Budapesten', 'year': 1944.0}
# {'title': 'Ajándék ez a nap', 'year': 1979.0}
# {'title': 'Santa Fe', 'year': 1951.0}
# {'title': 'Örült szerelem ez', 'year': 2008.0}
# {'title': 'Ez-Chewie', 'year': 2009.0}
# {'title': 'Kire ütött ez a gyerek?', 'year': 2007.0}
# {'title': 'Ez Már Nemcsak Játék', 'year': 1982.0}
# {'title': 'EZ Bake', 'year': 2009.0}
# {'title': 'Lights of Old Santa Fe', 'year': 1944.0}
# {'title': 'CW: Hard Labour', 'year': 2009.0}
# {'title': 'Search for a CW Star', 'year': 2010.0}
# {'title': 'CW (Carwash)', 'year': 2007.0}
# {'title': 'Fe Mahatet masr', 'year': 2006.0}
# {'title': 'L!fe Happens', 'year': 2011.0}
# {'title': 'Santa Fe', 'year': 1997.0}
# {'title': 'CW: Suprise Suprise', 'year': 2006.0}
# {'title': 'Mo fa a ma', 'year': 2000.0}
# {'title': 'Santa Fe Stampede', 'year': 1938.0}
# {'title': 'Santa Fe Passage', 'year': 1955.0}
# {'title': 'Cuestión de fe', 'year': 1995.0}
# {'title': 'Calle Santa Fe', 'year': 2007.0}
# {'title': 'The Excitement of the Do-Re-Mi-Fa Girl', 'year': 1985.0}
# {'title': 'Do Re Mi Fa So La Si Do', 'year': 2008.0}
# {'title': 'Hui nin yin fa dak bit doh', 'year': 1998.0}
# {'title': 'Here Come the Co-eds', 'year': 1945.0}
# {'title': 'Fa fa ying king', 'year': 2008.0}
# {'title': 'La poliziotta fa carriera', 'year': 1976.0}
# {'title': 'The Fair Co-Ed', 'year': 1927.0}
# {'title': 'Fa qian han', 'year': 1977.0}
# {'title': 'Fb', 'year': 2009.0}
# {'title': 'Yi chu ji fa', 'year': 1991.0}
# {'title': 'Your Mother Is a FB', 'year': 2013.0}
# {'title': 'Macross FB 7: Ore no Uta o Kike!', 'year': 2012.0}
# {'title': 'Hua pi zhi: Yin yang fa wang', 'year': 1993.0}
# {'title': 'Co mi zrobisz, jak mnie zlapiesz', 'year': 1978.0}
# {'title': 'FB: Fighting Beat', 'year': 2007.0}
# {'title': 'Pk.com.cn', 'year': 2008.0}
# {'title': 'The Culpepper Cattle Co.', 'year': 1972.0}
# {'title': 'Mr. C.N. Morton', 'year': 1897.0}
# {'title': 'Cai li fa xiao zi', 'year': 1976.0}
# {'title': 'How to Beat the High Co$t of Living', 'year': 1980.0}
# {'title': 'Samrat & Co.', 'year': 2014.0}
# {'title': 'Dancing Co-Ed', 'year': 1939.0}
# {'title': 'Co-ed Call Girl', 'year': 1996.0}
# {'title': 'The Falcon and the Co-eds', 'year': 1943.0}
# {'title': 'CQ', 'year': 2001.0}
# {'title': 'Max & Co', 'year': 2007.0}
# {'title': "On the Set of 'CQ'", 'year': 2002.0}
# {'title': 'CQ in My Dreams', 'year': 2014.0}
# {'title': 'CR No: 89', 'year': 2013.0}
# {'title': 'CR:SR Test národa 2006', 'year': 2006.0}
# {'title': 'CR:SR Test národa 2007', 'year': 2007.0}
# {'title': 'E.ON Energy Globe Award CR 2008', 'year': 2008.0}
# {'title': 'Vzpomínky na zvírecí koncentráky v CR 2002', 'year': 2003.0}
# {'title': 'Vzpomínky na zvírecí koncentráky v CR 2009', 'year': 2009.0}
# {'title': 'E.ON Energy Globe Award CR 2010', 'year': 2010.0}
# {'title': 'E.ON Energy Globe Award CR 2011', 'year': 2011.0}
# {'title': 'C.S. Lewis: Beyond Narnia', 'year': 2005.0}
# {'title': 'The Notorious C.R', 'year': 2013.0}
# {'title': 'The Question of God: Sigmund Freud & C.S. Lewis', 'year': 2004.0}
# {'title': 'C.S. Lewis: Dreamer of Narnia', 'year': 2006.0}
# {'title': 'The Magic Never Ends: The Life and Work of C.S. Lewis', 'year': 2002.0}
# {'title': 'The Shortest Way Home: C.S. Lewis and Mere Christianity', 'year': 2013.0}
# {'title': 'Through a Lens Darkly: Grief, Loss and C.S. Lewis', 'year': 2011.0}
# {'title': 'The Heavens Are Telling the Glory of God: The Theological Imagination of CS Lewis', 'year': 2013.0}
# {'title': 'O cs. studentech', 'year': 1950.0}
# {'title': 'Affectionately Yours, Screwtape: The Devil and C.S. Lewis', 'year': 2007.0}
# {'title': "Narnia's Lost Poet: The Secret Lives and Loves of CS Lewis", 'year': 2013.0}
# {'title': 'Louis C.K.: Chewed Up', 'year': 2008.0}
# {'title': 'Louis C.K.: Live at the Beacon Theater', 'year': 2011.0}
# {'title': 'Louis C.K.: Shameless', 'year': 2007.0}
# {'title': 'Louis C.K.: Hilarious', 'year': 2010.0}
# {'title': 'C.K. dezerterzy', 'year': 1986.0}
# {'title': 'Go F*ck Yourself with Dave Franco', 'year': 2011.0}
# {'title': 'Louis C.K. Learns About the Catholic Church', 'year': 2007.0}
# {'title': "Louis C.K.'s Last Chance", 'year': 2009.0}
# {'title': 'Louis C.K.: Live at the Comedy Store', 'year': 2015.0}
# {'title': 'El Topo', 'year': 1970.0}
# {'title': 'El mariachi', 'year': 1992.0}
# {'title': 'El Dorado', 'year': 1966.0}
# {'title': 'El crimen del padre Amaro', 'year': 2002.0}
# {'title': 'The Road to El Dorado', 'year': 2000.0}
# {'title': 'El Crimen Perfecto (The Perfect Crime)', 'year': 2004.0}
# {'title': 'El Cid', 'year': 1961.0}
# {'title': 'The Haunted World of El Superbeasto', 'year': 2009.0}
# {'title': 'El Narco', 'year': 2010.0}
# {'title': 'Liverpool FC: Champions of Europe 2005', 'year': 2005.0}
# {'title': 'F.C. De Kampioenen: Kampioen zijn blijft plezant', 'year': 2013.0}
# {'title': 'FC Venus', 'year': 2005.0}
# {'title': 'FC Venus', 'year': 2006.0}
# {'title': 'F.C. De Kampioenen 2: Jubilee general', 'year': 2015.0}
# {'title': 'Liverpool FC: 501 Goals', 'year': 2003.0}
# {'title': 'Arsenal FC: 501 Goals', 'year': 2004.0}
# {'title': '100 Jahre FC Bayern', 'year': 2000.0}
# {'title': 'Las ibéricas F.C.', 'year': 1971.0}
# {'title': 'J.G. Ballard: The Future Is Now', 'year': 1998.0}
# {'title': 'JK Enum Nanbanin Vaazhkai', 'year': 2015.0}
# {'title': 'J.K. Rowling: A Year in the Life', 'year': 2007.0}
# {'title': 'JK LOL', 'year': 2009.0}
# {'title': 'Magic Beyond Words: The J.K. Rowling Story', 'year': 2011.0}
# {'title': 'The Magical World of Harry Potter: The Unauthorized Story of J.K. Rowling', 'year': 2000.0}
# {'title': 'Chelsea FC: 100 Great Goals', 'year': 2003.0}
# {'title': 'Conversation with J.K. Rowling and Steve Kloves', 'year': 2003.0}
# {'title': 'The JK Years: A Political Trajectory', 'year': 1980.0}
# {'title': 'JK Rowling and the Harry Potter Express', 'year': 2001.0}
# {'title': 'JK Rowling: The Interview', 'year': 2003.0}
# {'title': 'Dil Toh Baccha Hai Ji', 'year': 2011.0}
# {'title': 'Gau ban ji ma goon ji baak min bau ching tin', 'year': 1994.0}
# {'title': 'Hamipanshitemo kinishinai! JK bishoujo ga taisougi (buruma) ni natte ecchi ni kaiketsushichau houkago soudanshitsu', 'year': 2010.0}
# {'title': 'Sardaar Ji', 'year': 2015.0}
# {'title': 'Bha Ji in Problem', 'year': 2013.0}
# {'title': '98 goo waak chai ji lung chang foo dau', 'year': 1998.0}
# {'title': 'Robo Jî', 'year': 2012.0}
# {'title': 'Ji', 'year': 2005.0}
# {'title': 'Jiang shi jia zu: Jiang shi xian sheng xu ji', 'year': 1986.0}
# {'title': 'La vérité si je mens!', 'year': 1997.0}
# {'title': "Je t'aime John Wayne", 'year': 2001.0}
# {'title': "Je t'aime je t'aime", 'year': 1968.0}
# {'title': 'Tesko je biti fin', 'year': 2007.0}
# {'title': "Paris, je t'aime", 'year': 2006.0}
# {'title': "Je t'aime moi non plus", 'year': 1976.0}
# {'title': "Je l'aimais", 'year': 2009.0}
# {'title': 'Je fais le mort', 'year': 2013.0}
# {'title': 'J.M. Mondésir', 'year': 2013.0}
# {'title': 'J.M. Barrie, la vérité sur Peter Pan', 'year': 2000.0}
# {'title': 'Correspondencia Jonas Mekas - J.L. Guerin', 'year': 2011.0}
# {'title': 'JM After Dark: Volume 1, Issue 1', 'year': 2008.0}
# {'title': 'Deconstructing JL: War with Jay Oliva and Jim Lee dvd-extra', 'year': 2013.0}
# {'title': 'J.M.', 'year': 1982.0}
# {'title': 'JL Ranch', 'year': 2016.0}
# {'title': 'Jeuh kieh a jm hm kahun', 'year': 2014.0}
# {'title': 'Kyon Ki...', 'year': 2005.0}
# {'title': 'Ferrari Ki Sawaari', 'year': 2012.0}
# {'title': 'Goliyon Ki Rasleela Ram-Leela', 'year': 2013.0}
# {'title': 'Mere Brother Ki Dulhan', 'year': 2011.0}
# {'title': 'Mere Yaar Ki Shaadi Hai', 'year': 2002.0}
# {'title': 'Humpty Sharma Ki Dulhania', 'year': 2014.0}
# {'title': 'Mere Dad Ki Maruti', 'year': 2013.0}
# {'title': 'Buenos Aires 100 Km', 'year': 2004.0}
# {'title': 'Mumbai 125 KM 3D', 'year': 2014.0}
# {'title': 'Main Prem Ki Diwani Hoon', 'year': 2003.0}
# {'title': 'Viyah 70 Km', 'year': 2013.0}
# {'title': 'KM 31: Kilometre 31', 'year': 2006.0}
# {'title': '1735 Km', 'year': 2005.0}
# {'title': '7915 Km', 'year': 2008.0}
# {'title': '10.000 Km', 'year': 2014.0}
# {'title': 'Cinema 500 km', 'year': 2006.0}
# {'title': 'KK Family List', 'year': 1997.0}
# {'title': 'Km. 0 - Kilometer Zero', 'year': 2000.0}
# {'title': '9 KK Road', 'year': 2010.0}
# {'title': '7 km da Gerusalemme', 'year': 2007.0}
# {'title': 'KK: The Girl with the Dog', 'year': 2013.0}
# {'title': 'Who Is KK Downey?', 'year': 2008.0}
# {'title': 'KL 10 Patthu', 'year': 2015.0}
# {'title': 'Pet filmova o Nives K.K.', 'year': 1980.0}
# {'title': 'Nevoljite na pokojniot K.K', 'year': 1963.0}
# {'title': 'KK 17', 'year': 1964.0}
# {'title': 'Evolusi: KL Drift 2', 'year': 2010.0}
# {'title': 'K.K. Steincke', 'year': 1932.0}
# {'title': 'KL Gangster 2', 'year': 2013.0}
# {'title': 'Kl', 'year': 2011.0}
# {'title': 'Iznenadna i prerana smrt pukovnika K.K', 'year': 1987.0}
# {'title': 'Evolusi: KL Drift', 'year': 2008.0}
# {'title': 'Hund, søndag kl. elleve', 'year': 2004.0}
# {'title': 'Väckning kl. 06.00', 'year': 1971.0}
# {'title': 'Dir en Grey: [KR] Cube', 'year': 2000.0}
# {'title': 'KL Zombi', 'year': 2013.0}
# {'title': 'KL Gangster', 'year': 2011.0}
# {'title': 'Lauri Kr. Relander 1925-1931', 'year': 1957.0}
# {'title': 'Goodbye KL', 'year': 2010.0}
# {'title': 'Chief Minister K.R. Gowthami', 'year': 1994.0}
# {'title': 'Review of British Navy at Southend End and Spithead: Lt. Shackleton on Board Armadale Castle', 'year': 1909.0}
# {'title': 'Raumfahrt als inneres Erlebnis: Gen. Lt. Pugatschow bei Stromsperre in Baikonur', 'year': 1999.0}
# {'title': 'Lt. Elmo Ramas: Sundalo', 'year': 1995.0}
# {'title': 'LT: The Life & Times', 'year': 2013.0}
# {'title': 'Lt. Col. Alejanndro Yanquling, WPD', 'year': 1993.0}
# {'title': 'In Conversation: Director L.Q. Jones & Writer Harlan Ellison', 'year': 2013.0}
# {'title': 'Lt. Robin Crusoe, U.S.N.', 'year': 1966.0}
# {'title': 'Von Zeppelin 1 bis LZ 130', 'year': 1937.0}
# {'title': 'Five Days in Winter: The LT Sean Snyder Story', 'year': 2015.0}
# {'title': 'Lt. Shintarô Sugiyama, the Single Dad Cop', 'year': 2015.0}
# {'title': 'Lv-225', 'year': 2013.0}
# {'title': 'homo@lv', 'year': 2010.0}
# {'title': 'Lt. Nicho-las Aguirre: Batas ko ang iiral', 'year': 1992.0}
# {'title': 'LZ Lost', 'year': 2015.0}
# {'title': 'La chance de ma vie', 'year': 2011.0}
# {'title': 'Lt. Dan Band: For the Common Good', 'year': 2011.0}
# {'title': 'The Decline of the Century: Testament L.Z.', 'year': 1994.0}
# {'title': 'Scusa ma ti voglio sposare', 'year': 2010.0}
# {'title': 'LV 16', 'year': 2008.0}
# {'title': 'Nie ma mocnych', 'year': 1974.0}
# {'title': 'Don Camillo monsignore... ma non troppo', 'year': 1961.0}
# {'title': 'Ma mère', 'year': 2004.0}
# {'title': 'Ma-ma', 'year': 1977.0}
# {'title': 'M.B. Curtis', 'year': 1899.0}
# {'title': 'M.B. - Doamna cu trandafiri', 'year': 2002.0}
# {'title': 'ND - Deutsches Neuland', 'year': 2004.0}
# {'title': 'Nc 87', 'year': 2014.0}
# {'title': 'Kannapolis, N.C.', 'year': 1941.0}
# {'title': 'Obama in NC: The Path to History', 'year': 2010.0}
# {'title': "The Rangers Jerkin Ain't Dead Greenville NC", 'year': 2011.0}
# {'title': 'Fu(nd) This!', 'year': 2009.0}
# {'title': 'Small Town, USA: Andrews, NC', 'year': 2014.0}
# {'title': 'N.H. Habitat', 'year': 2008.0}
# {'title': 'Onward Notre Dame: ND in Indy', 'year': 2014.0}
# {'title': 'NC Film Project Preview', 'year': 2013.0}
# {'title': 'The Ballad of Brooklyn, NC', 'year': 2014.0}
# {'title': 'N.H. 47', 'year': 1984.0}
# {'title': 'NH-8: Road to Nidhivan', 'year': 2015.0}
# {'title': 'NC Sixty', 'year': 2014.0}
# {'title': 'Still Standing: The Real Story of the NC Textile Industry', 'year': 2013.0}
# {'title': 'Tian guo ni zi', 'year': 1994.0}
# {'title': 'Lumberton, NC', 'year': 2007.0}
# {'title': 'Peace Envoys at Portsmouth, N.H.', 'year': 1905.0}
# {'title': 'Sin ton ni Sonia', 'year': 2003.0}
# {'title': 'Boku wa imouto ni koi wo suru: Secret sweethearts - Kono koi wa himitsu', 'year': 2005.0}
# {'title': 'Ni un hombre más', 'year': 2012.0}
# {'title': 'The Fantastic World of M.C. Escher', 'year': 1980.0}
# {'title': 'Metro ni notte', 'year': 2006.0}
# {'title': 'Boku wa imôto ni koi wo suru', 'year': 2007.0}
# {'title': 'Kimi ni shika kikoenai', 'year': 2007.0}
# {'title': 'Biao jie, ni hao ye!', 'year': 1990.0}
# {'title': 'The MC: Why We Do It', 'year': 2005.0}
# {'title': 'Mc Dandik', 'year': 2013.0}
# {'title': 'Show Me Your Genitals 2: E=MC Vagina', 'year': 2008.0}
# {'title': 'Takumi-kun Series: Soshite harukaze ni sasayaite', 'year': 2007.0}
# {'title': 'Metamorphose: M.C. Escher, 1898-1972', 'year': 1999.0}
# {'title': 'M.C. Escher: Sky and Water 1', 'year': 1998.0}
# {'title': 'Lu tempu di li pisci spata', 'year': 1954.0}
# {'title': 'Too Legit: The MC Hammer Story', 'year': 2001.0}
# {'title': 'Lu bing hua', 'year': 1989.0}
# {'title': 'Shu jian en chou lu', 'year': 1987.0}
# {'title': 'The Life and Times of MC Beer Bong', 'year': 2004.0}
# {'title': 'The Dream of Lu', 'year': 2012.0}
# {'title': 'MC Hammer: 2 Legit - The Videos', 'year': 2002.0}
# {'title': 'Hessians MC', 'year': 2005.0}
# {'title': 'The Martian', 'year': 2015.0}
# {'title': 'Toy Story 3', 'year': 2010.0}

# %%
#3) Contar las peliculas realizadas entre 1990 y 2000

count=db.movieDetails.count_documents({'$and':[{'year':{'$gte':1990}},{'year':{'$lte':2000}}]})
print(count)
# Out:
# 372

# %%
#4) ¿Cuáles son los titulos de peliculas que ganaron más de 5 awards?

for i in db.movieDetails.find({'awards.wins':{'$gt':5}},{'title':1,'awards.wins':1,'_id':0}):
    print(i)
# Out:
# {'title': 'West Side Story', 'awards': {'wins': 18.0}}
# {'title': 'Wild Wild West', 'awards': {'wins': 10.0}}
# {'title': 'How the West Was Won', 'awards': {'wins': 7.0}}
# {'title': 'Star Wars: Episode V - The Empire Strikes Back', 'awards': {'wins': 15.0}}
# {'title': 'Star Wars: Episode IV - A New Hope', 'awards': {'wins': 38.0}}
# {'title': 'Star Wars: Episode I - The Phantom Menace', 'awards': {'wins': 17.0}}
# {'title': 'Star Wars: Episode VI - Return of the Jedi', 'awards': {'wins': 15.0}}
# {'title': 'Star Wars: Episode III - Revenge of the Sith', 'awards': {'wins': 21.0}}
# {'title': 'Star Wars: Episode II - Attack of the Clones', 'awards': {'wins': 13.0}}
# {'title': 'Star Trek Into Darkness', 'awards': {'wins': 6.0}}
# {'title': 'Star Trek', 'awards': {'wins': 22.0}}
# {'title': 'Star Trek: First Contact', 'awards': {'wins': 8.0}}
# {'title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'awards': {'wins': 13.0}}
# {'title': 'Love Actually', 'awards': {'wins': 10.0}}
# {'title': 'Shakespeare in Love', 'awards': {'wins': 55.0}}
# {'title': 'Punch-Drunk Love', 'awards': {'wins': 14.0}}
# {'title': '2001: A Space Odyssey', 'awards': {'wins': 13.0}}
# {'title': 'The Adventures of Tintin', 'awards': {'wins': 22.0}}
# {'title': 'The Adventures of Priscilla, Queen of the Desert', 'awards': {'wins': 9.0}}
# {'title': 'The Truman Show', 'awards': {'wins': 35.0}}
# {'title': 'Best in Show', 'awards': {'wins': 11.0}}
# {'title': 'The Last Picture Show', 'awards': {'wins': 16.0}}
# {'title': 'Show Me Love', 'awards': {'wins': 19.0}}
# {'title': "Pirates of the Caribbean: Dead Man's Chest", 'awards': {'wins': 41.0}}
# {'title': 'Shaun of the Dead', 'awards': {'wins': 11.0}}
# {'title': 'Dead Poets Society', 'awards': {'wins': 17.0}}
# {'title': 'Evil Dead', 'awards': {'wins': 6.0}}
# {'title': "Before the Devil Knows You're Dead", 'awards': {'wins': 17.0}}
# {'title': 'Rise of the Planet of the Apes', 'awards': {'wins': 19.0}}
# {'title': 'Planet of the Apes', 'awards': {'wins': 10.0}}
# {'title': 'Dawn of the Planet of the Apes', 'awards': {'wins': 13.0}}
# {'title': 'Alien', 'awards': {'wins': 15.0}}
# {'title': 'Butch Cassidy and the Sundance Kid', 'awards': {'wins': 16.0}}
# {'title': 'The Kid with a Bike', 'awards': {'wins': 9.0}}
# {'title': 'Brazilian Western', 'awards': {'wins': 7.0}}
# {'title': 'Midnight Cowboy', 'awards': {'wins': 24.0}}
# {'title': 'The Adventures of Baron Munchausen', 'awards': {'wins': 6.0}}
# {'title': 'Drugstore Cowboy', 'awards': {'wins': 11.0}}
# {'title': 'Top Gun', 'awards': {'wins': 9.0}}
# {'title': 'Paris, Texas', 'awards': {'wins': 15.0}}
# {'title': 'Happy, Texas', 'awards': {'wins': 6.0}}
# {'title': 'Into the Wild', 'awards': {'wins': 23.0}}
# {'title': 'Where the Wild Things Are', 'awards': {'wins': 7.0}}
# {'title': 'Wild', 'awards': {'wins': 7.0}}
# {'title': 'Wild Tales', 'awards': {'wins': 42.0}}
# {'title': 'Beasts of the Southern Wild', 'awards': {'wins': 91.0}}
# {'title': 'Wild Strawberries', 'awards': {'wins': 12.0}}
# {'title': 'Law of Desire', 'awards': {'wins': 10.0}}
# {'title': "Herod's Law", 'awards': {'wins': 20.0}}
# {'title': 'Bound', 'awards': {'wins': 8.0}}
# {'title': 'Shutter Island', 'awards': {'wins': 7.0}}
# {'title': "King of Devil's Island", 'awards': {'wins': 7.0}}
# {'title': 'Like Stars on Earth', 'awards': {'wins': 13.0}}
# {'title': 'Another Earth', 'awards': {'wins': 7.0}}
# {'title': 'Battlefield Earth', 'awards': {'wins': 10.0}}
# {'title': 'Pretty Woman', 'awards': {'wins': 8.0}}
# {'title': 'The Woman', 'awards': {'wins': 12.0}}
# {'title': 'Lost in Translation', 'awards': {'wins': 90.0}}
# {'title': 'Raiders of the Lost Ark', 'awards': {'wins': 28.0}}
# {'title': 'The Little Mermaid', 'awards': {'wins': 10.0}}
# {'title': 'Little Miss Sunshine', 'awards': {'wins': 65.0}}
# {'title': 'Stuart Little', 'awards': {'wins': 7.0}}
# {'title': 'Crazy Heart', 'awards': {'wins': 32.0}}
# {'title': 'The Normal Heart', 'awards': {'wins': 20.0}}
# {'title': 'The Beat That My Heart Skipped', 'awards': {'wins': 20.0}}
# {'title': 'Big Hero 6', 'awards': {'wins': 11.0}}
# {'title': 'Big Daddy', 'awards': {'wins': 8.0}}
# {'title': 'My Big Fat Greek Wedding', 'awards': {'wins': 18.0}}
# {'title': 'Big', 'awards': {'wins': 11.0}}
# {'title': 'Once Upon a Time in America', 'awards': {'wins': 11.0}}
# {'title': 'A Time to Kill', 'awards': {'wins': 7.0}}
# {'title': 'Lagaan: Once Upon a Time in India', 'awards': {'wins': 44.0}}
# {'title': 'Gone Girl', 'awards': {'wins': 59.0}}
# {'title': 'The Girl with the Dragon Tattoo', 'awards': {'wins': 24.0}}
# {'title': 'The Girl with the Dragon Tattoo', 'awards': {'wins': 17.0}}
# {'title': 'Girl, Interrupted', 'awards': {'wins': 6.0}}
# {'title': 'Lars and the Real Girl', 'awards': {'wins': 6.0}}
# {'title': 'Terminator 2: Judgment Day', 'awards': {'wins': 20.0}}
# {'title': 'Girl with a Pearl Earring', 'awards': {'wins': 17.0}}
# {'title': 'Independence Day', 'awards': {'wins': 31.0}}
# {'title': 'Training Day', 'awards': {'wins': 14.0}}
# {'title': 'Dog Day Afternoon', 'awards': {'wins': 13.0}}
# {'title': 'Scott Pilgrim vs. the World', 'awards': {'wins': 16.0}}
# {'title': 'Master and Commander: The Far Side of the World', 'awards': {'wins': 21.0}}
# {'title': 'The World Is Not Enough', 'awards': {'wins': 6.0}}
# {'title': 'Good Night, and Good Luck.', 'awards': {'wins': 37.0}}
# {'title': 'Ghost World', 'awards': {'wins': 26.0}}
# {'title': 'Man of Steel', 'awards': {'wins': 7.0}}
# {'title': 'Iron Man', 'awards': {'wins': 19.0}}
# {'title': 'Iron Man 2', 'awards': {'wins': 7.0}}
# {'title': 'Spider-Man', 'awards': {'wins': 13.0}}
# {'title': 'Spider-Man 2', 'awards': {'wins': 19.0}}
# {'title': 'Rain Man', 'awards': {'wins': 21.0}}
# {'title': 'Toy Story', 'awards': {'wins': 22.0}}
# {'title': 'Toy Story 3', 'awards': {'wins': 56.0}}
# {'title': 'Toy Story 2', 'awards': {'wins': 20.0}}
# {'title': 'Iron Man 3', 'awards': {'wins': 17.0}}
# {'title': 'Perfume: The Story of a Murderer', 'awards': {'wins': 15.0}}
# {'title': "It's a Wonderful Life", 'awards': {'wins': 6.0}}
# {'title': 'Life Is Beautiful', 'awards': {'wins': 60.0}}
# {'title': 'Life of Pi', 'awards': {'wins': 71.0}}
# {'title': "A Bug's Life", 'awards': {'wins': 14.0}}
# {'title': 'The Straight Story', 'awards': {'wins': 13.0}}
# {'title': "A Bug's Life", 'awards': {'wins': 14.0}}
# {'title': 'The Tree of Life', 'awards': {'wins': 100.0}}
# {'title': 'Rang De Basanti', 'awards': {'wins': 17.0}}
# {'title': 'Cyrano de Bergerac', 'awards': {'wins': 30.0}}
# {'title': 'Jean de Florette', 'awards': {'wins': 11.0}}
# {'title': 'Café de Flore', 'awards': {'wins': 9.0}}
# {'title': 'Ek Tha Tiger', 'awards': {'wins': 9.0}}
# {'title': 'Ek Villain', 'awards': {'wins': 7.0}}
# {'title': 'Gadar: Ek Prem Katha', 'awards': {'wins': 6.0}}
# {'title': 'Ed Wood', 'awards': {'wins': 22.0}}
# {'title': 'As Good as It Gets', 'awards': {'wins': 35.0}}
# {'title': 'My Life as a Dog', 'awards': {'wins': 14.0}}
# {'title': 'Come as You Are', 'awards': {'wins': 10.0}}
# {'title': 'Eu Te Amo', 'awards': {'wins': 6.0}}
# {'title': 'The Story of Qiu Ju', 'awards': {'wins': 15.0}}
# {'title': 'Han Gong-ju', 'awards': {'wins': 12.0}}
# {'title': 'Bounce Ko Gals', 'awards': {'wins': 10.0}}
# {'title': 'Shun Li and the Poet', 'awards': {'wins': 16.0}}
# {'title': 'Mo', 'awards': {'wins': 9.0}}
# {'title': 'Tous les matins du monde', 'awards': {'wins': 9.0}}
# {'title': 'Pahiram ng isang umaga', 'awards': {'wins': 15.0}}
# {'title': 'The Wizard of Oz', 'awards': {'wins': 7.0}}
# {'title': 'Os Maias - Cenas da Vida Romântica', 'awards': {'wins': 11.0}}
# {'title': 'Os Desafinados', 'awards': {'wins': 12.0}}
# {'title': 'Os Maias', 'awards': {'wins': 6.0}}
# {'title': 'Mr. & Mrs. Smith', 'awards': {'wins': 9.0}}
# {'title': 'Mr. Nobody', 'awards': {'wins': 11.0}}
# {'title': 'The Talented Mr. Ripley', 'awards': {'wins': 10.0}}
# {'title': 'Fantastic Mr. Fox', 'awards': {'wins': 29.0}}
# {'title': 'Saving Mr. Banks', 'awards': {'wins': 11.0}}
# {'title': 'Da wan', 'awards': {'wins': 6.0}}
# {'title': '2 Filhos de Francisco: A História de Zezé di Camargo & Luciano', 'awards': {'wins': 25.0}}
# {'title': 'Catch Me If You Can', 'awards': {'wins': 11.0}}
# {'title': 'If These Walls Could Talk 2', 'awards': {'wins': 6.0}}
# {'title': 'If I Want to Whistle, I Whistle', 'awards': {'wins': 18.0}}
# {'title': 'The Godfather: Part II', 'awards': {'wins': 9.0}}
# {'title': 'Back to the Future Part II', 'awards': {'wins': 9.0}}
# {'title': 'Mission: Impossible II', 'awards': {'wins': 10.0}}
# {'title': 'Il Divo', 'awards': {'wins': 22.0}}
# {'title': 'Il Postino: The Postman', 'awards': {'wins': 28.0}}
# {'title': 'Blade II', 'awards': {'wins': 6.0}}
# {'title': 'Il marchese del Grillo', 'awards': {'wins': 9.0}}
# {'title': 'Om Shanti Om', 'awards': {'wins': 32.0}}
# {'title': 'Oy Vey! My Son Is Gay!!', 'awards': {'wins': 17.0}}
# {'title': 'La Haine', 'awards': {'wins': 8.0}}
# {'title': 'La Vie en Rose', 'awards': {'wins': 41.0}}
# {'title': 'L.A. Confidential', 'awards': {'wins': 81.0}}
# {'title': 'La Dolce Vita', 'awards': {'wins': 10.0}}
# {'title': 'La Strada', 'awards': {'wins': 11.0}}
# {'title': "No Man's Land", 'awards': {'wins': 27.0}}
# {'title': 'No Country for Old Men', 'awards': {'wins': 148.0}}
# {'title': 'Tell No One', 'awards': {'wins': 12.0}}
# {'title': 'Zindagi Na Milegi Dobara', 'awards': {'wins': 17.0}}
# {'title': 'Main Hoon Na', 'awards': {'wins': 8.0}}
# {'title': 'Na-moo-eobs-neun san', 'awards': {'wins': 7.0}}
# {'title': 'Oh! What a Lovely War', 'awards': {'wins': 7.0}}
# {'title': 'Happy-Go-Lucky', 'awards': {'wins': 38.0}}
# {'title': 'Never Let Me Go', 'awards': {'wins': 7.0}}
# {'title': 'Dilwale Dulhania Le Jayenge', 'awards': {'wins': 12.0}}
# {'title': 'Le Havre', 'awards': {'wins': 15.0}}
# {'title': 'All About My Mother', 'awards': {'wins': 55.0}}
# {'title': 'Mt. Tsurugidake', 'awards': {'wins': 12.0}}
# {'title': "My Best Friend's Wedding", 'awards': {'wins': 12.0}}
# {'title': "That's My Boy", 'awards': {'wins': 6.0}}
# {'title': 'My Week with Marilyn', 'awards': {'wins': 19.0}}
# {'title': 'Everything Will Be Ok', 'awards': {'wins': 22.0}}
# {'title': "I'm a Cyborg, But That's OK", 'awards': {'wins': 7.0}}
# {'title': '89 mm od Europy', 'awards': {'wins': 6.0}}
# {'title': 'Nömadak Tx', 'awards': {'wins': 6.0}}
# {'title': 'Y Tu Mamá También', 'awards': {'wins': 37.0}}
# {'title': 'Burma VJ: Reporter i et lukket land', 'awards': {'wins': 16.0}}
# {'title': 'Filler ve Çimen', 'awards': {'wins': 11.0}}
# {'title': 'Takva su pravila', 'awards': {'wins': 9.0}}
# {'title': 'Ae Fond Kiss...', 'awards': {'wins': 8.0}}
# {'title': 'Skyggen af Emma', 'awards': {'wins': 8.0}}
# {'title': 'There Will Be Blood', 'awards': {'wins': 103.0}}
# {'title': 'This Must Be the Place', 'awards': {'wins': 18.0}}
# {'title': 'Ai Weiwei: Never Sorry', 'awards': {'wins': 6.0}}
# {'title': 'Ai no shinsekai', 'awards': {'wins': 6.0}}
# {'title': 'I Am Legend', 'awards': {'wins': 9.0}}
# {'title': 'I Am Love', 'awards': {'wins': 14.0}}
# {'title': 'A.I. Artificial Intelligence', 'awards': {'wins': 16.0}}
# {'title': 'Who Am I', 'awards': {'wins': 6.0}}
# {'title': 'I Am Sam', 'awards': {'wins': 8.0}}
# {'title': 'I Am David', 'awards': {'wins': 8.0}}
# {'title': 'Ex Machina', 'awards': {'wins': 26.0}}
# {'title': 'E.T. the Extra-Terrestrial', 'awards': {'wins': 46.0}}
# {'title': 'Séraphin: un homme et son péché', 'awards': {'wins': 8.0}}
# {'title': 'Au Revoir Les Enfants', 'awards': {'wins': 27.0}}
# {'title': 'Au bout du monde', 'awards': {'wins': 22.0}}
# {'title': 'The Hobbit: An Unexpected Journey', 'awards': {'wins': 9.0}}
# {'title': 'An Officer and a Gentleman', 'awards': {'wins': 7.0}}
# {'title': 'An Inconvenient Truth', 'awards': {'wins': 29.0}}
# {'title': 'An American Tail', 'awards': {'wins': 6.0}}
# {'title': 'An Education', 'awards': {'wins': 34.0}}
# {'title': 'Inochi bô ni furô', 'awards': {'wins': 6.0}}
# {'title': '¡Ay, Carmela!', 'awards': {'wins': 23.0}}
# {'title': 'En la cama', 'awards': {'wins': 10.0}}
# {'title': 'Un Coeur en Hiver', 'awards': {'wins': 15.0}}
# {'title': 'Ma Vie en Rose', 'awards': {'wins': 12.0}}
# {'title': 'En la ciudad sin límites', 'awards': {'wins': 8.0}}
# {'title': 'Cuestión de fe', 'awards': {'wins': 9.0}}
# {'title': 'El mariachi', 'awards': {'wins': 7.0}}
# {'title': 'El crimen del padre Amaro', 'awards': {'wins': 21.0}}
# {'title': 'El Cid', 'awards': {'wins': 6.0}}
# {'title': 'El Narco', 'awards': {'wins': 27.0}}
# {'title': 'Goliyon Ki Rasleela Ram-Leela', 'awards': {'wins': 29.0}}
# {'title': '10.000 Km', 'awards': {'wins': 17.0}}
# {'title': 'Toy Story 3', 'awards': {'wins': 56.0}}

# %%
#5) ¿Cuál es el rating promedio en el sitio imdb para todas las peliculas?

for i in db.movieDetails.aggregate([{'$group':{'_id':'null','average':{'$avg':"$imdb.rating"}}}]):
    print(i)
# Out:
# {'_id': 'null', 'average': 6.5031560490940965}

# %%
#6) ¿Cuáles son las peliculas en las cuales participó el actor Nicolas Cage?

for i in db.movieDetails.find({'actors':"Nicolas Cage"},{'_id':0,'title':1}):
    print(i)
# Out:
# {'title': 'Red Rock West'}
# {'title': 'Wild at Heart'}

# %%
#7) ¿Cuál es el número de pelicula por año?

for i in db.movieDetails.aggregate([{'$group':{'_id':"$year",'numeropeliculas':{'$sum':1}}}]):
    print(i)
# Out:
# {'_id': 1927.0, 'numeropeliculas': 1}
# {'_id': 1944.0, 'numeropeliculas': 2}
# {'_id': 1935.0, 'numeropeliculas': 1}
# {'_id': 1903.0, 'numeropeliculas': 2}
# {'_id': 2018.0, 'numeropeliculas': 1}
# {'_id': 1909.0, 'numeropeliculas': 2}
# {'_id': 1932.0, 'numeropeliculas': 3}
# {'_id': 1926.0, 'numeropeliculas': 1}
# {'_id': 1897.0, 'numeropeliculas': 2}
# {'_id': 1917.0, 'numeropeliculas': 1}
# {'_id': 1920.0, 'numeropeliculas': 1}
# {'_id': 1918.0, 'numeropeliculas': 1}
# {'_id': 1937.0, 'numeropeliculas': 3}
# {'_id': 1933.0, 'numeropeliculas': 4}
# {'_id': 1905.0, 'numeropeliculas': 2}
# {'_id': 1936.0, 'numeropeliculas': 2}
# {'_id': 1949.0, 'numeropeliculas': 2}
# {'_id': 1910.0, 'numeropeliculas': 2}
# {'_id': 1939.0, 'numeropeliculas': 3}
# {'_id': 1925.0, 'numeropeliculas': 5}
# {'_id': 1943.0, 'numeropeliculas': 4}
# {'_id': 1945.0, 'numeropeliculas': 2}
# {'_id': 1979.0, 'numeropeliculas': 16}
# {'_id': 1970.0, 'numeropeliculas': 11}
# {'_id': 1978.0, 'numeropeliculas': 8}
# {'_id': 1981.0, 'numeropeliculas': 25}
# {'_id': 1989.0, 'numeropeliculas': 26}
# {'_id': 2004.0, 'numeropeliculas': 65}
# {'_id': 2001.0, 'numeropeliculas': 53}
# {'_id': 1904.0, 'numeropeliculas': 1}
# {'_id': 1954.0, 'numeropeliculas': 6}
# {'_id': 1971.0, 'numeropeliculas': 20}
# {'_id': 1928.0, 'numeropeliculas': 2}
# {'_id': 1975.0, 'numeropeliculas': 20}
# {'_id': 1984.0, 'numeropeliculas': 19}
# {'_id': 1987.0, 'numeropeliculas': 22}
# {'_id': 1938.0, 'numeropeliculas': 7}
# {'_id': 1994.0, 'numeropeliculas': 35}
# {'_id': 2006.0, 'numeropeliculas': 80}
# {'_id': 1959.0, 'numeropeliculas': 7}
# {'_id': 2000.0, 'numeropeliculas': 55}
# {'_id': 2010.0, 'numeropeliculas': 105}
# {'_id': 1963.0, 'numeropeliculas': 9}
# {'_id': 2014.0, 'numeropeliculas': 100}
# {'_id': 1991.0, 'numeropeliculas': 24}
# {'_id': 1968.0, 'numeropeliculas': 12}
# {'_id': 2015.0, 'numeropeliculas': 73}
# {'_id': 1993.0, 'numeropeliculas': 34}
# {'_id': 1896.0, 'numeropeliculas': 2}
# {'_id': 2008.0, 'numeropeliculas': 75}
# {'_id': 1911.0, 'numeropeliculas': 1}
# {'_id': 1961.0, 'numeropeliculas': 11}
# {'_id': 2007.0, 'numeropeliculas': 97}
# {'_id': 1980.0, 'numeropeliculas': 23}
# {'_id': 2003.0, 'numeropeliculas': 61}
# {'_id': 1906.0, 'numeropeliculas': 2}
# {'_id': 2013.0, 'numeropeliculas': 127}
# {'_id': 1916.0, 'numeropeliculas': 1}
# {'_id': 1952.0, 'numeropeliculas': 2}
# {'_id': 1999.0, 'numeropeliculas': 50}
# {'_id': 1902.0, 'numeropeliculas': 5}
# {'_id': 2012.0, 'numeropeliculas': 103}
# {'_id': 1915.0, 'numeropeliculas': 6}
# {'_id': 1977.0, 'numeropeliculas': 16}
# {'_id': 1983.0, 'numeropeliculas': 8}
# {'_id': 2005.0, 'numeropeliculas': 73}
# {'_id': 1908.0, 'numeropeliculas': 1}
# {'_id': 1982.0, 'numeropeliculas': 15}
# {'_id': 2002.0, 'numeropeliculas': 60}
# {'_id': 1962.0, 'numeropeliculas': 12}
# {'_id': 2009.0, 'numeropeliculas': 89}
# {'_id': 1912.0, 'numeropeliculas': 2}
# {'_id': 1996.0, 'numeropeliculas': 32}
# {'_id': 1899.0, 'numeropeliculas': 4}
# {'_id': 2011.0, 'numeropeliculas': 102}
# {'_id': 1914.0, 'numeropeliculas': 3}
# {'_id': 1964.0, 'numeropeliculas': 13}
# {'_id': 1951.0, 'numeropeliculas': 6}
# {'_id': 1998.0, 'numeropeliculas': 35}
# {'_id': 1901.0, 'numeropeliculas': 6}
# {'_id': 1992.0, 'numeropeliculas': 26}
# {'_id': 1956.0, 'numeropeliculas': 2}
# {'_id': 1997.0, 'numeropeliculas': 29}
# {'_id': 1900.0, 'numeropeliculas': 1}
# {'_id': 1988.0, 'numeropeliculas': 31}
# {'_id': 1969.0, 'numeropeliculas': 8}
# {'_id': 1921.0, 'numeropeliculas': 1}
# {'_id': 1986.0, 'numeropeliculas': 36}
# {'_id': 1965.0, 'numeropeliculas': 10}
# {'_id': 1930.0, 'numeropeliculas': 5}
# {'_id': 1940.0, 'numeropeliculas': 2}
# {'_id': 1941.0, 'numeropeliculas': 4}
# {'_id': 1958.0, 'numeropeliculas': 6}
# {'_id': 1942.0, 'numeropeliculas': 4}
# {'_id': 1974.0, 'numeropeliculas': 10}
# {'_id': 1950.0, 'numeropeliculas': 3}
# {'_id': 1990.0, 'numeropeliculas': 24}
# {'_id': 1972.0, 'numeropeliculas': 12}
# {'_id': 1985.0, 'numeropeliculas': 23}
# {'_id': 1995.0, 'numeropeliculas': 28}
# {'_id': 1898.0, 'numeropeliculas': 9}
# {'_id': 1957.0, 'numeropeliculas': 6}
# {'_id': 1976.0, 'numeropeliculas': 20}
# {'_id': 1947.0, 'numeropeliculas': 1}
# {'_id': 1946.0, 'numeropeliculas': 3}
# {'_id': 1955.0, 'numeropeliculas': 4}
# {'_id': 1967.0, 'numeropeliculas': 5}
# {'_id': 1966.0, 'numeropeliculas': 15}
# {'_id': 2016.0, 'numeropeliculas': 8}
# {'_id': 1919.0, 'numeropeliculas': 2}
# {'_id': 1948.0, 'numeropeliculas': 3}
# {'_id': 1973.0, 'numeropeliculas': 15}
# {'_id': 1953.0, 'numeropeliculas': 3}
# {'_id': 1934.0, 'numeropeliculas': 3}
# {'_id': 1960.0, 'numeropeliculas': 4}
# {'_id': 1929.0, 'numeropeliculas': 1}
# {'_id': 1931.0, 'numeropeliculas': 2}
# {'_id': 1924.0, 'numeropeliculas': 1}

# %%
#8) ¿Cuál es la pelicula con el mejor rating?

maxTitle=title
maxRating=0

for i in db.movieDetails.find():
    title=i.get('title')
    rating=i.get('imdb')
    rating=rating.get("rating")
    if rating is None:     
        rating=0
    else:
        if(maxRating<rating):
            maxTitle=title
            maxRating=rating
    
print("Titulo de la pelicula: ", maxTitle)
print("Rating de la pelicula: ", maxRating)
# Out:
# Titulo de la pelicula:  DP Fantasies 2
# Rating de la pelicula:  9.6

# %%
#9) ¿Cuáles son los thrillers con un rating de al meno 6?

for i in db.movieDetails.find({'$and':[{"imdb.rating":{'$gte':6}},{'genres':"Thriller"}]},{'_id':0,'title':1,"imdb.rating":1}):
    print(i)
# Out:
# {'title': 'Red Rock West', 'imdb': {'rating': 7.0}}
# {'title': 'Slow West', 'imdb': {'rating': 7.0}}
# {'title': 'From Russia with Love', 'imdb': {'rating': 7.5}}
# {'title': 'From Paris with Love', 'imdb': {'rating': 6.5}}
# {'title': 'Space Cowboys', 'imdb': {'rating': 6.4}}
# {'title': "Before the Devil Knows You're Dead", 'imdb': {'rating': 7.3}}
# {'title': 'False Trail', 'imdb': {'rating': 6.5}}
# {'title': 'Total western', 'imdb': {'rating': 6.4}}
# {'title': 'The Man with the Golden Gun', 'imdb': {'rating': 6.8}}
# {'title': 'Wild Tales', 'imdb': {'rating': 8.2}}
# {'title': 'Law Abiding Citizen', 'imdb': {'rating': 7.4}}
# {'title': 'Law of Desire', 'imdb': {'rating': 7.2}}
# {'title': 'Beyond the Law', 'imdb': {'rating': 6.5}}
# {'title': 'Shutter Island', 'imdb': {'rating': 8.1}}
# {'title': 'The Woman in Black', 'imdb': {'rating': 6.4}}
# {'title': 'Lost Highway', 'imdb': {'rating': 7.7}}
# {'title': 'Angel Heart', 'imdb': {'rating': 7.3}}
# {'title': 'Wild at Heart', 'imdb': {'rating': 7.3}}
# {'title': 'In Time', 'imdb': {'rating': 6.7}}
# {'title': 'Once Upon a Time in Mexico', 'imdb': {'rating': 6.4}}
# {'title': 'A Time to Kill', 'imdb': {'rating': 7.4}}
# {'title': 'Training Day', 'imdb': {'rating': 7.7}}
# {'title': 'Die Another Day', 'imdb': {'rating': 6.1}}
# {'title': 'The World Is Not Enough', 'imdb': {'rating': 6.4}}
# {'title': '30 Days of Night', 'imdb': {'rating': 6.6}}
# {'title': 'We Own the Night', 'imdb': {'rating': 6.9}}
# {'title': 'Ab Tak Chhappan', 'imdb': {'rating': 8.0}}
# {'title': "L'assassino è costretto ad uccidere ancora", 'imdb': {'rating': 6.7}}
# {'title': '2000 AD', 'imdb': {'rating': 6.0}}
# {'title': 'Cul-De-Sac', 'imdb': {'rating': 7.2}}
# {'title': 'Ek Hasina Thi', 'imdb': {'rating': 7.7}}
# {'title': 'Ee Adutha Kaalath', 'imdb': {'rating': 7.6}}
# {'title': 'Ee Thanutha Veluppan Kalathu', 'imdb': {'rating': 7.2}}
# {'title': 'Thick as Thieves', 'imdb': {'rating': 6.0}}
# {'title': 'As Above, So Below', 'imdb': {'rating': 6.1}}
# {'title': 'Varg Veum - I mørket er alle ulver grå', 'imdb': {'rating': 6.5}}
# {'title': 'Salige er de som tørster', 'imdb': {'rating': 6.0}}
# {'title': "Give 'em Hell Malone", 'imdb': {'rating': 6.0}}
# {'title': 'Ko', 'imdb': {'rating': 7.8}}
# {'title': 'Perder es cuestión de método', 'imdb': {'rating': 6.4}}
# {'title': 'Gekijô ban Bleach: The DiamondDust Rebellion - Mô hitotsu no hyôrinmaru', 'imdb': {'rating': 7.2}}
# {'title': 'Charlie the Ox', 'imdb': {'rating': 8.1}}
# {'title': 'The Talented Mr. Ripley', 'imdb': {'rating': 7.3}}
# {'title': 'The Da Vinci Code', 'imdb': {'rating': 6.5}}
# {'title': 'Nom de code: DP', 'imdb': {'rating': 7.6}}
# {'title': 'Mission: Impossible II', 'imdb': {'rating': 6.0}}
# {'title': 'Nyama nishto po-hubavo ot loshoto vreme', 'imdb': {'rating': 7.2}}
# {'title': 'Mais im Bundeshuus: le génie helvétique', 'imdb': {'rating': 7.4}}
# {'title': 'Das Geheimnis im Wald', 'imdb': {'rating': 6.3}}
# {'title': 'La Femme Nikita', 'imdb': {'rating': 7.4}}
# {'title': 'Dr. No', 'imdb': {'rating': 7.3}}
# {'title': 'D.C. Sniper: 23 Days of Fear', 'imdb': {'rating': 6.0}}
# {'title': 'No Escape', 'imdb': {'rating': 6.8}}
# {'title': 'No Country for Old Men', 'imdb': {'rating': 8.1}}
# {'title': 'Na Maloom Afraad', 'imdb': {'rating': 8.2}}
# {'title': 'ID:A', 'imdb': {'rating': 6.1}}
# {'title': 'Positive I.D.', 'imdb': {'rating': 6.2}}
# {'title': 'Before I Go to Sleep', 'imdb': {'rating': 6.3}}
# {'title': 'Bob le Flambeur', 'imdb': {'rating': 7.8}}
# {'title': 'KT', 'imdb': {'rating': 6.3}}
# {'title': 'Le Doulos', 'imdb': {'rating': 7.9}}
# {'title': 'T.T. Syndrome', 'imdb': {'rating': 6.2}}
# {'title': 'Filler ve Çimen', 'imdb': {'rating': 7.2}}
# {'title': 'I Am Legend', 'imdb': {'rating': 7.2}}
# {'title': 'Who Am I', 'imdb': {'rating': 7.6}}
# {'title': 'Ax', 'imdb': {'rating': 7.5}}
# {'title': 'The Hunt for CM 24', 'imdb': {'rating': 6.2}}
# {'title': 'El Crimen Perfecto (The Perfect Crime)', 'imdb': {'rating': 7.1}}

# %%
#10) ¿Cuáles son todos los valores de generos posibles?

for i in db.movieDetails.distinct("genres"):
    print(i)
# Out:
# Crime
# Drama
# Musical
# Action
# Comedy
# Western
# Adventure
# Animation
# Family
# Thriller
# Fantasy
# Documentary
# Sci-Fi
# Romance
# Biography
# Mystery
# Horror
# Music
# History
# War
# Short
# Film-Noir
# Sport
# Talk-Show
# News
# Reality-TV
# Adult
# Game-Show

# %%
#11) ¿Cuáles son las peliculas que contienen la palabra 'Star'?

for i in db.movieDetails.find({'title': {'$regex':".*star", '$options':"i"}},{'_id':0, 'title':1}):
    print(i)
# Out:
# {'title': 'Star Wars: Episode V - The Empire Strikes Back'}
# {'title': 'Star Wars: Episode IV - A New Hope'}
# {'title': 'Star Wars: Episode I - The Phantom Menace'}
# {'title': 'Star Wars: Episode VI - Return of the Jedi'}
# {'title': 'Star Wars: Episode III - Revenge of the Sith'}
# {'title': 'Star Wars: Episode II - Attack of the Clones'}
# {'title': 'Star Trek Into Darkness'}
# {'title': 'Star Trek'}
# {'title': 'Star Trek: First Contact'}
# {'title': 'Star Trek II: The Wrath of Khan'}
# {'title': 'Like Stars on Earth'}
# {'title': 'Precure Allstars DX'}
# {'title': 'Star Cuts 66: K.C. Valentine'}
# {'title': 'JJ Star... How Embarrassing'}
# {'title': 'Star Trek VI: The Undiscovered Country'}
# {'title': 'RE:AX aka Peace Starts With Me'}
# {'title': 'CD Ram: Sex Star Interactive'}
# {'title': 'Search for a CW Star'}
# {'title': 'Search for a CW Star'}

# %%
#12) ¿Cuáles son los títulos que empiezan con la letra 'T'?

for i in db.movieDetails.find({},{'_id':0,'title':1}):
    if(i.get('title')[0]=='T'):
        print(i)
# Out:
# {'title': 'Turks in Space'}
# {'title': 'The Adventures of Tintin'}
# {'title': 'The Adventures of Priscilla, Queen of the Desert'}
# {'title': 'The Adventures of Robin Hood'}
# {'title': 'The Many Adventures of Winnie the Pooh'}
# {'title': 'The Adventures of Sharkboy and Lavagirl 3-D'}
# {'title': 'The Adventures of Buckaroo Banzai Across the 8th Dimension'}
# {'title': 'The Extraordinary Adventures of Adèle Blanc-Sec'}
# {'title': 'The Adventures of Rocky & Bullwinkle'}
# {'title': 'The Truman Show'}
# {'title': 'The Rocky Horror Picture Show'}
# {'title': 'The Last Picture Show'}
# {'title': 'The Greatest Show on Earth'}
# {'title': "There's No Business Like Show Business"}
# {'title': 'The Evil Dead'}
# {'title': 'Treasure Planet'}
# {'title': 'The Karate Kid'}
# {'title': 'The Karate Kid'}
# {'title': 'The Heartbreak Kid'}
# {'title': 'The Kid'}
# {'title': 'The Kid'}
# {'title': 'Trail of the Pink Panther'}
# {'title': 'The Kid with a Bike'}
# {'title': 'The Karate Kid, Part II'}
# {'title': 'The Hallelujah Trail'}
# {'title': 'The Big Trail'}
# {'title': 'The Decline of Western Civilization Part II: The Metal Years'}
# {'title': 'The Decline of Western Civilization'}
# {'title': 'Total western'}
# {'title': 'The Adventures of Baron Munchausen'}
# {'title': 'The Cowboy Way'}
# {'title': 'The Cowboy and the Lady'}
# {'title': 'The Naked Gun: From the Files of Police Squad!'}
# {'title': 'The Naked Gun 2½: The Smell of Fear'}
# {'title': 'The Man with the Golden Gun'}
# {'title': 'Top Gun'}
# {'title': 'The Way of the Gun'}
# {'title': 'The Texas Chainsaw Massacre'}
# {'title': 'Texas Chainsaw 3D'}
# {'title': 'The Texas Chainsaw Massacre 2'}
# {'title': 'The Texas Chainsaw Massacre: The Beginning'}
# {'title': 'The Texas Chain Saw Massacre'}
# {'title': 'Texas Chainsaw Massacre: The Next Generation'}
# {'title': 'The Poseidon Adventure'}
# {'title': 'The Oogieloves in the Big Balloon Adventure'}
# {'title': 'The Wild Bunch'}
# {'title': 'Trouble Bound'}
# {'title': 'The Island'}
# {'title': 'The Island of Dr. Moreau'}
# {'title': 'The Day the Earth Stood Still'}
# {'title': 'The Day the Earth Stood Still'}
# {'title': 'The Man from Earth'}
# {'title': 'The Other Woman'}
# {'title': 'The Woman in Black'}
# {'title': 'The Woman in Black 2: Angel of Death'}
# {'title': 'The Other Woman'}
# {'title': 'The Woman'}
# {'title': 'The Lost Boys'}
# {'title': 'The Lost World: Jurassic Park'}
# {'title': 'The City of Lost Children'}
# {'title': 'True Romance'}
# {'title': "Tillie's Punctured Romance"}
# {'title': 'The Little Mermaid'}
# {'title': 'The Normal Heart'}
# {'title': 'The Beat That My Heart Skipped'}
# {'title': 'The Big Lebowski'}
# {'title': 'The Big Sleep'}
# {'title': "The Time Traveler's Wife"}
# {'title': 'The Time Machine'}
# {'title': 'The Girl with the Dragon Tattoo'}
# {'title': 'The Girl with the Dragon Tattoo'}
# {'title': 'The Girl Next Door'}
# {'title': 'The Other Boleyn Girl'}
# {'title': 'The Girl Who Played with Fire'}
# {'title': 'Terminator 2: Judgment Day'}
# {'title': 'The Day After Tomorrow'}
# {'title': 'Training Day'}
# {'title': 'Thor: The Dark World'}
# {'title': 'The World Is Not Enough'}
# {'title': 'Team America: World Police'}
# {'title': 'The Night of the Hunter'}
# {'title': 'The Amazing Spider-Man'}
# {'title': 'Toy Story'}
# {'title': 'Toy Story 3'}
# {'title': 'The Amazing Spider-Man 2'}
# {'title': 'Toy Story 2'}
# {'title': 'The NeverEnding Story'}
# {'title': 'The Secret Life of Walter Mitty'}
# {'title': 'The Life Aquatic with Steve Zissou'}
# {'title': 'The Straight Story'}
# {'title': 'The Tree of Life'}
# {'title': "Tora pou fevgo ap' ti zoi"}
# {'title': "To gelio vgike ap' ton Paradeiso"}
# {'title': 'The Notorious B.G.: A Forum with Bill Gates'}
# {'title': 'The Unknown Celebrities: B.D. Benedikt'}
# {'title': 'The 1986 Annual D.W. Griffith Awards'}
# {'title': 'The Return of E.C. Gonatas'}
# {'title': 'The Buffalo Chips: Gimme an Eb Minor'}
# {'title': 'The Land of Eb'}
# {'title': 'The Committee Ep 1: Bad Dog'}
# {'title': "The Making of 'Captain Eo'"}
# {'title': 'The Best of BJ Thomas Live'}
# {'title': 'The Ran(dy)som for Eva'}
# {'title': 'Torrente, el brazo tonto de la ley'}
# {'title': 'The Earrings of Madame de...'}
# {'title': 'The EE British Academy Film Awards'}
# {'title': 'The Jazz Channel Presents B.B. King'}
# {'title': 'Totally F***ed Up'}
# {'title': 'Thick as Thieves'}
# {'title': 'Talada ev'}
# {'title': 'The Story of Father Ev'}
# {'title': 'The Hi-Lo Country'}
# {'title': 'Todo lo que tú quieras'}
# {'title': "Tout le monde n'a pas eu la chance d'avoir des parents communistes"}
# {'title': "The Artist's Studio: E.W. NAY"}
# {'title': 'The Passing of J.B. Randall and Company'}
# {'title': 'The Ballad of Little Jo'}
# {'title': 'The Death of J.P. Cuenca'}
# {'title': "The Duke: Based on the Memoir 'I'm the Duke' by J.P. Duke"}
# {'title': 'The Story of Qiu Ju'}
# {'title': 'The Hated K.P.'}
# {'title': 'Taste of KC Williams'}
# {'title': 'The KC Challenge'}
# {'title': 'Treacle Jr.'}
# {'title': 'To Tulsa and Back: On Tour with J.J. Cale'}
# {'title': 'The JJ Project'}
# {'title': 'Taboo: The Single and the LP'}
# {'title': 'Taboo: The Single and the LP'}
# {'title': 'Todo es mentira'}
# {'title': 'Tod den Hippies!! Es lebe der Punk!'}
# {'title': 'The Secret Government: Origin, Identity and Purpose of the Real MJ-12'}
# {'title': 'The LS SuperTards'}
# {'title': 'Tie jia wu di Ma Li Ya'}
# {'title': 'Tous les matins du monde'}
# {'title': 'Takot ako, eh!'}
# {'title': 'The JD Set 2011: Bowie'}
# {'title': 'The JD Set: 2010'}
# {'title': 'The Ox-Bow Incident'}
# {'title': 'The Battle of Chantilly (Ox Hill)'}
# {'title': 'The Year of the Ox'}
# {'title': 'The Ox'}
# {'title': 'The Wizard of Oz'}
# {'title': 'The Return of the Musk Ox'}
# {'title': 'The Wizard of Oz'}
# {'title': 'The Wonderful Wizard of Oz'}
# {'title': 'The New Wizard of Oz'}
# {'title': 'Tom and Jerry & The Wizard of Oz'}
# {'title': 'The Dreamer of Oz'}
# {'title': "The Muppets' Wizard of Oz"}
# {'title': 'The Truth About P!Nk'}
# {'title': 'The Whizzard of Ow'}
# {'title': 'The In-between World of M.G. Vassanji'}
# {'title': 'The Talented Mr. Ripley'}
# {'title': 'The Shaggy D.A.'}
# {'title': 'The Da Vinci Code'}
# {'title': 'Tutta colpa di Freud'}
# {'title': "The D.T.'s"}
# {'title': "The D.T.'s; or, The Horrors of Drink"}
# {'title': 'The GB Project'}
# {'title': 'The D.P. Man 2'}
# {'title': 'The D.P. Man'}
# {'title': 'The Twins of the G.L. Ranch'}
# {'title': 'The Godfather: Part II'}
# {'title': 'The Hangover Part II'}
# {'title': 'Trimata ot zapasa'}
# {'title': 'The Other Man: F.W. de Klerk and the End of Apartheid'}
# {'title': 'The Ku Klux Klan: A Secret History'}
# {'title': 'The Cabinet of Dr. Caligari'}
# {'title': 'The Abominable Dr. Phibes'}
# {'title': 'The Testament of Dr. Mabuse'}
# {'title': 'The Pursuit of D.B. Cooper'}
# {'title': 'Tanssija 100 dB:n hiljaisuudesta'}
# {'title': 'The Man Who Found DB Cooper'}
# {'title': 'The Last Truck: Closing of a GM Plant'}
# {'title': 'The GM Affair'}
# {'title': 'Tell No One'}
# {'title': 'Tumko Na Bhool Paayenge'}
# {'title': 'The O.J. Simpson Story'}
# {'title': 'The Trial of O.J. Simpson'}
# {'title': 'The Oh in Ohio'}
# {'title': 'The Increasing Human Devastation from the BP Blowout'}
# {'title': 'Tha parw mia vathia anasa kai tha sou pw'}
# {'title': 'Thu Kyun Ma Khan Py'}
# {'title': 'The KW Project'}
# {'title': 'To Be or Not LB'}
# {'title': 'The Tragedy of Ky Young'}
# {'title': 'The Liberation of L.B. Jones'}
# {'title': 'Twenty One Pilots: Live from the LC'}
# {'title': 'The Jury: Emma Watts QC'}
# {'title': 'The Trouble with TQ'}
# {'title': 'T.T. Syndrome'}
# {'title': 'The Saints of Mt. Christopher'}
# {'title': 'Tribulation TT with Kyp Kyp Levoux'}
# {'title': "T.T.'s Oriental Adventure"}
# {'title': 'T.T el taterrestre'}
# {'title': 'TT 5446'}
# {'title': 'TQ-1992'}
# {'title': "That's My Boy"}
# {'title': 'Tro, håb og kærlighed'}
# {'title': 'The Return of Marcus Welby, M.D.'}
# {'title': 'The Disappearance of the PX-15'}
# {'title': 'The Demon of Mount Oe'}
# {'title': 'Tie Xi Qu: West of the Tracks'}
# {'title': 'T.R. Baskin'}
# {'title': 'Tie Xi Qu: West of the Tracks'}
# {'title': 'TR(A) the Restricted Artistic'}
# {'title': 'Tie Xi Qu: West of the Tracks'}
# {'title': 'The Professional TR Course'}
# {'title': 'The Different TR Courses and Their Criticism'}
# {'title': 'TR: An American Lion'}
# {'title': 'Third Ward TX'}
# {'title': 'The Black Keys: Live in Austin, TX'}
# {'title': 'Ty i ya'}
# {'title': 'Ty - mne, ya - tebe'}
# {'title': 'Ty u menya odna'}
# {'title': 'Ty ne sirota'}
# {'title': 'Tu Dors Nicole'}
# {'title': 'Tu Chor Main Sipahi'}
# {'title': 'TV: The Movie'}
# {'title': 'The Monster Known as VD'}
# {'title': 'The TV Set'}
# {'title': 'TV Nation: Volume Two'}
# {'title': 'TV Junkie'}
# {'title': 'TS Playground 5'}
# {'title': 'TV Nation: Volume One'}
# {'title': 'The Young and Prodigious T.S. Spivet'}
# {'title': 'TS Playground 2'}
# {'title': 'The Young and Prodigious T.S. Spivet'}
# {'title': 'TS Playground'}
# {'title': 'TS Playground 4'}
# {'title': 'TS Playground 3'}
# {'title': 'TS Playground 7: Ebony Edition'}
# {'title': 'TS Playground 6'}
# {'title': 'The Land Before Time VI: The Secret of Saurus Rock'}
# {'title': 'Takva su pravila'}
# {'title': "Tarantellen af 'Napoli'"}
# {'title': 'Titan A.E.'}
# {'title': 'The Gods Must Be Crazy'}
# {'title': 'To Be or Not to Be'}
# {'title': 'There Will Be Blood'}
# {'title': 'The Man Who Would Be King'}
# {'title': 'This Must Be the Place'}
# {'title': "That's What I Am"}
# {'title': 'The Ballad of Big Al'}
# {'title': 'The Ax'}
# {'title': 'The Ax Fight'}
# {'title': "The Ax Man Enigma: The Real-life Horror Behind 'Slay Utterly'"}
# {'title': 'The Ex-Mrs. Bradford'}
# {'title': 'The Ex'}
# {'title': 'The Ex'}
# {'title': "Tintin et le mystère de la Toison d'Or"}
# {'title': 'Tintin et les oranges bleues'}
# {'title': 'Touchez Pas au Grisbi'}
# {'title': 'Tercera feria del libro de la cd. de México'}
# {'title': 'The CD Shop'}
# {'title': 'Tout ce que tu possèdes'}
# {'title': 'The Hunt for CM 24'}
# {'title': 'The Hobbit: An Unexpected Journey'}
# {'title': 'Tiger Pride: Eight Decades of CC Hockey'}
# {'title': 'Three Cases for CC Brite'}
# {'title': 'The World Within: C.G. Jung in His Own Words'}
# {'title': 'Tae-Bo Workout: Basic'}
# {'title': 'The Excitement of the Do-Re-Mi-Fa Girl'}
# {'title': 'The Fair Co-Ed'}
# {'title': 'The Culpepper Cattle Co.'}
# {'title': 'The Falcon and the Co-eds'}
# {'title': 'The Notorious C.R'}
# {'title': 'The Question of God: Sigmund Freud & C.S. Lewis'}
# {'title': 'The Magic Never Ends: The Life and Work of C.S. Lewis'}
# {'title': 'The Shortest Way Home: C.S. Lewis and Mere Christianity'}
# {'title': 'Through a Lens Darkly: Grief, Loss and C.S. Lewis'}
# {'title': 'The Heavens Are Telling the Glory of God: The Theological Imagination of CS Lewis'}
# {'title': 'The Road to El Dorado'}
# {'title': 'The Haunted World of El Superbeasto'}
# {'title': 'The Magical World of Harry Potter: The Unauthorized Story of J.K. Rowling'}
# {'title': 'The JK Years: A Political Trajectory'}
# {'title': 'Tesko je biti fin'}
# {'title': 'The Decline of the Century: Testament L.Z.'}
# {'title': "The Rangers Jerkin Ain't Dead Greenville NC"}
# {'title': 'The Ballad of Brooklyn, NC'}
# {'title': 'Tian guo ni zi'}
# {'title': 'The Fantastic World of M.C. Escher'}
# {'title': 'The MC: Why We Do It'}
# {'title': 'Takumi-kun Series: Soshite harukaze ni sasayaite'}
# {'title': 'Too Legit: The MC Hammer Story'}
# {'title': 'The Life and Times of MC Beer Bong'}
# {'title': 'The Dream of Lu'}
# {'title': 'The Martian'}
# {'title': 'Toy Story 3'}

# %%
#13) ¿Cuáles son las peliculas que no son de tipo Drama o Thriller?

for i in db.movieDetails.find({'$and':[{'genres':{'$ne':"Thriller"}},{'genres':{'$ne':"Drama"}}]},{'_id':0,'title':1}):
    print(i)
# Out:
# {'title': 'Wild Wild West'}
# {'title': 'Once Upon a Time in the West'}
# {'title': 'An American Tail: Fievel Goes West'}
# {'title': 'How the West Was Won'}
# {'title': 'A Million Ways to Die in the West'}
# {'title': 'Journey to the West'}
# {'title': 'Star Wars: Episode V - The Empire Strikes Back'}
# {'title': 'West of Memphis'}
# {'title': 'Star Wars: Episode IV - A New Hope'}
# {'title': 'Star Wars: Episode I - The Phantom Menace'}
# {'title': 'Star Wars: Episode VI - Return of the Jedi'}
# {'title': 'Star Wars: Episode III - Revenge of the Sith'}
# {'title': 'Star Wars: Episode II - Attack of the Clones'}
# {'title': 'Star Trek Into Darkness'}
# {'title': 'Star Trek'}
# {'title': 'Star Trek: First Contact'}
# {'title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb'}
# {'title': 'I Love You, Man'}
# {'title': 'I Love You Phillip Morris'}
# {'title': '2001: A Space Odyssey'}
# {'title': 'Office Space'}
# {'title': 'Zathura: A Space Adventure'}
# {'title': 'Plan 9 from Outer Space'}
# {'title': 'Muppets from Space'}
# {'title': '2001: A Space Travesty'}
# {'title': 'Space Chimps'}
# {'title': 'Turks in Space'}
# {'title': 'The Adventures of Tintin'}
# {'title': 'The Adventures of Priscilla, Queen of the Desert'}
# {'title': 'The Adventures of Robin Hood'}
# {'title': 'Adventures in Babysitting'}
# {'title': 'Lost in Space'}
# {'title': 'The Many Adventures of Winnie the Pooh'}
# {'title': 'The Adventures of Sharkboy and Lavagirl 3-D'}
# {'title': 'The Adventures of Buckaroo Banzai Across the 8th Dimension'}
# {'title': 'The Extraordinary Adventures of Adèle Blanc-Sec'}
# {'title': 'The Adventures of Rocky & Bullwinkle'}
# {'title': 'The Rocky Horror Picture Show'}
# {'title': 'Best in Show'}
# {'title': 'Show People'}
# {'title': "Pirates of the Caribbean: Dead Man's Chest"}
# {'title': 'Shaun of the Dead'}
# {'title': 'The Evil Dead'}
# {'title': 'Dawn of the Dead'}
# {'title': 'Evil Dead'}
# {'title': 'Evil Dead II'}
# {'title': 'Dawn of the Dead'}
# {'title': 'Night of the Living Dead'}
# {'title': 'Planet Terror'}
# {'title': 'Planet of the Apes'}
# {'title': 'Planet of the Apes'}
# {'title': 'Treasure Planet'}
# {'title': 'Planet 51'}
# {'title': 'Beneath the Planet of the Apes'}
# {'title': 'Alien'}
# {'title': 'Alien³'}
# {'title': 'Forbidden Planet'}
# {'title': 'Alien: Resurrection'}
# {'title': 'AVP: Alien vs. Predator'}
# {'title': 'My Stepmother Is an Alien'}
# {'title': 'Alien Nation'}
# {'title': 'Alien Raiders'}
# {'title': 'Alien Autopsy'}
# {'title': 'The Heartbreak Kid'}
# {'title': 'Honey I Blew Up the Kid'}
# {'title': 'Diary of a Wimpy Kid'}
# {'title': 'The Kid'}
# {'title': 'Trail of the Pink Panther'}
# {'title': 'The Karate Kid, Part II'}
# {'title': 'The Hallelujah Trail'}
# {'title': 'Anacondas: Trail of Blood'}
# {'title': 'HOUBA! On the Trail of the Marsupilami'}
# {'title': 'The Big Trail'}
# {'title': 'Crossfire Trail'}
# {'title': 'MacGyver: Trail to Doomsday'}
# {'title': 'Sukiyaki Western Django'}
# {'title': 'The Decline of Western Civilization Part II: The Metal Years'}
# {'title': 'Western Union'}
# {'title': 'The Decline of Western Civilization'}
# {'title': 'Western Spaghetti'}
# {'title': 'Cowboy Bebop: The Movie'}
# {'title': 'The Adventures of Baron Munchausen'}
# {'title': 'Cowboy'}
# {'title': "Ride 'Em Cowboy"}
# {'title': 'Carry on Cowboy'}
# {'title': 'The Naked Gun: From the Files of Police Squad!'}
# {'title': 'Naked Gun 33 1/3: The Final Insult'}
# {'title': 'The Naked Gun 2½: The Smell of Fear'}
# {'title': 'Western'}
# {'title': 'Machine Gun Preacher'}
# {'title': 'The Texas Chainsaw Massacre'}
# {'title': 'The Texas Chainsaw Massacre 2'}
# {'title': 'The Texas Chainsaw Massacre: The Beginning'}
# {'title': 'The Texas Chain Saw Massacre'}
# {'title': "Bill & Ted's Excellent Adventure"}
# {'title': 'Happy, Texas'}
# {'title': "Pee-wee's Big Adventure"}
# {'title': 'My Awkward Sexual Adventure'}
# {'title': 'The Oogieloves in the Big Balloon Adventure'}
# {'title': 'Caravan of Courage: An Ewok Adventure'}
# {'title': 'Remo Williams: The Adventure Begins'}
# {'title': 'Arthur and the Great Adventure'}
# {'title': 'Wild Hogs'}
# {'title': 'The Wild Bunch'}
# {'title': "Herod's Law"}
# {'title': 'Monster-in-Law'}
# {'title': 'Bollywood Bound'}
# {'title': 'Trouble Bound'}
# {'title': 'Storm Bound'}
# {'title': 'The Island'}
# {'title': 'Journey 2: The Mysterious Island'}
# {'title': "Nim's Island"}
# {'title': 'Spy Kids 2: Island of Lost Dreams'}
# {'title': 'Cutthroat Island'}
# {'title': 'Muppet Treasure Island'}
# {'title': 'After Earth'}
# {'title': 'Journey to the Center of the Earth'}
# {'title': 'Battlefield Earth'}
# {'title': 'The Day the Earth Stood Still'}
# {'title': 'Escape from Planet Earth'}
# {'title': 'Pretty Woman'}
# {'title': 'The Other Woman'}
# {'title': 'Raiders of the Lost Ark'}
# {'title': 'Home Alone 2: Lost in New York'}
# {'title': 'The Lost Boys'}
# {'title': 'Atlantis: The Lost Empire'}
# {'title': 'The Lost World: Jurassic Park'}
# {'title': 'The City of Lost Children'}
# {'title': 'Romance & Cigarettes'}
# {'title': 'Office Romance'}
# {'title': "Tillie's Punctured Romance"}
# {'title': 'Modern Romance'}
# {'title': 'The Little Mermaid'}
# {'title': 'Stuart Little'}
# {'title': 'A Little Romance'}
# {'title': 'Big Trouble in Little China'}
# {'title': 'Little Fockers'}
# {'title': 'Little Nicky'}
# {'title': 'Chicken Little'}
# {'title': 'Stuart Little 2'}
# {'title': 'Little Shop of Horrors'}
# {'title': 'I Heart Huckabees'}
# {'title': 'The Big Lebowski'}
# {'title': 'Big Hero 6'}
# {'title': 'My Big Fat Greek Wedding'}
# {'title': "Big Momma's House"}
# {'title': 'The Big Sleep'}
# {'title': 'Prince of Persia: The Sands of Time'}
# {'title': 'Hot Tub Time Machine'}
# {'title': 'The Time Machine'}
# {'title': 'Terminator 2: Judgment Day'}
# {'title': 'Groundhog Day'}
# {'title': 'Independence Day'}
# {'title': 'The Day After Tomorrow'}
# {'title': "Ferris Bueller's Day Off"}
# {'title': 'World War Z'}
# {'title': 'Knight and Day'}
# {'title': 'Thor: The Dark World'}
# {'title': 'Jurassic World'}
# {'title': 'Scott Pilgrim vs. the World'}
# {'title': "Wayne's World"}
# {'title': 'Team America: World Police'}
# {'title': 'Date Night'}
# {'title': 'Night at the Museum'}
# {'title': 'Fright Night'}
# {'title': 'Night at the Museum: Secret of the Tomb'}
# {'title': 'Man of Steel'}
# {'title': 'Iron Man'}
# {'title': 'Iron Man 2'}
# {'title': 'The Amazing Spider-Man'}
# {'title': 'Spider-Man'}
# {'title': 'Spider-Man 2'}
# {'title': 'Spider-Man 3'}
# {'title': 'Toy Story'}
# {'title': 'Toy Story 3'}
# {'title': 'The Amazing Spider-Man 2'}
# {'title': 'Toy Story 2'}
# {'title': 'Dodgeball: A True Underdog Story'}
# {'title': 'A Christmas Story'}
# {'title': 'Iron Man 3'}
# {'title': 'Life of Brian'}
# {'title': "A Bug's Life"}
# {'title': "A Bug's Life"}
# {'title': "Mia Italida ap' tin Kypseli"}
# {'title': "Gabros ap' to Londino"}
# {'title': "Ap' ta kokala vgalmena"}
# {'title': 'Being AP'}
# {'title': "I gynaikara ap' to Kilkis"}
# {'title': "To gelio vgike ap' ton Paradeiso"}
# {'title': 'Lara Croft Tomb Raider: The Cradle of Life'}
# {'title': 'AC/DC: Let There Be Rock'}
# {'title': 'AC/DC: Family Jewels'}
# {'title': 'AC/DC: No Bull'}
# {'title': 'AC/DC: Live at Donington'}
# {'title': 'AC/DC: Live at River Plate'}
# {'title': 'AC/DC: Stiff Upper Lip Live'}
# {'title': 'One Million AC/DC'}
# {'title': 'Ap 2000'}
# {'title': 'AC/DC: Plug Me In'}
# {'title': 'B.G. aru 19 sai no nikki agete yokkata'}
# {'title': 'AC/DC: Highway to Hell - Classic Album Under Review'}
# {'title': 'B.G. monogatari: nijusai no nikki'}
# {'title': 'B.G. Roper Presents...'}
# {'title': 'Incredible Blinking Machines Presents BG/B'}
# {'title': 'AC/DC: Fly on the Wall'}
# {'title': 'Blur: Rated BG'}
# {'title': 'The Notorious B.G.: A Forum with Bill Gates'}
# {'title': 'B.D. in the mountains and on the seaside'}
# {'title': 'B.D. in alert'}
# {'title': 'B.D. în alerta - Vaduve cu termen redus'}
# {'title': 'B.D. în alerta - Profesorul de mimica'}
# {'title': 'B.D. Women'}
# {'title': "BG's Dirty 30: Cruise to Ensenada"}
# {'title': 'The Unknown Celebrities: B.D. Benedikt'}
# {'title': 'B.D.'}
# {'title': 'Bikhod & Bi Jahat'}
# {'title': 'Fu gui bi ren'}
# {'title': 'Bi the Way'}
# {'title': 'Il Bi e il Ba'}
# {'title': 'Ab-normal Beauty'}
# {'title': 'Ab Tak Chhappan 2'}
# {'title': 'Faryad-e zir-e ab'}
# {'title': 'Fink fährt ab'}
# {'title': 'Peter schießt den Vogel ab'}
# {'title': 'Hotter Than July Bk'}
# {'title': 'Die Post geht ab'}
# {'title': 'Ao: The Last Hunter'}
# {'title': 'S.O.S.: Mulheres ao Mar'}
# {'title': 'S.O.S.: Mulheres ao Mar 2'}
# {'title': 'Ao oni'}
# {'title': 'Ao qi xiong ying'}
# {'title': 'Fei hu xiong xin 2 zhi ao qi bi tian gao'}
# {'title': 'Dv'}
# {'title': 'Broken: How to Make DV Look Like Film'}
# {'title': 'DV Guide'}
# {'title': 'Dv-Campitelli'}
# {'title': 'D.V.'}
# {'title': 'Heft in BH'}
# {'title': 'BH eurosong'}
# {'title': 'SX80 bh'}
# {'title': 'BM.F'}
# {'title': 'Ef'}
# {'title': 'Killa-EF'}
# {'title': 'Ulf & EF'}
# {'title': 'Pettson & Findus - Katten och gubbens år'}
# {'title': 'Jag är med barn'}
# {'title': 'Själen är större än världen'}
# {'title': 'Jag är inte beredd att dö än'}
# {'title': 'D.W. Griffith and Lillian Gish'}
# {'title': 'Maria Wern: Först när givaren är död'}
# {'title': 'D.W. Griffith et le loup'}
# {'title': 'D.W. Griffith'}
# {'title': 'The 1986 Annual D.W. Griffith Awards'}
# {'title': 'The Return of E.C. Gonatas'}
# {'title': 'Reverse Plantation, an E.C. Skit'}
# {'title': 'E.A. 2'}
# {'title': 'Hoe zotter hoe liever, het succes van de Vlaamse volksfilms van Edith Kiel e.a. van 1930-1960'}
# {'title': "Naked Love: Ea's Garden"}
# {'title': 'Megafactories: EA Sports'}
# {'title': 'Ea Sola - Sécheresse et pluie'}
# {'title': '2005 EA Sports NFL Quarterback Challenge'}
# {'title': 'Sigur Rós: Ég anda'}
# {'title': 'Ég mundi segja hó'}
# {'title': 'Det er eg!'}
# {'title': 'Az ég kék éve'}
# {'title': 'Ég Anda'}
# {'title': 'Ahol az ég is meghajlik...'}
# {'title': 'Ég és föld között'}
# {'title': 'Eb & Flo'}
# {'title': 'The Buffalo Chips: Gimme an Eb Minor'}
# {'title': 'Eb & Flo'}
# {'title': 'Eb'}
# {'title': 'Mr. B.F. Keith'}
# {'title': "B.F. Keith's New Million Dollar Theatre"}
# {'title': 'Road EB 01'}
# {'title': "BF's Forever"}
# {'title': 'BF Nowhere'}
# {'title': 'EP-X-503'}
# {'title': 'The Committee Ep 1: Bad Dog'}
# {'title': 'Gamechangers Ep. 3: A Legend in the Booth'}
# {'title': 'Gamechangers Ep. 1: The Rant Writer'}
# {'title': 'Cleve Dixon Ep 2: The Downtown Breakdown'}
# {'title': 'Asian Conan Ep. 1'}
# {'title': 'My Best Friend Bigfoot Ep.1 & 2.'}
# {'title': 'Gamechangers Ep. 2: Fear the NFL Draft'}
# {'title': 'Nathan Grant: Ghost Detective Ep. 7'}
# {'title': 'EP: Side 2'}
# {'title': 'Captain EO'}
# {'title': 'Captain Eo Grand Opening'}
# {'title': 'Captain EO Promo & Pre-show'}
# {'title': 'Hi-eo-ro'}
# {'title': 'Eo'}
# {'title': 'EO Bubble Buddy'}
# {'title': "The Making of 'Captain Eo'"}
# {'title': 'Immortal (Ad Vitam)'}
# {'title': 'Dracula A.D. 1972'}
# {'title': "Daleks' Invasion Earth 2150 A.D."}
# {'title': 'Babylon A.D.'}
# {'title': 'AD/BC: A Rock Opera'}
# {'title': 'WWE: The New & Improved DX'}
# {'title': 'WWE: DX: One Last Stand'}
# {'title': 'Eiga Purikyua ôru sutâzu DX 2: Kibou no hikari Reinbô jueru o mamore!'}
# {'title': 'Precure Allstars DX'}
# {'title': 'A.D. Police Files'}
# {'title': 'Eiga Purikyua ôru sutâzu DX 3: Mirai ni todoke! Sekai o tsunagu nijiiro no hana'}
# {'title': 'Swallowed Land DX'}
# {'title': 'Jitsuroku! Real kyoufu DX'}
# {'title': 'Dorîmu ûman x zâmen suiken DX 5'}
# {'title': 'df/dx'}
# {'title': 'The Best of BJ Thomas Live'}
# {'title': 'UFC 107: BJ Penn vs. Diego Sanchez'}
# {'title': 'Pia Carrot e Yokoso! 2 DX'}
# {'title': 'Yokohama BJ Blues'}
# {'title': 'B.J.: Black Jocks'}
# {'title': 'BJ Babes'}
# {'title': 'BJ Babes 2'}
# {'title': 'BJ Thomas: That Christmas Feeling'}
# {'title': 'BJ Becky'}
# {'title': 'The Ran(dy)som for Eva'}
# {'title': 'Dy herë mat'}
# {'title': 'L.A.dy Dior'}
# {'title': 'Dy gosti'}
# {'title': 'Bj'}
# {'title': 'Ar-khi-me-dy!'}
# {'title': 'Dhimbje midis dy brigjeve'}
# {'title': 'Dy endjet'}
# {'title': 'Pranvera dy hapa pranë'}
# {'title': 'Ne kufi te dy legjendave'}
# {'title': 'Dy-nasty'}
# {'title': 'Casa de mi Padre'}
# {'title': 'Torrente, el brazo tonto de la ley'}
# {'title': 'Ek Chalis Ki Last Local'}
# {'title': 'Jaani Dushman: Ek Anokhi Kahani'}
# {'title': 'Ek Ajnabee'}
# {'title': 'Ek Aur Ek Gyarah: By Hook or by Crook'}
# {'title': 'Gay Purr-ee'}
# {'title': 'Ee Pattanathil Bhootham'}
# {'title': 'Ee Rojullo'}
# {'title': 'Ee Puzhayum Kadannu'}
# {'title': 'The EE British Academy Film Awards'}
# {'title': 'B.B. King: The Life of Riley'}
# {'title': 'Live by Request: BB King'}
# {'title': 'B.B. King: Into the Night'}
# {'title': 'The Jazz Channel Presents B.B. King'}
# {'title': 'B.B. King: The Life of Riley'}
# {'title': 'Mardi Gras.BB: A Silent Rockumentary'}
# {'title': 'B.B. King: The Blues Summit'}
# {'title': 'B.B. King: Live'}
# {'title': 'Ed'}
# {'title': 'Evil Ed'}
# {'title': 'BB Gun'}
# {'title': 'Ed and His Dead Mother'}
# {'title': 'Sex Ed'}
# {'title': "Ed, Edd n Eddy's Big Picture Show"}
# {'title': 'Cool as Ice'}
# {'title': 'Az 1812-es év'}
# {'title': 'No EV Trouble in Little China'}
# {'title': 'Expediente EV-0043'}
# {'title': 'Talada ev'}
# {'title': 'Basketball Wives: Temper Tantrums w/ Ev'}
# {'title': 'Egy éj Velencében'}
# {'title': 'Csendes éj'}
# {'title': 'The Story of Father Ev'}
# {'title': 'Ev hali'}
# {'title': "EJ's Awesome Recovery"}
# {'title': 'Captain E.J. Smith, R.N.R. Commander of the Ill Fated S.S. Titanic: A Final Inspection of His Vessel Ten Minutes Before Sailing Time'}
# {'title': 'Ej blot til lyst'}
# {'title': 'Egy éj at Arany Bogárban'}
# {'title': 'Strawberry Schmilsson Forever - A Videopainting by E.J. Gold'}
# {'title': 'Lek ej med kärleken'}
# {'title': 'O Dia D E.J. Carvalho'}
# {'title': 'Lo'}
# {'title': 'Rok Sako To Rok Lo'}
# {'title': 'Isi/Disi - Amor a lo bestia'}
# {'title': 'Il commissario Lo Gatto'}
# {'title': 'Lo contrario al amor'}
# {'title': 'No lo llames amor... llámalo X'}
# {'title': 'Os Homens São de Marte... E é pra Lá que Eu Vou!'}
# {'title': "Tout le monde n'a pas eu la chance d'avoir des parents communistes"}
# {'title': 'Les demoiselles ont eu 25 ans'}
# {'title': 'Que Farei eu com Esta Espada?'}
# {'title': 'Eu Matei Lúcio Flávio'}
# {'title': 'Hut Nr. E.W. 2106 V'}
# {'title': "The Artist's Studio: E.W. NAY"}
# {'title': 'Ey, na linkore!'}
# {'title': 'Ey!'}
# {'title': 'Journ(ey)ées aux pays des percussions'}
# {'title': 'Pra/ey: A Vampire Film Short by Lia Scott Price'}
# {'title': 'Ey, kto nibud!'}
# {'title': "JB Smoove: That's How I Dooz It"}
# {'title': '1940: A Reminiscence by J.B. Priestly'}
# {'title': 'Pour J.B.'}
# {'title': 'J.C. Chávez'}
# {'title': 'H20 Secrets: J.B. King'}
# {'title': 'RTL voetbal: KNVB Beker finale Feyenoord - Roda JC'}
# {'title': 'J.C. Leyendecker: The Great American Illustrator'}
# {'title': 'J.C.'}
# {'title': 'Community Builder: The Life & Legacy of J.C. Nichols'}
# {'title': 'J.F. Que?'}
# {'title': 'J.C.'}
# {'title': 'J.F. Willumsen'}
# {'title': 'J.F. Willems'}
# {'title': 'Rech JF: pour court-métrage rémunéré'}
# {'title': 'Jo'}
# {'title': 'New Meet Me on South Street: The Story of JC Dobbs'}
# {'title': 'Jo Bole So Nihaal'}
# {'title': 'Ashura-jô no hitomi'}
# {'title': 'Dil Jo Bhi Kahey...'}
# {'title': 'J.P. Hopfelt: My Kind of Free'}
# {'title': 'JP Medical'}
# {'title': 'J.P. Love in Berlin'}
# {'title': 'JP Rawson'}
# {'title': 'J.P.'}
# {'title': 'The Death of J.P. Cuenca'}
# {'title': 'Hjelp, vi er i filmbransjen'}
# {'title': 'Er kanns nicht lassen'}
# {'title': 'ATM: Er Rak Error'}
# {'title': 'Baghdad ER'}
# {'title': 'Skulle det dukke opp flere lik, er det bare å ringe...'}
# {'title': 'Hjelp, vi er russ'}
# {'title': 'Full Circle: Malcolm Smith and J.N. Roberts - The Legend Lives On'}
# {'title': 'KD Matheson Boundless Tribesman'}
# {'title': 'KD No. 1'}
# {'title': 'Live by Request: K.D. Lang'}
# {'title': "K.D. Lang Talks with Percy Adlon About 'Percy Adlon's Salmonberries': 11 Years Later"}
# {'title': 'K.D. Lang: Miss Chatelaine'}
# {'title': 'Ju-on: The Grudge'}
# {'title': 'Ju-on: The Curse 2'}
# {'title': 'Ju-on: The Curse'}
# {'title': 'Ju-on: White Ghost'}
# {'title': "Shoot 'Em Up"}
# {'title': "Ax 'Em"}
# {'title': 'Ju-on: Black Ghost'}
# {'title': "Hang 'Em High"}
# {'title': 'Ju-on: The Beginning of the End'}
# {'title': "Class of Nuke 'Em High"}
# {'title': "Class of Nuke 'Em High Part II: Subhumanoid Meltdown"}
# {'title': "Keep 'Em Flying"}
# {'title': 'Jy is My Liefling'}
# {'title': 'KJ: Music and Life'}
# {'title': "Return to Nuke 'Em High Volume 1"}
# {'title': 'Ngo ga yau yat chek hiu dung see'}
# {'title': 'DJ KJ the First Hit'}
# {'title': 'Gamma Labs Presents KJ Noons'}
# {'title': "Jy's Lieflik Vanaand"}
# {'title': '72 ga cho hak'}
# {'title': 'Ga, Ga - Chwala bohaterom'}
# {'title': 'Jy is Myne'}
# {'title': 'Daai foo ji ga'}
# {'title': 'Amin Jensen - 150 kg over bæltestedet'}
# {'title': 'A Portrait of Ga'}
# {'title': 'Athens, Ga. - Inside/Out'}
# {'title': 'The Hated K.P.'}
# {'title': 'Yasha-ga-ike'}
# {'title': '1.150 kg'}
# {'title': 'Ørkenens sønner - Gå aldrig tilbage til en fuser!'}
# {'title': 'Not Less Than 50 Kg'}
# {'title': '18 kg'}
# {'title': 'Josser, KC'}
# {'title': 'Le disgrazie di un 100 Kg'}
# {'title': '3 Kg'}
# {'title': 'All About Me KG'}
# {'title': 'Taste of KC Williams'}
# {'title': 'Mrs. K.C. of England'}
# {'title': 'The KC Challenge'}
# {'title': 'Star Cuts 66: K.C. Valentine'}
# {'title': 'K.C.'}
# {'title': '2 Live Crew Feat. KC of KC & the Sunshine Band and Freak Nasty: 2 Live Party'}
# {'title': 'Private Times Video 485: Santa Fey & KC'}
# {'title': "Ko-Ko's Earth Control"}
# {'title': 'Project A-Ko'}
# {'title': 'Project A-Ko 2: Daitokuji zaibatsu no inbô'}
# {'title': 'Project A-Ko Versus Battle 2: Blue Side'}
# {'title': 'Project A-Ko 3: Cinderella Rhapsody'}
# {'title': 'Dr. Josser, K.C.'}
# {'title': 'Project A-Ko Versus Battle 1: Grey Side'}
# {'title': 'Sherlock Jr.'}
# {'title': 'Ace Ventura: Pet Detective Jr.'}
# {'title': 'Santa, Jr.'}
# {'title': 'Luxo Jr.'}
# {'title': 'Mr. Death: The Rise and Fall of Fred A. Leuchter, Jr.'}
# {'title': "Luxo Jr. in 'Surprise' and 'Light & Heavy'"}
# {'title': 'Évocateur: The Morton Downey Jr. Movie'}
# {'title': 'J.J. Biker'}
# {'title': 'To Tulsa and Back: On Tour with J.J. Cale'}
# {'title': 'Untitled Seth Ott/J.J. Project'}
# {'title': 'A Tribute to J.J. Abrams'}
# {'title': 'JJ Star... How Embarrassing'}
# {'title': 'The JJ Project'}
# {'title': 'Untitled J.J. Abrams/Chris Alender Sci-Fi Project'}
# {'title': "J.J. Redick's Guide to the Perfect March Madness Bracket"}
# {'title': 'Eric Clapton & Friends: The Breeze - An Appreciation of JJ Cale'}
# {'title': "L.L. M.M. le Tsar et la Tsarine entrant dans l'église de l'Assomption [Moscou]"}
# {'title': 'Départ en gondole de LL. MM.'}
# {'title': "LL Cool J's Mama Said Home Security Service"}
# {'title': 'Hubert Selby Jr: It/ll Be Better Tomorrow'}
# {'title': 'Cortège de gymnastique devant LL. MM.'}
# {'title': "Monza, L.L. M.M. le Roi et la Reine d'Italie"}
# {'title': "Incontro delle ll.mm. il re d'Italia e gli imperiali di Germania a Venezia splendida"}
# {'title': 'L.M. Beat'}
# {'title': "Nikki Rich & LL Cool J's Simone I Smith: Charitable Cancer Fundraiser"}
# {'title': 'c o ll e g e t o w n'}
# {'title': 'Elf ll'}
# {'title': '100 Million BC'}
# {'title': 'Josh Kirby... Time Warrior: Chapter 4, Eggs from 70 Million B.C.'}
# {'title': 'One Million Years B.C.'}
# {'title': 'One Million B.C.'}
# {'title': 'LP Into the Wild Live at Eastwest Studios'}
# {'title': 'Journey to 10,000 BC'}
# {'title': 'R.F.D. 10,000 B.C.'}
# {'title': 'Lp'}
# {'title': 'Bimbos B.C.'}
# {'title': 'B.C. Rock'}
# {'title': 'Big Daddy Dad: Ride the Bus LP'}
# {'title': 'Taboo: The Single and the LP'}
# {'title': 'David LP: Rocky Balboa'}
# {'title': 'La Casa: LP'}
# {'title': 'Taboo: The Single and the LP'}
# {'title': 'Catch LJ Live!'}
# {'title': 'Lj - Ubiti'}
# {'title': 'LJ BeachPad'}
# {'title': 'L.J. Waters'}
# {'title': 'My Way ... My Life Lp'}
# {'title': 'Kenny Plays with LJ'}
# {'title': 'Amanece, que no es poco'}
# {'title': '9 és 1/2 randi'}
# {'title': "Comme t'y es belle!"}
# {'title': 'La ciudad no es para mí'}
# {'title': 'Todo es mentira'}
# {'title': 'El mundo es nuestro'}
# {'title': 'Muqaddar Ka Sikandar'}
# {'title': 'Joru Ka Ghulam'}
# {'title': 'MJ Dong'}
# {'title': 'The Secret Government: Origin, Identity and Purpose of the Real MJ-12'}
# {'title': 'Remember the Time: An MJ Video Tribute'}
# {'title': 'Mj 12'}
# {'title': 'L.S. Lowry'}
# {'title': 'Sexy MF'}
# {'title': 'Chalti Ka Naam Gaadi'}
# {'title': 'MF'}
# {'title': 'Untitled MF 6: Bring the Rukus'}
# {'title': 'The LS SuperTards'}
# {'title': 'Tie jia wu di Ma Li Ya'}
# {'title': 'Gorcilo - Jesi li to dosao da me vidis'}
# {'title': "Jet Li Is 'The One'"}
# {'title': 'Kormoranid ehk Nahkpükse ei pesta'}
# {'title': 'Mehed ei nuta'}
# {'title': 'Bruce Li the Invincible Chinatown Connection'}
# {'title': 'Das Gelbe vom Ei'}
# {'title': 'Heil Hitler und Alaaf! - Karneval in der NS-Zeit'}
# {'title': "'Ei se mitään!' sanoi Eemeli"}
# {'title': 'Kuningas jolla ei ollut sydäntä'}
# {'title': 'N.S. Khruschev v Amerike'}
# {'title': 'Das Ei ist eine geschissene Gottesgabe'}
# {'title': 'Das Ei'}
# {'title': "Hitlers Reiseagentur KdF - Die NS-Gemeinschaft 'Kraft durch Freude'"}
# {'title': 'Frontabschnitt Hochschule - Universitäten in der NS-Zeit'}
# {'title': 'Once Upon a Nuclear Ship: Stories of the NS Savannah'}
# {'title': 'Before Hollywood, There Was Fort Lee, N.J.'}
# {'title': "Burning of the Standard Oil Co.'s Tanks, Bayonne, N.J."}
# {'title': 'Life Rescue Scene at Atlantic City, N.J.'}
# {'title': 'Panorama of the Paterson (N.J.) Fire'}
# {'title': 'Annual Baby Parade, 1904, Asbury Park, N.J.'}
# {'title': 'Verdrängte Jahre - Die ÖBB auf Spurensuche in der NS-Zeit'}
# {'title': 'Circular Panorama of Atlantic City, N.J.'}
# {'title': 'Ruins of City Hall, Paterson (N.J.)'}
# {'title': 'Advance Guard, Return of N.J. Troops'}
# {'title': 'Shad Fishing at Gloucester, N.J.'}
# {'title': 'Ice-Boat Racing at Redbank, N.J.'}
# {'title': 'Que Pena Tu Vida Mx'}
# {'title': 'Mo'}
# {'title': 'Qu mo jing cha'}
# {'title': 'Mo deng bao biao'}
# {'title': 'Zubekô banchô: zange no neuchi mo nai'}
# {'title': 'Yuen chi mo hei'}
# {'title': 'Mo hup leung juk'}
# {'title': 'Les couloirs du temps: Les visiteurs II'}
# {'title': 'Cirque du Soleil: Worlds Away'}
# {'title': 'Les bronzés font du ski'}
# {'title': 'Les couloirs du temps: Les visiteurs II'}
# {'title': "De l'autre côté du lit"}
# {'title': 'Speaking Object-ly'}
# {'title': 'Josef a Ly'}
# {'title': "Cirque du Freak: The Vampire's Assistant"}
# {'title': 'Care Bears: Grizzle-ly Adventures'}
# {'title': 'Anal-ly Yours'}
# {'title': 'Sha(w)ly Not?'}
# {'title': 'Lilith and Ly'}
# {'title': 'EQ: A Film About Emotional Intelligence'}
# {'title': 'Eh Janam Tumhare Lekhe'}
# {'title': 'Here We Go Again, Eh Providence?'}
# {'title': 'Here We Go Again, Eh Providence?'}
# {'title': 'Life Is Tough, Eh Providence?'}
# {'title': 'Electrika kasi, eh!'}
# {'title': 'Eh, Pagu, Eh!'}
# {'title': 'Cheeta-eh: Ganda lalake?'}
# {'title': 'Eh kasi bata'}
# {'title': 'Beyond Batman: Bats, Mattes & Dark Nights - The Visual FX of Batman Returns'}
# {'title': 'AI/FX'}
# {'title': 'FX'}
# {'title': 'FX 18'}
# {'title': 'Eh, Joe?'}
# {'title': 'Gorezone FX Lab Live'}
# {'title': 'AVP: Alien vs. Predator - FX Special Event'}
# {'title': "Guts & Gore: The FX of 'Hatchet'"}
# {'title': "Monsters Among Us: The Creature FX of 'The Mist'"}
# {'title': "Beyond Batman: Freeze Frame - The Visual FX of 'Batman & Robin'"}
# {'title': 'School NL'}
# {'title': 'Chantal@avro.nl'}
# {'title': 'FZ Anonymous'}
# {'title': 'Ng goh haak gwai dik siu nin'}
# {'title': 'N.L. Farnum Post, G.A.R.'}
# {'title': 'Ng yun ji dai'}
# {'title': 'Wan choi ng fuk sing'}
# {'title': 'Enteng ng Ina mo'}
# {'title': 'Gintberg - Op på fars Jihad'}
# {'title': 'Verliefd op Ibiza'}
# {'title': 'Hotel op stelten'}
# {'title': 'Mees Kees op de planken'}
# {'title': "Far til fire gi'r aldrig op"}
# {'title': 'Dichter op de zeedijk'}
# {'title': 'Space Diamonds: The Philosophy of JD Moore'}
# {'title': 'UrbanAgentTV: Up Close & Personal Interview with JD'}
# {'title': 'The JD Set 2011: Bowie'}
# {'title': 'JD Set'}
# {'title': 'The JD Set: 2010'}
# {'title': "JD Lawrence's the Clean Up Woman"}
# {'title': 'JD Charisma: Never Give Up'}
# {'title': 'Yellow Ox Mountain'}
# {'title': 'The Battle of Chantilly (Ox Hill)'}
# {'title': 'Golden Ox Inn'}
# {'title': 'The Year of the Ox'}
# {'title': 'The Ox'}
# {'title': 'The Wizard of Oz'}
# {'title': 'The Return of the Musk Ox'}
# {'title': 'The Wizard of Oz'}
# {'title': 'A Sussex Ox Wagon'}
# {'title': 'The Wonderful Wizard of Oz'}
# {'title': 'The New Wizard of Oz'}
# {'title': 'Return to Oz'}
# {'title': 'Oz the Great and Powerful'}
# {'title': 'Tom and Jerry & The Wizard of Oz'}
# {'title': 'Journey Back to Oz'}
# {'title': 'Rasmus på luffen'}
# {'title': "The Muppets' Wizard of Oz"}
# {'title': 'Mannen på balkongen'}
# {'title': 'Sällskapsresan eller Finns det svenskt kaffe på grisfesten'}
# {'title': 'Varg Veum - Skriften på veggen'}
# {'title': 'Scotland, Pa.'}
# {'title': 'Lotta på Bråkmakargatan'}
# {'title': 'Ma and Pa Kettle'}
# {'title': 'Revolution OS'}
# {'title': 'Os Trapalhões e o Mágico de Oróz'}
# {'title': 'Madicken på Junibacken'}
# {'title': 'P!nk: The King Is Dead... Unofficial'}
# {'title': "P!nk - I'm Not Dead: Bonus DVD"}
# {'title': 'Os saltimbancos Trapalhões'}
# {'title': 'A Princesa Xuxa e os Trapalhões'}
# {'title': 'Kung Fu-nk'}
# {'title': "P!nk: Fuckin' Perfect"}
# {'title': 'NK: El documental'}
# {'title': "P!NK: I'm Not Dead - Live from Wembley Arena"}
# {'title': 'Os Maias'}
# {'title': 'The Truth About P!Nk'}
# {'title': 'P!Nk: Greatest Hits ... So Far!!!'}
# {'title': 'P!Nk: Live in Europe'}
# {'title': "Lookin' Back with O.W. Bandy"}
# {'title': 'Dough Ray Me-ow'}
# {'title': 'The Whizzard of Ow'}
# {'title': 'Me-Ow!'}
# {'title': "It's Greek to Me-ow!"}
# {'title': 'O.W. Kenosha'}
# {'title': "O.W. Hout's & Sons, Inc."}
# {'title': 'Gunfight at OQ Corral'}
# {'title': 'Ow What!'}
# {'title': 'Aa Gaye Munde U.K. De'}
# {'title': 'Aa Okkati Adakku'}
# {'title': 'Aa bakudan'}
# {'title': 'Aa Gale Lag Jaa'}
# {'title': 'Shaadi Ke Side Effects'}
# {'title': 'Kaagaz Ke Phool'}
# {'title': 'Love Ke Liye Kuch Bhi Karega'}
# {'title': 'Sex-partijski neprijatelj br. 1'}
# {'title': 'Significant (Br)other'}
# {'title': 'Br-Zap!'}
# {'title': "40 mg d'amour par jour"}
# {'title': 'Anacefax sadico 50 mg.'}
# {'title': 'The In-between World of M.G. Vassanji'}
# {'title': 'Br(a)illiant'}
# {'title': 'Inside the Octagon 2, MG: 1946-1980'}
# {'title': 'Mg-2416'}
# {'title': 'Die Entnazifizierung des MH'}
# {'title': 'M.H. Rowley'}
# {'title': "MH-370's Enigma"}
# {'title': 'Olympia P.H.-m.H.'}
# {'title': 'Mr. & Mrs. Smith'}
# {'title': 'M.H. Pope Leo in a Chair'}
# {'title': 'Fantastic Mr. Fox'}
# {'title': 'Mr. Deeds'}
# {'title': "Mr. Bean's Holiday"}
# {'title': "Mr. Popper's Penguins"}
# {'title': 'The Shaggy D.A.'}
# {'title': 'Escanaba in da Moonlight'}
# {'title': 'Da Hip Hop Witch'}
# {'title': 'Uroczystosc otwarcia Uniwersytetu Warszawskiego w dn. 15.XI.1915 r.'}
# {'title': 'Febbre da cavallo'}
# {'title': 'Vai que dá Certo'}
# {'title': "Fakin' Da Funk"}
# {'title': 'La leggenda di Al, John e Jack'}
# {'title': 'Viaggi di nozze'}
# {'title': 'Filme da Treta'}
# {'title': 'Attila flagello di Dio'}
# {'title': 'Tutta colpa di Freud'}
# {'title': 'D.G. 4'}
# {'title': 'D.G. Movie Pioneer'}
# {'title': 'Il ragazzo di campagna'}
# {'title': 'D.F. (destino final)'}
# {'title': 'Exposición agricola y ganadera de San Jacinto, D.F.'}
# {'title': 'DF Tram & Cal-TV present The Great Movie Remix'}
# {'title': 'Wei Xiao Bao: Feng zhi gou nv'}
# {'title': 'Professori Uuno D.G. Turhapuro'}
# {'title': 'Fallon, NV: Deadly Oasis'}
# {'title': 'N.V. Gogol'}
# {'title': 'Wo shi nv wang'}
# {'title': "The D.T.'s"}
# {'title': "The D.T.'s; or, The Horrors of Drink"}
# {'title': 'Wie die Thüringer Turner der D.T. ins dritte Reich marschierten'}
# {'title': 'A Zen Life: D.T. Suzuki'}
# {'title': 'D.H. Lawrence: En busca de la serpiente'}
# {'title': 'Visions in Meditation #4: D.H. Lawrence'}
# {'title': "Good Ol' Freda"}
# {'title': "Good Ol' Freda"}
# {'title': "Bad Ol' Putty Tat"}
# {'title': '6 Desires: DH Lawrence and Sardinia'}
# {'title': 'Mutlu ol yeter'}
# {'title': "Little Ol' Bosko in Bagdad"}
# {'title': "Little Ol' Bosko and the Cannibals"}
# {'title': 'The GB Project'}
# {'title': 'El caso G.B.'}
# {'title': 'GB: 2525'}
# {'title': 'DP Fantasies 2'}
# {'title': 'Dorcel Airlines: Flight DP 69'}
# {'title': '10,000 Anal Maniacs 2: The D.P. Years'}
# {'title': 'The D.P. Man 2'}
# {'title': 'The D.P. Man'}
# {'title': "Bette Midler: Ol' Red Hair Is Back"}
# {'title': 'Anal and DP Gangbang'}
# {'title': 'DP Me'}
# {'title': 'DP My Wife with Me 4'}
# {'title': 'The Twins of the G.L. Ranch'}
# {'title': 'Shriek If You Know What I Did Last Friday the Thirteenth'}
# {'title': 'If Looks Could Kill'}
# {'title': 'What If'}
# {'title': 'The Hangover Part II'}
# {'title': 'Men in Black II'}
# {'title': 'Hellboy II: The Golden Army'}
# {'title': 'Back to the Future Part II'}
# {'title': 'Saw II'}
# {'title': 'Bad Boys II'}
# {'title': 'Blade II'}
# {'title': 'Il secondo tragico Fantozzi'}
# {'title': 'Sagan om Karl-Bertil Jonssons julafton'}
# {'title': 'Il marchese del Grillo'}
# {'title': 'Il mio miglior nemico'}
# {'title': 'Kurt Olsson - filmen om mitt liv som mej själv'}
# {'title': 'Kurt Josef Wagle og legenden om Fjordheksa'}
# {'title': "Anden live i Cirkusbygningen - Hva' snakker du om?"}
# {'title': 'Widaehan hunter GJ'}
# {'title': 'GJ Club@'}
# {'title': 'I.G.'}
# {'title': 'Mit csinált Felséged 3-tól 5-ig?'}
# {'title': 'World of Little Ig'}
# {'title': 'Anna ot 6 do 18'}
# {'title': 'Lora ot sutrin do vecher'}
# {'title': 'Ot 180 i vyshe'}
# {'title': 'Klyuch ot spalni'}
# {'title': 'Ot nishto neshto'}
# {'title': 'Secret Agent OO Soul'}
# {'title': 'OT: Our Town'}
# {'title': 'Oo-lee-byeol il-ho-wa eol-lug-so'}
# {'title': 'Rock Oo! Rimba bara kembali'}
# {'title': 'Oo na sige na'}
# {'title': 'Oo Nina Bobo'}
# {'title': 'Ot W Far'}
# {'title': 'Viimane öö'}
# {'title': "Oo ako'y espiya"}
# {'title': 'James Bande OO sexe'}
# {'title': 'Los 5 Faust de F.W. Murnau'}
# {'title': 'The Other Man: F.W. de Klerk and the End of Apartheid'}
# {'title': 'Oy!'}
# {'title': 'Pif-paf, oy-oy-oy!'}
# {'title': 'Oy Vey! My Son Is Gay!!'}
# {'title': 'Oy farfara farfara'}
# {'title': "Oy... Akin yata 'yan"}
# {'title': 'Oy Doktor!'}
# {'title': 'Ship, Oy, Oy!'}
# {'title': "Oy, It's a Boy!"}
# {'title': 'Bollywood im Alpenrausch'}
# {'title': 'Das Wirtshaus im Spessart'}
# {'title': '00 Schneider - Im Wendekreis der Eidechse'}
# {'title': 'Die Kirche bleibt im Dorf'}
# {'title': '100 Jahre Adolf Hitler - Die letzte Stunde im Führerbunker'}
# {'title': 'Im Himmel ist die Hölle los'}
# {'title': "J'aurais pu être une pute"}
# {'title': 'Gong pu II'}
# {'title': 'Jin pu sa'}
# {'title': 'Liu mang gong pu'}
# {'title': 'Katt Williams: The Pimp Chronicles Pt. 1'}
# {'title': 'American Fame Pt. 1: Drowning River Phoenix'}
# {'title': 'The Ku Klux Klan: A Secret History'}
# {'title': 'Big Movie Premiere: Harry Potter & the Deathly Hallows Pt. 1'}
# {'title': 'A Decade of Decadence, Pt. 2: Legacy of Dreams'}
# {'title': 'Ku Fu? Dalla Sicilia con furore'}
# {'title': 'Spam-ku'}
# {'title': 'Kochira Katsushika-ku Kameari kôen mae hashutsujo: The Movie'}
# {'title': 'Somay Ku: A Uganda Tennis Story'}
# {'title': 'Escape from L.A.'}
# {'title': 'Wenn lang die Bilder schon verblassen... KZ Theresienstadt - Propagandafilm und Wirklichkeit'}
# {'title': 'Ha/lf'}
# {'title': 'MI Really LF'}
# {'title': 'Diese verfluchten Stunden am Abend - Häftlingsbordelle im KZ'}
# {'title': 'KZ'}
# {'title': 'LD 50 Lethal Dose'}
# {'title': 'Kz'}
# {'title': '70. Jahrestag Befreiung des KZ Dachau'}
# {'title': 'The Cabinet of Dr. Caligari'}
# {'title': "Dr. Seuss' The Cat in the Hat"}
# {'title': "Cy's Triumph"}
# {'title': 'Dr. Dolittle 2'}
# {'title': 'The Abominable Dr. Phibes'}
# {'title': 'Bigfoot vs. D.B. Cooper'}
# {'title': 'Dr. Jekyll and Mr. Hyde'}
# {'title': 'The Testament of Dr. Mabuse'}
# {'title': 'Cy Warrior'}
# {'title': 'Cy Perkins in the City of Delusion'}
# {'title': 'On Reflection: B.S. Johnson on Dr. Samuel Johnson'}
# {'title': 'Luna-cy!'}
# {'title': "Mel Crow's CZ-918"}
# {'title': 'Bs As Subte'}
# {'title': 'Tanssija 100 dB:n hiljaisuudesta'}
# {'title': "Herc and D.B. in: What's All the Ruckus??"}
# {'title': 'B.S.'}
# {'title': 'B.S. I Love You'}
# {'title': 'Lego DC Comics Super Heroes: Justice League vs. Bizarro League'}
# {'title': 'Bs. As.'}
# {'title': 'BS Confidential'}
# {'title': 'Grinf*ckers AKA Corporate BS Artistes'}
# {'title': 'Mu mien jia sha'}
# {'title': 'Bs. As. Traffic Symphony'}
# {'title': 'DC Showcase Original Shorts Collection'}
# {'title': 'LEGO Batman: The Movie - DC Super Heroes Unite'}
# {'title': 'Bs As Hot Festival: Oasis'}
# {'title': 'DC Showcase: Jonah Hex'}
# {'title': 'Secret Origin: The Story of DC Comics'}
# {'title': 'UK/DK: A Film About Punks and Skinheads'}
# {'title': 'Robot Chicken: DC Comics Special'}
# {'title': 'Mock Up on Mu'}
# {'title': 'Mamma Mu och Kråkan'}
# {'title': 'Mu zhong wu ren'}
# {'title': "D.L. Hughley: Goin' Home"}
# {'title': 'Ke lian tian xia fu mu xin'}
# {'title': 'Antikiller D.K.'}
# {'title': 'Arkadaslik öldü mü?'}
# {'title': 'DL Presents: Ecordor'}
# {'title': 'Færøerne.dk'}
# {'title': 'Amin Jensen: Blæs på DK'}
# {'title': "Stand-up.dk Special: Thomas Wivel's vaffelbar"}
# {'title': 'D.L. Hughley: Unapologetic'}
# {'title': 'Gruppa MV-A10'}
# {'title': 'Jihad.dk'}
# {'title': 'DK'}
# {'title': 'On the D.L.'}
# {'title': "G.M. Whiting's Enemy"}
# {'title': 'D.L. Hughley: Reset'}
# {'title': 'D.L. Hughley: Clear'}
# {'title': 'D.L. Hughley: The Endangered List'}
# {'title': 'Coming Off the DL'}
# {'title': 'Alice MV'}
# {'title': 'Dawgz on the D.L.'}
# {'title': 'Farmer to Farmer: The Truth About GM Crops'}
# {'title': 'Pinky Presents Mz. Booty'}
# {'title': 'Heat M.V.'}
# {'title': "GM Video #242: Labor Day Wet T&A '99, Vols. 1-3"}
# {'title': 'Mactabilis Voluntas (M.V.)'}
# {'title': 'DL Hughley: Shocked and Appalled'}
# {'title': 'G.M.'}
# {'title': 'The Last Truck: Closing of a GM Plant'}
# {'title': 'G.M. különös élete'}
# {'title': "G.M. Whiting's: Notes"}
# {'title': 'The GM Affair'}
# {'title': 'Socha Na Tha'}
# {'title': "Sure Shot Dombrowski 3 Moving on Up: The GM's Office"}
# {'title': 'Paradi-gm'}
# {'title': 'No Strings Attached'}
# {'title': 'God Is My DJ'}
# {'title': 'See No Evil, Hear No Evil'}
# {'title': 'Alexander and the Terrible, Horrible, No Good, Very Bad Day'}
# {'title': 'Main Hoon Na'}
# {'title': 'DJ Snake and Lil Jon: Turn Down for What'}
# {'title': 'Fantasy Aquarium Nintendo DS Music Video'}
# {'title': 'Hang the DJ'}
# {'title': 'DS Part 2'}
# {'title': 'Little DJ: Chiisana koi no monogatari'}
# {'title': 'L.A. D.J.'}
# {'title': 'Oj! Nie moge sie zatrzymac!'}
# {'title': 'DJ Quik: Visualism - The Art of Sound Into Vision'}
# {'title': 'Rock DJ'}
# {'title': 'Rick vs. DS'}
# {'title': "O.J. Simpson: If I Did It, Here's How It Happened"}
# {'title': 'Escape from DS-3'}
# {'title': 'Kurt, Mungo, BP and Me'}
# {'title': 'OJ Simpson: Monster or Myth?'}
# {'title': 'DS Part 1'}
# {'title': 'O.J. Simpson: Juice on the Loose'}
# {'title': 'David Dimbleby Looks at the BP Tanker Company'}
# {'title': 'DS 70 nevyjizdi'}
# {'title': 'Gamer Rage II: DS Cases'}
# {'title': 'OJ: The Musical'}
# {'title': 'The Trial of O.J. Simpson'}
# {'title': 'O.J.: A Study in Black & White'}
# {'title': 'O.J. Speaks: The Hidden Tapes'}
# {'title': 'BP Spills Coffee'}
# {'title': 'Juiced with O.J. Simpson'}
# {'title': 'The Increasing Human Devastation from the BP Blowout'}
# {'title': 'Ikaria BP 1447'}
# {'title': 'BP (Pushing the Boundaries)'}
# {'title': 'Oh, God! You Devil'}
# {'title': 'Aero NT-54'}
# {'title': 'Riki-Oh: The Story of Ricky'}
# {'title': 'Come Hell or High Water: Corollary of the BP Deepwater Horizon Oil Spill Disaster'}
# {'title': 'Sweet Talk, Sweet Talk: Remembering Those Affected by the BP Oil Spill Crisis'}
# {'title': 'I.H. ora miden'}
# {'title': 'Sharknado 3: Oh Hell No!'}
# {'title': 'Oh, God!'}
# {'title': 'Louis C.K. Oh My God'}
# {'title': 'BP: $30 Billion Blowout'}
# {'title': 'Yu-Gi-Oh!: The Movie'}
# {'title': 'Oh! What a Lovely War'}
# {'title': 'Sentido NT'}
# {'title': 'Oh Heavenly Dog'}
# {'title': 'Boy@nt!'}
# {'title': 'Fake ID'}
# {'title': 'Blue Cercle KW'}
# {'title': 'Ih, du forbarmende'}
# {'title': 'Northern Lights: A Season with NT Thunder'}
# {'title': "La grande parade d'Olivier Py"}
# {'title': 'Delez LUZ-a v razvoju Ljubljane v zadnjih 25-ih letih'}
# {'title': 'Na iache rsoxoqui so qá'}
# {'title': 'Thu Kyun Ma Khan Py'}
# {'title': 'Zivot pise romane ali nema ko da ih cita'}
# {'title': 'The KW Project'}
# {'title': 'Fake ID'}
# {'title': 'ID Swiss'}
# {'title': 'KY Kapers'}
# {'title': 'LG World Championships of Freestyle Motocross'}
# {'title': 'Harold & Kumar Go to White Castle'}
# {'title': 'Just Go with It'}
# {'title': 'Go'}
# {'title': 'LG at Google I/O'}
# {'title': 'the ky.pbn MOVIE'}
# {'title': "Let's Go to Prison"}
# {'title': 'Louisville Commandery, Louisville, Ky.'}
# {'title': 'To Be or Not LB'}
# {'title': 'IPSC Pan American Shotgun Championship: Rockcastle Shooting Center at Park Mammoth Resort, Park City, KY, July 29 - August 1, 2010'}
# {'title': 'Knights Templar Parade at Louisville, Ky.'}
# {'title': 'The Tragedy of Ky Young'}
# {'title': 'LG Action Sports World Tour Stop #6: Paris, BMX'}
# {'title': 'Ryan Cabrera: Live at the Wiltern LG'}
# {'title': 'LG Action Sports Championships'}
# {'title': 'LG Action Sports World Tour Stop #6: Paris, Skateboarding'}
# {'title': 'LG and Lucky Are Friends'}
# {'title': 'Qo'}
# {'title': 'Twenty One Pilots: Live from the LC'}
# {'title': '650-lb Virgin: The Weight Is Over'}
# {'title': '650-lb Virgin'}
# {'title': 'Nightmare on L.B. Street'}
# {'title': 'Geheimzeichen LB 17'}
# {'title': 'Sr. L.B.'}
# {'title': 'LB vs AR'}
# {'title': "627 lb. Woman: Jackie's Story"}
# {'title': "Message of K.T's Footsteps"}
# {'title': 'Heshtje që flet'}
# {'title': 'Le Chef'}
# {'title': 'QC Redemption II'}
# {'title': 'QC Notorious'}
# {'title': "An Island's Legacy: Preparing for TT"}
# {'title': 'U omãi qe dava pulus'}
# {'title': 'The Jury: Emma Watts QC'}
# {'title': 'Asses Galore 5: T.T. vs. the World'}
# {'title': 'Musa Hoti - Kosova eshte gjaku im qe nuk falet'}
# {'title': 'VM-Krönikan 2006'}
# {'title': 'Unitet që mposht tërmete'}
# {'title': 'Kujdes nga lëndët që përdoren kundër dëmtonjësve në bujqësi'}
# {'title': 'El rapto de T.T.'}
# {'title': 'The Trouble with TQ'}
# {'title': 'Joey: The Man Who Conquered the TT'}
# {'title': 'Tribulation TT with Kyp Kyp Levoux'}
# {'title': "T.T.'s Oriental Adventure"}
# {'title': 'T.T el taterrestre'}
# {'title': "An Island's Legacy: TT Entertainment"}
# {'title': 'Ascending Mt. Low, California'}
# {'title': 'Run It with VMware: V.M. Waré Construction Co.'}
# {'title': 'TT 5446'}
# {'title': 'Fotbolls-VM krönikan 1994'}
# {'title': 'Hot Tw*t'}
# {'title': 'Mod målet - VM for hjemløse'}
# {'title': 'Panoramic View Near Mt. Golden on the Canadian Pacific R. R.'}
# {'title': "My Best Friend's Wedding"}
# {'title': 'Lick Observatory, Mt. Hamilton, Cal.'}
# {'title': 'Mt. Everest: The Fatal Climb'}
# {'title': 'Olsen-banden og Dynamitt-Harry går amok'}
# {'title': 'Salt Lake City Company of Rocky Mt. Riders'}
# {'title': "Dude, Where's My Car?"}
# {'title': "She's Out of My League"}
# {'title': 'My Neighbor Totoro'}
# {'title': 'My Cousin Vinny'}
# {'title': 'Studie Nr. 5'}
# {'title': "Under the Shadow of Mt. Stephen, Passing Field's Station in the Rocky Mountains"}
# {'title': "That's My Boy"}
# {'title': 'Olsen-banden møter kongen og knekten'}
# {'title': 'Sperrgebiet Nr.1'}
# {'title': 'Karius og Baktus'}
# {'title': 'Solan og Ludvig - Jul i Flåklypa'}
# {'title': 'Mädchen Nr. 1'}
# {'title': 'Olsen-banden og Dynamitt-Harry'}
# {'title': 'Everything Will Be Ok'}
# {'title': 'Olsenbanden og Dynamitt-Harry mot nye høyder'}
# {'title': 'Nr. 1 - Aus Berichten der Wach- und Patrouillendienste'}
# {'title': 'Aggro Berlin - Ansage Nr. 1'}
# {'title': 'Rebus Film Nr. 1'}
# {'title': 'M.D. Geist II'}
# {'title': 'OK Kanmani'}
# {'title': 'Ok'}
# {'title': 'Ready? OK!'}
# {'title': 'M.D. Geist'}
# {'title': 'Sokrovishcha O.K.'}
# {'title': 'Deutsche Wochenschau Nr. 681/40/1943'}
# {'title': 'OE.20 Live in Kyiv'}
# {'title': 'House, M.D., Season Four: New Beginnings'}
# {'title': 'Carnaby, M.D.'}
# {'title': 'Betty Boop, M.D.'}
# {'title': 'Abflug LH 646'}
# {'title': 'House, M.D., Season Four: My Favorite Episode So Far...'}
# {'title': 'Irish Mail, L. & N.W. Railway, Taking Up Water at Full Speed'}
# {'title': 'The Disappearance of the PX-15'}
# {'title': 'LH 615 - Operation München'}
# {'title': 'The Demon of Mount Oe'}
# {'title': 'Code Name Black Cat o oe'}
# {'title': 'Ein Abend mit O.E. Hasse'}
# {'title': 'Aloha Oe'}
# {'title': 'Oe-gyu-so-nyeo, bul-si-chak-hada'}
# {'title': 'Slatko od snova'}
# {'title': 'Seki A Oe: A Crazy Samoan Love Story'}
# {'title': 'N or NW'}
# {'title': 'Holiday Trip to the Clyde Coast of Scotland Via L. & N.W. Railway'}
# {'title': 'NX Files: Discover the Secret'}
# {'title': 'Graphite on Canvas, 1920 x 1080 px'}
# {'title': 'QB Game Analysis'}
# {'title': 'Sok od sljiva'}
# {'title': 'Tie Xi Qu: West of the Tracks'}
# {'title': 'PX This'}
# {'title': 'QQ Speed'}
# {'title': 'Some QB That I Used to Know: Gotye Parody'}
# {'title': 'Projekt dziecko, czyli ojciec potrzebny od zaraz'}
# {'title': '89 mm od Europy'}
# {'title': 'Makedonski del od pekolot'}
# {'title': 'Doktor od jezera hrochu'}
# {'title': 'Covik od svita'}
# {'title': 'Tie Xi Qu: West of the Tracks'}
# {'title': 'TR(A) the Restricted Artistic'}
# {'title': 'Od 3 do 22'}
# {'title': 'Tie Xi Qu: West of the Tracks'}
# {'title': 'Qu mo dao zhang'}
# {'title': 'Jun fa qu shi'}
# {'title': 'Nömadak Tx'}
# {'title': 'Da gong kuang xian qu'}
# {'title': 'The Professional TR Course'}
# {'title': 'The Different TR Courses and Their Criticism'}
# {'title': 'Oc Tr'}
# {'title': 'Nakajima Miyuki Live & PV: Utahime gekijouban'}
# {'title': 'S.S. Doomtrooper'}
# {'title': 'TR: An American Lion'}
# {'title': 'Sincerely, P.V. Reese'}
# {'title': 'Anime Festival Asia PV'}
# {'title': 'tx-transform'}
# {'title': 'Third Ward TX'}
# {'title': 'Flesh, TX'}
# {'title': 'Uncertain, Tx'}
# {'title': 'Psycho City, TX'}
# {'title': 'The Black Keys: Live in Austin, TX'}
# {'title': 'Gde ty, Bagira?'}
# {'title': 'SS Experiment Camp'}
# {'title': 'Ilsa: She Wolf of the SS'}
# {'title': "Waffen SS: Hitler's Elite Fighting Force"}
# {'title': 'Ty - mne, ya - tebe'}
# {'title': 'Bordel SS'}
# {'title': 'I Was an MTV VJ'}
# {'title': 'Ish ty, maslenitsa!'}
# {'title': 'Vsyo, chto ty lyubish'}
# {'title': 'O sport, ty - mir!'}
# {'title': 'VJ Day & Homecoming'}
# {'title': 'A chtoy-to ty vo frake?'}
# {'title': 'Sólo con tu pareja'}
# {'title': 'About VD'}
# {'title': 'Que pena tu boda'}
# {'title': 'Come tu mi vuoi'}
# {'title': 'Wanna Be a VJ Too'}
# {'title': 'VJ Day 60th Anniversary'}
# {'title': 'TV: The Movie'}
# {'title': 'Mad Love: V.J. Smith and Mad Dads'}
# {'title': 'Myx Adventures: VJ Chino in Japan'}
# {'title': 'Wanna Be a VJ 3'}
# {'title': 'Burma VJ: Reporter i et lukket land'}
# {'title': 'Frankie Boyle Live 2: If I Could Reach Out Through Your TV and Strangle You I Would'}
# {'title': 'VJ Search'}
# {'title': 'How to Keep from Catching VD'}
# {'title': 'VD Blues'}
# {'title': 'VD Attack Plan'}
# {'title': 'V.D: Name Your Contacts'}
# {'title': 'Melekler ve kumarbazlar'}
# {'title': 'Känd från TV'}
# {'title': 'Showrunners: The Art of Running a TV Show'}
# {'title': 'Charlotta-TS'}
# {'title': 'U2: Zoo TV Live from Sydney'}
# {'title': 'TV Nation: Volume Two'}
# {'title': 'TV Junkie'}
# {'title': 'TS Playground 5'}
# {'title': 'U2: Zoo TV Live from Sydney'}
# {'title': 'TV Nation: Volume One'}
# {'title': 'Pamuk Prenses ve 7 cüceler'}
# {'title': 'VH-1: Still Wanted'}
# {'title': 'Moral Bozuklugu ve 31'}
# {'title': 'Robinson Crusoe ve Cuma'}
# {'title': 'Dedem, gofret ve ben'}
# {'title': 'TS Playground 2'}
# {'title': 'Star Trek VI: The Undiscovered Country'}
# {'title': 'TS Playground'}
# {'title': 'TS Playground 4'}
# {'title': 'TS Playground 3'}
# {'title': 'TS Playground 7: Ebony Edition'}
# {'title': 'TS Playground 6'}
# {'title': 'VH-1 Where Are They Now: TV Hunks'}
# {'title': "VH-1: Pop Up Video 80's"}
# {'title': 'VH-1 to One: Paula Abdul'}
# {'title': 'VH-1 to One: The Corrs'}
# {'title': 'V.I. Warshawski'}
# {'title': 'Saw VI'}
# {'title': 'The Land Before Time VI: The Secret of Saurus Rock'}
# {'title': 'Vi hade i alla fall tur med vädret'}
# {'title': 'Rocky VI'}
# {'title': 'Fascisti su Marte'}
# {'title': 'Svemirci su krivi za sve'}
# {'title': 'Bij de beesten af'}
# {'title': 'Chi wo sû uchû'}
# {'title': 'Vampiri su medju nama'}
# {'title': 'Zigeunerdans af troubaduren'}
# {'title': 'Biblen fortolket af Brian Mørk og Christian Fuhlendorff'}
# {'title': 'Onkel Danny - Portræt af en karma cowboy'}
# {'title': "Tarantellen af 'Napoli'"}
# {'title': 'Ib Schønberg - et portræt af Danmarks største filmskuespiller'}
# {'title': 'Skyggen af tvivl'}
# {'title': 'Ak-Meer'}
# {'title': 'Titan A.E.'}
# {'title': 'Ae Jugara Krushna Sudama'}
# {'title': 'AE: Apocalypse Earth'}
# {'title': 'Cheol-ae-kum'}
# {'title': 'A.K.'}
# {'title': 'AK and Beyond'}
# {'title': 'Ak-47 Wanted'}
# {'title': 'Dung-aw'}
# {'title': 'Ak-47 temible cuerno de chivo'}
# {'title': 'Ak-47 Wanted 2'}
# {'title': 'Life Is Good in Ak'}
# {'title': 'MAD V1deo Music Aw@rds 2010'}
# {'title': 'Saphai breu... aw aw'}
# {'title': "Aw, Crap! It's a Musical?"}
# {'title': 'Aw, Nurse'}
# {'title': 'The Gods Must Be Crazy'}
# {'title': 'To Be or Not to Be'}
# {'title': 'The Man Who Would Be King'}
# {'title': "Let's Be Cops"}
# {'title': "Don't Be a Menace to South Central While Drinking Your Juice in the Hood"}
# {'title': "Ah, L'Amour"}
# {'title': 'Ah Boys to Men'}
# {'title': 'Be Cool'}
# {'title': 'Ah Nerede'}
# {'title': 'Ah Long Pte Ltd'}
# {'title': 'Ah, Sweet Mouse-Story of Life'}
# {'title': 'Ai Weiwei: Never Sorry'}
# {'title': 'Ah Pook Is Here'}
# {'title': 'A.I. Assault'}
# {'title': 'Ai-en-ji'}
# {'title': 'E Aí... Comeu?'}
# {'title': "Un'estate ai Caraibi"}
# {'title': 'Anplagghed al cinema'}
# {'title': 'I Am Number Four'}
# {'title': 'Generation Ax'}
# {'title': 'Who Am I?'}
# {'title': 'The Ballad of Big Al'}
# {'title': 'Al-irhab wal kabab'}
# {'title': "Ljubi, ljubi, al' glavu ne gubi"}
# {'title': "'Weird Al' Yankovic: The Ultimate Video Collection"}
# {'title': "'Weird Al' Yankovic: The Videos"}
# {'title': 'The Ax Fight'}
# {'title': "The Ax Man Enigma: The Real-life Horror Behind 'Slay Utterly'"}
# {'title': 'Day of the Ax'}
# {'title': 'Ax'}
# {'title': 'RE:AX aka Peace Starts With Me'}
# {'title': 'Appleseed Saga: Ex Machina'}
# {'title': 'The Ex-Mrs. Bradford'}
# {'title': 'Az elvarázsolt dollár'}
# {'title': 'Az igazi Mao'}
# {'title': 'Egy tél az Isten háta mögött'}
# {'title': 'Az oroszlán ugrani készül'}
# {'title': 'My Super Ex-Girlfriend'}
# {'title': 'The Ex'}
# {'title': 'Ex'}
# {'title': 'Burying the Ex'}
# {'title': '3 hommes et un couffin'}
# {'title': 'E.T. the Extra-Terrestrial'}
# {'title': 'Le moine et le poisson'}
# {'title': 'Tintin et les oranges bleues'}
# {'title': 'CD Ram: Sex Star Interactive'}
# {'title': 'Du jour au lendemain'}
# {'title': 'Au Pair'}
# {'title': 'Au bout du monde'}
# {'title': 'Poulet au vinaigre'}
# {'title': 'Au Pair II'}
# {'title': 'La cuisine au beurre'}
# {'title': 'C.D. Graham Swimming the Lower Rapids'}
# {'title': 'Tercera feria del libro de la cd. de México'}
# {'title': 'CD-Rom'}
# {'title': 'The CD Shop'}
# {'title': 'CD Hoy: Portraits from the Frontier'}
# {'title': "James & Kathy's CD Drop"}
# {'title': 'CD:UK Dance Workout'}
# {'title': "Une journée bien remplie ou Neuf meurtres insolites dans une même journée par un seul homme dont ce n'est pas le métier"}
# {'title': '33 cm! Das Monster im Arsch'}
# {'title': 'Ce soir, je dors chez toi'}
# {'title': 'Frank McKlusky, C.I.'}
# {'title': 'Nos héros sont morts ce soir'}
# {'title': 'A.Li.Ce'}
# {'title': 'Est-ce bien raisonnable?'}
# {'title': "Ce n'è per tutti"}
# {'title': '22 cm oder einige Erlebnisse des stellungssuchenden Gerd M.'}
# {'title': 'Ci hai rotto papà'}
# {'title': 'WWE: CM Punk - Best in the World'}
# {'title': '30 cm zgvis donidan'}
# {'title': '30 cm de Pica e Demais'}
# {'title': '35x50 cm'}
# {'title': '5 CM Peter'}
# {'title': 'The Hobbit: An Unexpected Journey'}
# {'title': 'Ci vuole un gran fisico'}
# {'title': 'La dottoressa ci sta col colonnello'}
# {'title': 'Huang jia shi jie zhi III: Ci xiong da dao'}
# {'title': 'Ci vediamo domani'}
# {'title': 'Vakantiefilm BV'}
# {'title': 'Pata Nahi Rabb Kehdeyan Rangan Ch Raazi'}
# {'title': 'An Inconvenient Truth'}
# {'title': 'An American Werewolf in London'}
# {'title': 'Fu Manchu Ch. 13 Watch Your Step'}
# {'title': 'So I Married an Axe Murderer'}
# {'title': 'BV-01'}
# {'title': 'Roy Chubby Brown: Jingle Bx@!cks'}
# {'title': 'Specificnosti u rukovanju i odrzavanju terenskog vozila TAM 110 T7 BV'}
# {'title': 'Cj Platinum Live and Unplugged'}
# {'title': 'Summer CH Counterpoint'}
# {'title': 'Are You A Ch*t*ya? Part 2'}
# {'title': 'C.B.'}
# {'title': 'À la découverte de la BN'}
# {'title': 'Factor CH'}
# {'title': 'BX. Thug Soldiers'}
# {'title': 'Avro Canuck... CF-100 All Weather Interceptor'}
# {'title': "C.J.'s Bondage Adventure"}
# {'title': 'Pack Attack 3: C.J. Knight'}
# {'title': 'CJ Wilson Douche Bags'}
# {'title': 'C.B. Hustlers'}
# {'title': 'CJ Hendry: Pen on Paper'}
# {'title': 'Ranjit Sinhji and C.B. Fry at the Wickets'}
# {'title': 'Ready When You Are, CB'}
# {'title': "A Day with C.B. Fry's Mercury Boys"}
# {'title': 'Avro Arrow: CF-105 a Short History'}
# {'title': 'Young, Deaf and CF'}
# {'title': 'Tiger Pride: Eight Decades of CC Hockey'}
# {'title': 'CF girl: Onanie shower'}
# {'title': 'CF: Two Little Letters'}
# {'title': 'CF gâru'}
# {'title': 'Bo Burnham: what.'}
# {'title': 'Governor C.C. Young Hails Greater Talkie Season'}
# {'title': 'C.B. Mamas'}
# {'title': 'Three Cases for CC Brite'}
# {'title': "CC Coletti's: Trouble with Me"}
# {'title': 'CC 2010'}
# {'title': 'C.C. gâruzu fâsuto ran: Kaze o dakishimete'}
# {'title': 'The World Within: C.G. Jung in His Own Words'}
# {'title': 'CC: Stand-Up - The Bonnaroo Experience'}
# {'title': "CC Coletti's: Mercedes Benz"}
# {'title': 'CC Variety TV'}
# {'title': 'Bu Iste Bir Yalnizlik Var'}
# {'title': 'Bo Burnham: Words, Words, Words'}
# {'title': 'Bo ming chan dao duo ming qiang'}
# {'title': 'Dan sun bo lok'}
# {'title': 'Nereden çikti bu velet'}
# {'title': "L'Empire Bo$$é"}
# {'title': 'Tae-Bo Workout: Basic'}
# {'title': 'Man bo nu lang'}
# {'title': 'Nereye bakiyor bu adamlar'}
# {'title': 'Bu jian bu san'}
# {'title': 'Xin tian long ba bu zhi tian shan tong lao'}
# {'title': 'Ay Lav Yu'}
# {'title': 'Modern Greeks: C.P. Cavafy'}
# {'title': 'GameCenter CX: The Movie - 1986 Mighty Bomb Jack'}
# {'title': 'Sule, Ay Need You'}
# {'title': '¡Ay, qué tiempos señor don Simón!'}
# {'title': 'Cl/h'}
# {'title': 'Sayonara CP'}
# {'title': 'CP Castings'}
# {'title': 'Ay! Ay! Ramon'}
# {'title': 'Yrrol - En kolossalt genomtänkt film'}
# {'title': 'Romance @ C.P. Coaching'}
# {'title': 'CP Trainer'}
# {'title': 'CP Time'}
# {'title': 'C.P. Research Institute'}
# {'title': 'CP Family Reunion'}
# {'title': "Ma vie en l'air"}
# {'title': 'Indieboyz Cl!maxed'}
# {'title': '10 Ez Steps for Mortician Success'}
# {'title': 'En gång i Phuket'}
# {'title': 'Hälsoresan - En smal film av stor vikt'}
# {'title': 'Search for a CW Star'}
# {'title': 'Arc-en-CL'}
# {'title': 'EZ Money'}
# {'title': 'Ez történt Budapesten'}
# {'title': 'Santa Fe'}
# {'title': 'Örült szerelem ez'}
# {'title': 'Ez-Chewie'}
# {'title': 'Kire ütött ez a gyerek?'}
# {'title': 'Ez Már Nemcsak Játék'}
# {'title': 'EZ Bake'}
# {'title': 'Lights of Old Santa Fe'}
# {'title': 'CW: Hard Labour'}
# {'title': 'Search for a CW Star'}
# {'title': 'CW (Carwash)'}
# {'title': 'Fe Mahatet masr'}
# {'title': 'L!fe Happens'}
# {'title': 'CW: Suprise Suprise'}
# {'title': 'Mo fa a ma'}
# {'title': 'Santa Fe Stampede'}
# {'title': 'Santa Fe Passage'}
# {'title': 'Calle Santa Fe'}
# {'title': 'The Excitement of the Do-Re-Mi-Fa Girl'}
# {'title': 'Here Come the Co-eds'}
# {'title': 'La poliziotta fa carriera'}
# {'title': 'The Fair Co-Ed'}
# {'title': 'Fa qian han'}
# {'title': 'Fb'}
# {'title': 'Your Mother Is a FB'}
# {'title': 'Macross FB 7: Ore no Uta o Kike!'}
# {'title': 'Hua pi zhi: Yin yang fa wang'}
# {'title': 'Co mi zrobisz, jak mnie zlapiesz'}
# {'title': 'FB: Fighting Beat'}
# {'title': 'The Culpepper Cattle Co.'}
# {'title': 'Mr. C.N. Morton'}
# {'title': 'How to Beat the High Co$t of Living'}
# {'title': 'Samrat & Co.'}
# {'title': 'Dancing Co-Ed'}
# {'title': "On the Set of 'CQ'"}
# {'title': 'CR No: 89'}
# {'title': 'CR:SR Test národa 2006'}
# {'title': 'CR:SR Test národa 2007'}
# {'title': 'E.ON Energy Globe Award CR 2008'}
# {'title': 'Vzpomínky na zvírecí koncentráky v CR 2002'}
# {'title': 'Vzpomínky na zvírecí koncentráky v CR 2009'}
# {'title': 'E.ON Energy Globe Award CR 2010'}
# {'title': 'E.ON Energy Globe Award CR 2011'}
# {'title': 'C.S. Lewis: Beyond Narnia'}
# {'title': 'The Notorious C.R'}
# {'title': 'C.S. Lewis: Dreamer of Narnia'}
# {'title': 'The Magic Never Ends: The Life and Work of C.S. Lewis'}
# {'title': 'The Shortest Way Home: C.S. Lewis and Mere Christianity'}
# {'title': 'The Heavens Are Telling the Glory of God: The Theological Imagination of CS Lewis'}
# {'title': 'O cs. studentech'}
# {'title': 'Affectionately Yours, Screwtape: The Devil and C.S. Lewis'}
# {'title': "Narnia's Lost Poet: The Secret Lives and Loves of CS Lewis"}
# {'title': 'Louis C.K.: Chewed Up'}
# {'title': 'Louis C.K.: Live at the Beacon Theater'}
# {'title': 'Louis C.K.: Shameless'}
# {'title': 'Louis C.K.: Hilarious'}
# {'title': 'C.K. dezerterzy'}
# {'title': 'Go F*ck Yourself with Dave Franco'}
# {'title': 'Louis C.K. Learns About the Catholic Church'}
# {'title': "Louis C.K.'s Last Chance"}
# {'title': 'Louis C.K.: Live at the Comedy Store'}
# {'title': 'The Road to El Dorado'}
# {'title': 'The Haunted World of El Superbeasto'}
# {'title': 'El Narco'}
# {'title': 'Liverpool FC: Champions of Europe 2005'}
# {'title': 'F.C. De Kampioenen: Kampioen zijn blijft plezant'}
# {'title': 'FC Venus'}
# {'title': 'FC Venus'}
# {'title': 'F.C. De Kampioenen 2: Jubilee general'}
# {'title': 'Liverpool FC: 501 Goals'}
# {'title': 'Arsenal FC: 501 Goals'}
# {'title': '100 Jahre FC Bayern'}
# {'title': 'Las ibéricas F.C.'}
# {'title': 'J.G. Ballard: The Future Is Now'}
# {'title': 'JK Enum Nanbanin Vaazhkai'}
# {'title': 'J.K. Rowling: A Year in the Life'}
# {'title': 'The Magical World of Harry Potter: The Unauthorized Story of J.K. Rowling'}
# {'title': 'Chelsea FC: 100 Great Goals'}
# {'title': 'Conversation with J.K. Rowling and Steve Kloves'}
# {'title': 'The JK Years: A Political Trajectory'}
# {'title': 'JK Rowling and the Harry Potter Express'}
# {'title': 'JK Rowling: The Interview'}
# {'title': 'Gau ban ji ma goon ji baak min bau ching tin'}
# {'title': 'Hamipanshitemo kinishinai! JK bishoujo ga taisougi (buruma) ni natte ecchi ni kaiketsushichau houkago soudanshitsu'}
# {'title': 'Sardaar Ji'}
# {'title': 'Bha Ji in Problem'}
# {'title': '98 goo waak chai ji lung chang foo dau'}
# {'title': 'Jiang shi jia zu: Jiang shi xian sheng xu ji'}
# {'title': 'La vérité si je mens!'}
# {'title': "Je t'aime John Wayne"}
# {'title': 'Je fais le mort'}
# {'title': 'J.M. Mondésir'}
# {'title': 'J.M. Barrie, la vérité sur Peter Pan'}
# {'title': 'Correspondencia Jonas Mekas - J.L. Guerin'}
# {'title': 'JM After Dark: Volume 1, Issue 1'}
# {'title': 'Deconstructing JL: War with Jay Oliva and Jim Lee dvd-extra'}
# {'title': 'Jeuh kieh a jm hm kahun'}
# {'title': 'Mere Dad Ki Maruti'}
# {'title': 'Mumbai 125 KM 3D'}
# {'title': 'Viyah 70 Km'}
# {'title': '1735 Km'}
# {'title': '7915 Km'}
# {'title': 'Cinema 500 km'}
# {'title': 'KK Family List'}
# {'title': '7 km da Gerusalemme'}
# {'title': 'Who Is KK Downey?'}
# {'title': 'KL 10 Patthu'}
# {'title': 'Pet filmova o Nives K.K.'}
# {'title': 'Nevoljite na pokojniot K.K'}
# {'title': 'KK 17'}
# {'title': 'Evolusi: KL Drift 2'}
# {'title': 'K.K. Steincke'}
# {'title': 'KL Gangster 2'}
# {'title': 'Iznenadna i prerana smrt pukovnika K.K'}
# {'title': 'Evolusi: KL Drift'}
# {'title': 'Väckning kl. 06.00'}
# {'title': 'Dir en Grey: [KR] Cube'}
# {'title': 'KL Gangster'}
# {'title': 'Lauri Kr. Relander 1925-1931'}
# {'title': 'Chief Minister K.R. Gowthami'}
# {'title': 'Review of British Navy at Southend End and Spithead: Lt. Shackleton on Board Armadale Castle'}
# {'title': 'Raumfahrt als inneres Erlebnis: Gen. Lt. Pugatschow bei Stromsperre in Baikonur'}
# {'title': 'Lt. Elmo Ramas: Sundalo'}
# {'title': 'LT: The Life & Times'}
# {'title': 'Lt. Col. Alejanndro Yanquling, WPD'}
# {'title': 'In Conversation: Director L.Q. Jones & Writer Harlan Ellison'}
# {'title': 'Lt. Robin Crusoe, U.S.N.'}
# {'title': 'Von Zeppelin 1 bis LZ 130'}
# {'title': 'Five Days in Winter: The LT Sean Snyder Story'}
# {'title': 'Lv-225'}
# {'title': 'homo@lv'}
# {'title': 'Lt. Nicho-las Aguirre: Batas ko ang iiral'}
# {'title': 'LZ Lost'}
# {'title': 'La chance de ma vie'}
# {'title': 'Lt. Dan Band: For the Common Good'}
# {'title': 'The Decline of the Century: Testament L.Z.'}
# {'title': 'LV 16'}
# {'title': 'Nie ma mocnych'}
# {'title': 'Don Camillo monsignore... ma non troppo'}
# {'title': 'Ma-ma'}
# {'title': 'M.B. Curtis'}
# {'title': 'M.B. - Doamna cu trandafiri'}
# {'title': 'ND - Deutsches Neuland'}
# {'title': 'Nc 87'}
# {'title': 'Kannapolis, N.C.'}
# {'title': 'Obama in NC: The Path to History'}
# {'title': "The Rangers Jerkin Ain't Dead Greenville NC"}
# {'title': 'Fu(nd) This!'}
# {'title': 'Small Town, USA: Andrews, NC'}
# {'title': 'N.H. Habitat'}
# {'title': 'Onward Notre Dame: ND in Indy'}
# {'title': 'NC Film Project Preview'}
# {'title': 'N.H. 47'}
# {'title': 'NH-8: Road to Nidhivan'}
# {'title': 'Lumberton, NC'}
# {'title': 'Peace Envoys at Portsmouth, N.H.'}
# {'title': 'Sin ton ni Sonia'}
# {'title': 'Ni un hombre más'}
# {'title': 'The Fantastic World of M.C. Escher'}
# {'title': 'Boku wa imôto ni koi wo suru'}
# {'title': 'The MC: Why We Do It'}
# {'title': 'Mc Dandik'}
# {'title': 'Show Me Your Genitals 2: E=MC Vagina'}
# {'title': 'Metamorphose: M.C. Escher, 1898-1972'}
# {'title': 'M.C. Escher: Sky and Water 1'}
# {'title': 'Lu tempu di li pisci spata'}
# {'title': 'The Life and Times of MC Beer Bong'}
# {'title': 'MC Hammer: 2 Legit - The Videos'}
# {'title': 'Hessians MC'}
# {'title': 'Toy Story 3'}

# %% [markdown]
# ## Ejercicio 4: Conceptos avanzados de Base de Datos: MySQL y Mongo
#
# - <b>Indíce: optimización de consultas</b>
#
# Referencias:
# - Indíces en Mongo: https://docs.mongodb.com/manual/indexes/
# - Indíces en MySQL: https://dev.mysql.com/doc/refman/8.0/en/optimization-indexes.html
# - Introducción a indíces en MySQL: https://www.adictosaltrabajo.com/2015/09/11/introduccion-a-indices-en-mysql/
#
# 1) ¿Qué es un Indíce y de qué sirve?
#
#     Es una dirección de memoria que apunta a una tabla o un conjunto de estas
#
# 2) ¿Cuándo los SGBDs utilizan los Indíces?
#
#     Los indices se usan cuando se quiere realizar muchas consultas y se quiere optimizar en tiempo
#
# 3) ¿Cuáles son los tipos de Indíces en MySQL y Mongo?
#
#     En MySQL existe: PRIMARY KEY | INDEX | UNIQUE | FULL TEXT | SPATIAL
#     En Mongo existe: Simple | Compuesto | Unico | Sparse | Hash | Array | Texto | Geoposicion
#
# 4) Si los indíces son utiles, ¿por qué no crear indíces por cada columna/atributo? ¿Cuáles son los límimtes?
#
# Porque crear y actualizar un indice es muy costoso en cuanto a tiempo, entonces no siempre es conveniente crear indices
#
# 5) Conectarse a la base de datos 'sakila' de MySQL y ejecutar la consulta siguiente para poder conservar información sobre el rendimiento de consultas:
#
# <code>set profiling=1;</code>
#
# Ejecutar 10 veces la consulta siguiente:
# <code>select * from rental where return_date>="2005-08-25 17:48:44";</code>
#
# Luego, ejecutar el comando:
# <code>show profiles;</code>
#
# ¿Cuál es la duración promedia del SGBD para responder a esta consulta?
#
#     Tarda aproximadamente 0.025 segundos
#
# 6) Crear un index sobre la columna 'return_date', y medir nuevamente 10 veces el rendimiento de la misma consulta. ¿Cuál es el nuevo valor promedio?
#
#     Ahora la duración es de aproximadamente 0.016
#
# 7) ¿Cómo crear índices en Mongo?
#
#     db.users.ensureIndex( { "Nombre_atributo" : 1 } )
#
# - <b>Transacciones</b>
#
# Referencias:
# - Introducción a Transacciones en MySQL: http://raknarrok.blogspot.com/2011/03/introduccion-transacciones.html
# - Transacción en MySQL: https://dev.mysql.com/doc/refman/8.0/en/commit.html
# - Transacción en Mongo: https://docs.mongodb.com/manual/core/transactions/
#
# 1) ¿Qué es una transacción?
#
#     Es un conjunto de operaciones elementales que se realiza de forma aislada para no perder consistencia en una base de datos
#
# 2) ¿En términos de transacción, cuáles son las características que deberian garantizar un buen SGBD?
#
#     Se debe garantizar que las transacciones sean atomicas (que para finalizar la transaccion, se hayan hecho todas las operaciones, de lo contrario, ninguna operacion se ejecuta) la consistencia de datos al finalizar una transacción, además las inconsistencias en este proceso no se pueden ver en la base de datos mientras ocurre, también se debe garantizar que las transacciones son aisladas, esto quiere decir que si hay operaciones ejecutandose de forma concurrente, no pueden interferirse unas con otras, y por ultimo, la durabilidad de los datos en el sistema, incluso luego de un fallo
#
# 3) En MySQL, crear una tabla <b>bank_user(name VARCHAR(10), account INT)</b> que permite conocer el monto disponible en la cuenta bancaria de algunos usuarios.
#
# 4) Realizar una operación que permita transferir 100.000 pesos del usuario A al usuario B. ¿Cómo garantizar que la operación no va a generar algún incoherencia en los datos? Escribir el código SQL correspondiente.
#
#     set autocommit=0;
#     begin;
#     ...
#     commit;
#
# 5) Supongamos que queremos hacerlo mismo en Mongo. ¿Mongo soporta transacciones ACID? ¿Desde cuándo? ¿Cómo se puede hacer transacciones? ¿Con qué limitaciones?
#
#     La forma de hacer transacciones en mongo es mediante una librería que permita hacerlo, ya que mongo no ha implementado las transacciones dentro de sus facultades
#
# - <b>Sharding y Replicación</b>
#
# 1) ¿Cuál es el principio del Sharding?
#
#     Se llama sharding a la practica de particionar una base de datos en diferentes servidores para poder hacer consultas más rápidas
#
# 2) ¿Cuál es el principio de la Replicación?
#
#     La replicacion se utiliza para hacer copias de seguridad de una base de datos, de manera que si falla la base de datos principal, puede ser reemplazada por una de estas replicaciones
#
# 3) ¿MySQL implementa mecanismos de Sharding/Replicación? y Mongo?
#
#     El mecanismo de replicación si es incorporado por MySql de fabrica, usando copias, donde hay una primaria, y secundarias, tal cual en mongo
#     Por otro lado, el sharding no es incorporado por MySql de fabica, pero aún así, si se puede hacer mediante MySql Cluster que puedes particiones automaticamente
